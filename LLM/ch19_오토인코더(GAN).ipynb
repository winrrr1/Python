# %% [markdown]
# # 19장 세상에 없는 얼굴 GAN, 오토인코더

# %% [markdown]
# ## 3. 적대적 신경망 실행하기

# %% [markdown]
# ### 실습: GAN 모델 만들기

# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.layers import Input, Dense, Reshape, Flatten, Dropout
from tensorflow.keras.layers import BatchNormalization, Activation, LeakyReLU, UpSampling2D, Conv2D
from tensorflow.keras.models import Sequential, Model

import numpy as np
import matplotlib.pyplot as plt

# 생성자 모델을 만듭니다.
generator = Sequential()
generator.add(Dense(128*7*7, input_dim=100, activation=LeakyReLU(0.2)))
generator.add(BatchNormalization())
generator.add(Reshape((7, 7, 128)))
generator.add(UpSampling2D())
generator.add(Conv2D(64, kernel_size=5, padding='same'))
generator.add(BatchNormalization())
generator.add(Activation(LeakyReLU(0.2)))
generator.add(UpSampling2D())
generator.add(Conv2D(1, kernel_size=5, padding='same', activation='tanh'))

# 판별자 모델을 만듭니다.
discriminator = Sequential()
discriminator.add(Conv2D(64, kernel_size=5, strides=2, input_shape=(28,28,1), padding="same"))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Conv2D(128, kernel_size=5, strides=2, padding="same"))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Flatten())
discriminator.add(Dense(1, activation='sigmoid'))
discriminator.compile(loss='binary_crossentropy', optimizer='adam')
discriminator.trainable = False

# 생성자와 판별자 모델을 연결시키는 gan 모델을 만듭니다.
ginput = Input(shape=(100,))
dis_output = discriminator(generator(ginput))
gan = Model(ginput, dis_output)
gan.compile(loss='binary_crossentropy', optimizer='adam')
gan.summary()

# 신경망을 실행시키는 함수를 만듭니다.
def gan_train(epoch, batch_size, saving_interval):

  # MNIST 데이터를 불러옵니다.

  (X_train, _), (_, _) = mnist.load_data()  # 앞서 불러온 적 있는 MNIST를 다시 이용합니다. 단, 테스트 과정은 필요 없고 이미지만 사용할 것이기 때문에 X_train만 불러왔습니다.
  X_train = X_train.reshape(X_train.shape[0], 28, 28, 1).astype('float32')
  X_train = (X_train - 127.5) / 127.5  # 픽셀 값은 0에서 255 사이의 값입니다. 이전에 255로 나누어 줄때는 이를 0~1 사이의 값으로 바꾸었던 것인데, 여기서는 127.5를 빼준 뒤 127.5로 나누어 줌으로 인해 -1에서 1사이의 값으로 바뀌게 됩니다.
  # X_train.shape, Y_train.shape, X_test.shape, Y_test.shape

  true = np.ones((batch_size, 1))
  fake = np.zeros((batch_size, 1))

  for i in range(epoch):
          # 실제 데이터를 판별자에 입력하는 부분입니다.
          idx = np.random.randint(0, X_train.shape[0], batch_size)
          imgs = X_train[idx]
          d_loss_real = discriminator.train_on_batch(imgs, true)

          # 가상 이미지를 판별자에 입력하는 부분입니다.
          noise = np.random.normal(0, 1, (batch_size, 100))
          gen_imgs = generator.predict(noise)
          d_loss_fake = discriminator.train_on_batch(gen_imgs, fake)

          # 판별자와 생성자의 오차를 계산합니다.
          d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)
          g_loss = gan.train_on_batch(noise, true)

          print('epoch:%d' % i, ' d_loss:%.4f' % d_loss, ' g_loss:%.4f' % g_loss)

        # 이 부분은 중간 과정을 이미지로 저장해 주는 부분입니다. 이 장의 주요 내용과 관련이 없어
        # 소스 코드만 첨부합니다. 만들어진 이미지들은 gan_images 폴더에 저장됩니다.
          if i % saving_interval == 0:
              #r, c = 5, 5
              noise = np.random.normal(0, 1, (25, 100))
              gen_imgs = generator.predict(noise)

              # Rescale images 0 - 1
              gen_imgs = 0.5 * gen_imgs + 0.5

              fig, axs = plt.subplots(5, 5)
              count = 0
              for j in range(5):
                  for k in range(5):
                      axs[j, k].imshow(gen_imgs[count, :, :, 0], cmap='gray')
                      axs[j, k].axis('off')
                      count += 1
              fig.savefig("./gan_mnist_%d.png" % i)

gan_train(2001, 32, 200)  # 2000번 반복되고, 배치 사이즈는 32,  200번마다 결과가 저장되게 하였습니다.
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 100)]             0
#
#  sequential (Sequential)     (None, 28, 28, 1)         865281
#
#  sequential_1 (Sequential)   (None, 1)                 212865
#
# =================================================================
# Total params: 1,078,146
# Trainable params: 852,609
# Non-trainable params: 225,537
# _________________________________________________________________
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x0000012A53D14EE8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x0000012A53D14EE8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x0000012A53E6EF78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x0000012A53E6EF78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x0000012A53DD60D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x0000012A53DD60D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# epoch:0  d_loss:0.6675  g_loss:0.6889
# epoch:1  d_loss:0.3965  g_loss:0.3330
# epoch:2  d_loss:0.4619  g_loss:0.0717
# epoch:3  d_loss:0.9692  g_loss:0.0419
# epoch:4  d_loss:1.0864  g_loss:0.0852
# epoch:5  d_loss:0.7518  g_loss:0.3665
# epoch:6  d_loss:0.4948  g_loss:0.8815
# epoch:7  d_loss:0.4983  g_loss:1.2507
# epoch:8  d_loss:0.5559  g_loss:1.2759
# epoch:9  d_loss:0.4708  g_loss:1.1640
# epoch:10  d_loss:0.4023  g_loss:0.9506
# epoch:11  d_loss:0.3071  g_loss:0.7959
# epoch:12  d_loss:0.2661  g_loss:0.7619
# epoch:13  d_loss:0.2130  g_loss:0.7076
# epoch:14  d_loss:0.1817  g_loss:0.5901
# epoch:15  d_loss:0.1515  g_loss:0.5984
# epoch:16  d_loss:0.1545  g_loss:0.5692
# epoch:17  d_loss:0.2195  g_loss:0.4827
# epoch:18  d_loss:0.2515  g_loss:0.1787
# epoch:19  d_loss:0.3156  g_loss:0.1160
# epoch:20  d_loss:0.3652  g_loss:0.1183
# epoch:21  d_loss:0.4224  g_loss:0.0945
# epoch:22  d_loss:0.7508  g_loss:0.0819
# epoch:23  d_loss:0.4243  g_loss:0.2198
# epoch:24  d_loss:0.5349  g_loss:0.4082
# epoch:25  d_loss:0.7001  g_loss:0.4547
# epoch:26  d_loss:0.5904  g_loss:0.3796
# epoch:27  d_loss:0.6672  g_loss:0.3471
# epoch:28  d_loss:0.5397  g_loss:0.5282
# epoch:29  d_loss:0.5695  g_loss:0.6159
# epoch:30  d_loss:0.5675  g_loss:0.7134
# epoch:31  d_loss:0.5399  g_loss:0.6709
# epoch:32  d_loss:0.4819  g_loss:0.6677
# epoch:33  d_loss:0.4632  g_loss:0.6781
# epoch:34  d_loss:0.4397  g_loss:0.6771
# epoch:35  d_loss:0.4422  g_loss:0.6469
# epoch:36  d_loss:0.4077  g_loss:0.5599
# epoch:37  d_loss:0.4510  g_loss:0.6097
# epoch:38  d_loss:0.3507  g_loss:0.7852
# epoch:39  d_loss:0.2843  g_loss:0.8409
# epoch:40  d_loss:0.3758  g_loss:0.7584
# epoch:41  d_loss:0.2835  g_loss:0.9791
# epoch:42  d_loss:0.2375  g_loss:1.3089
# epoch:43  d_loss:0.1772  g_loss:1.4644
# epoch:44  d_loss:0.1480  g_loss:1.7093
# epoch:45  d_loss:0.1082  g_loss:2.2244
# epoch:46  d_loss:0.1259  g_loss:2.5658
# epoch:47  d_loss:0.0857  g_loss:3.0503
# epoch:48  d_loss:0.0473  g_loss:3.7360
# epoch:49  d_loss:0.1237  g_loss:3.9295
# epoch:50  d_loss:0.0888  g_loss:3.4299
# epoch:51  d_loss:0.1229  g_loss:4.2376
# epoch:52  d_loss:0.0834  g_loss:4.0762
# epoch:53  d_loss:0.1194  g_loss:3.7200
# epoch:54  d_loss:0.1031  g_loss:3.4507
# epoch:55  d_loss:0.0791  g_loss:3.9482
# epoch:56  d_loss:0.2399  g_loss:2.3751
# epoch:57  d_loss:0.4668  g_loss:1.8676
# epoch:58  d_loss:0.4328  g_loss:3.3391
# epoch:59  d_loss:0.9000  g_loss:1.1055
# epoch:60  d_loss:0.8986  g_loss:1.1039
# epoch:61  d_loss:0.2194  g_loss:2.8429
# epoch:62  d_loss:0.2082  g_loss:3.7894
# epoch:63  d_loss:0.1222  g_loss:3.2755
# epoch:64  d_loss:0.0275  g_loss:3.0540
# epoch:65  d_loss:0.0522  g_loss:3.1707
# epoch:66  d_loss:0.0265  g_loss:3.3384
# epoch:67  d_loss:0.0992  g_loss:4.2676
# epoch:68  d_loss:0.0350  g_loss:5.0291
# epoch:69  d_loss:0.0111  g_loss:6.2690
# epoch:70  d_loss:0.0727  g_loss:6.8531
# epoch:71  d_loss:0.0244  g_loss:7.6857
# epoch:72  d_loss:0.1430  g_loss:7.2577
# epoch:73  d_loss:0.1075  g_loss:6.9478
# epoch:74  d_loss:0.2820  g_loss:7.1941
# epoch:75  d_loss:0.3678  g_loss:7.7500
# epoch:76  d_loss:0.4438  g_loss:6.5227
# epoch:77  d_loss:0.3165  g_loss:6.7884
# epoch:78  d_loss:0.4072  g_loss:5.2277
# epoch:79  d_loss:0.5227  g_loss:3.2577
# epoch:80  d_loss:0.3567  g_loss:4.1468
# epoch:81  d_loss:0.1781  g_loss:4.5927
# epoch:82  d_loss:0.1544  g_loss:4.2214
# epoch:83  d_loss:0.3430  g_loss:2.0624
# epoch:84  d_loss:0.2534  g_loss:2.1766
# epoch:85  d_loss:0.1620  g_loss:3.3526
# epoch:86  d_loss:0.1505  g_loss:3.5136
# epoch:87  d_loss:0.2070  g_loss:3.3509
# epoch:88  d_loss:0.1657  g_loss:3.2397
# epoch:89  d_loss:0.1751  g_loss:3.4867
# epoch:90  d_loss:0.1770  g_loss:3.2712
# epoch:91  d_loss:0.1407  g_loss:3.4154
# epoch:92  d_loss:0.1952  g_loss:4.4240
# epoch:93  d_loss:0.2084  g_loss:4.2958
# epoch:94  d_loss:0.3398  g_loss:2.8990
# epoch:95  d_loss:0.2730  g_loss:3.2361
# epoch:96  d_loss:0.3046  g_loss:3.2629
# epoch:97  d_loss:0.3713  g_loss:3.6285
# epoch:98  d_loss:0.3637  g_loss:3.5517
# epoch:99  d_loss:0.2468  g_loss:3.7674
# epoch:100  d_loss:0.2283  g_loss:3.7212
# epoch:101  d_loss:0.2562  g_loss:4.0621
# epoch:102  d_loss:0.2169  g_loss:4.6363
# epoch:103  d_loss:0.4045  g_loss:4.1237
# epoch:104  d_loss:0.3553  g_loss:3.3213
# epoch:105  d_loss:0.4988  g_loss:3.1139
# epoch:106  d_loss:0.4108  g_loss:3.5060
# epoch:107  d_loss:0.2989  g_loss:3.8499
# epoch:108  d_loss:0.4217  g_loss:3.3597
# epoch:109  d_loss:0.5421  g_loss:2.9113
# epoch:110  d_loss:0.4339  g_loss:2.5793
# epoch:111  d_loss:0.3155  g_loss:3.8338
# epoch:112  d_loss:0.5775  g_loss:2.6671
# epoch:113  d_loss:0.4892  g_loss:2.8312
# epoch:114  d_loss:0.4002  g_loss:2.8306
# epoch:115  d_loss:0.3407  g_loss:3.6094
# epoch:116  d_loss:0.4664  g_loss:3.2400
# epoch:117  d_loss:0.6035  g_loss:2.4835
# epoch:118  d_loss:0.3962  g_loss:2.6606
# epoch:119  d_loss:0.4702  g_loss:2.6521
# epoch:120  d_loss:0.2843  g_loss:3.3116
# epoch:121  d_loss:0.3886  g_loss:2.8225
# epoch:122  d_loss:0.4320  g_loss:2.4781
# epoch:123  d_loss:0.5574  g_loss:1.8485
# epoch:124  d_loss:0.4829  g_loss:2.5143
# epoch:125  d_loss:0.4272  g_loss:2.7626
# epoch:126  d_loss:0.4466  g_loss:3.1742
# epoch:127  d_loss:0.4771  g_loss:2.4306
# epoch:128  d_loss:0.3833  g_loss:2.1046
# epoch:129  d_loss:0.3734  g_loss:2.5569
# epoch:130  d_loss:0.5051  g_loss:2.0498
# epoch:131  d_loss:0.3024  g_loss:2.7719
# epoch:132  d_loss:0.2422  g_loss:2.7743
# epoch:133  d_loss:0.4607  g_loss:2.2471
# epoch:134  d_loss:0.3486  g_loss:2.6358
# epoch:135  d_loss:0.2631  g_loss:3.5288
# epoch:136  d_loss:0.3288  g_loss:2.6387
# epoch:137  d_loss:0.2201  g_loss:2.9979
# epoch:138  d_loss:0.3784  g_loss:2.7111
# epoch:139  d_loss:0.4106  g_loss:2.0808
# epoch:140  d_loss:0.4061  g_loss:1.8720
# epoch:141  d_loss:0.4036  g_loss:2.3870
# epoch:142  d_loss:0.3387  g_loss:3.2928
# epoch:143  d_loss:0.4566  g_loss:3.3070
# epoch:144  d_loss:0.4458  g_loss:2.5430
# epoch:145  d_loss:0.4255  g_loss:2.4184
# epoch:146  d_loss:0.3723  g_loss:2.1906
# epoch:147  d_loss:0.6203  g_loss:1.8165
# epoch:148  d_loss:0.2948  g_loss:2.1289
# epoch:149  d_loss:0.3051  g_loss:2.5616
# epoch:150  d_loss:0.2252  g_loss:3.1846
# epoch:151  d_loss:0.3120  g_loss:2.9546
# epoch:152  d_loss:0.5255  g_loss:2.4080
# epoch:153  d_loss:0.4374  g_loss:1.4006
# epoch:154  d_loss:0.4788  g_loss:2.0402
# epoch:155  d_loss:0.4574  g_loss:2.2754
# epoch:156  d_loss:0.2680  g_loss:3.1621
# epoch:157  d_loss:0.4053  g_loss:2.9922
# epoch:158  d_loss:0.4937  g_loss:2.0821
# epoch:159  d_loss:0.5332  g_loss:1.4315
# epoch:160  d_loss:0.3815  g_loss:1.3939
# epoch:161  d_loss:0.3510  g_loss:2.4308
# epoch:162  d_loss:0.2826  g_loss:3.0750
# epoch:163  d_loss:0.3641  g_loss:2.3284
# epoch:164  d_loss:0.4006  g_loss:2.1206
# epoch:165  d_loss:0.3314  g_loss:1.8127
# epoch:166  d_loss:0.3261  g_loss:1.8814
# epoch:167  d_loss:0.4436  g_loss:1.6724
# epoch:168  d_loss:0.3187  g_loss:1.8924
# epoch:169  d_loss:0.4842  g_loss:1.6318
# epoch:170  d_loss:0.4573  g_loss:1.8753
# epoch:171  d_loss:0.4031  g_loss:1.8933
# epoch:172  d_loss:0.4025  g_loss:1.8279
# epoch:173  d_loss:0.5523  g_loss:1.1588
# epoch:174  d_loss:0.5558  g_loss:1.6286
# epoch:175  d_loss:0.3802  g_loss:1.4234
# epoch:176  d_loss:0.3944  g_loss:2.3398
# epoch:177  d_loss:0.4234  g_loss:2.3886
# epoch:178  d_loss:0.5124  g_loss:1.7805
# epoch:179  d_loss:0.3998  g_loss:1.7147
# epoch:180  d_loss:0.5231  g_loss:1.3456
# epoch:181  d_loss:0.6057  g_loss:1.6623
# epoch:182  d_loss:0.4843  g_loss:1.9698
# epoch:183  d_loss:0.5622  g_loss:1.8527
# epoch:184  d_loss:0.5927  g_loss:1.7735
# epoch:185  d_loss:0.4952  g_loss:1.7657
# epoch:186  d_loss:0.5314  g_loss:1.9676
# epoch:187  d_loss:0.4123  g_loss:2.0061
# epoch:188  d_loss:0.4046  g_loss:1.7042
# epoch:189  d_loss:0.3185  g_loss:1.8244
# epoch:190  d_loss:0.5350  g_loss:1.5979
# epoch:191  d_loss:0.5459  g_loss:1.8935
# epoch:192  d_loss:0.3783  g_loss:1.7307
# epoch:193  d_loss:0.4034  g_loss:1.7196
# epoch:194  d_loss:0.4551  g_loss:1.5669
# epoch:195  d_loss:0.5046  g_loss:1.7344
# epoch:196  d_loss:0.5550  g_loss:2.0382
# epoch:197  d_loss:0.5635  g_loss:1.8039
# epoch:198  d_loss:0.3876  g_loss:2.2280
# epoch:199  d_loss:0.3529  g_loss:2.1087
# epoch:200  d_loss:0.5076  g_loss:1.9307
# epoch:201  d_loss:0.6057  g_loss:1.4634
# epoch:202  d_loss:0.5144  g_loss:1.6304
# epoch:203  d_loss:0.5425  g_loss:1.4043
# epoch:204  d_loss:0.6252  g_loss:1.3024
# epoch:205  d_loss:0.4719  g_loss:2.1404
# epoch:206  d_loss:0.4989  g_loss:1.8860
# epoch:207  d_loss:0.5813  g_loss:1.7959
# epoch:208  d_loss:0.4858  g_loss:1.8711
# epoch:209  d_loss:0.5097  g_loss:1.3193
# epoch:210  d_loss:0.3672  g_loss:1.4971
# epoch:211  d_loss:0.4373  g_loss:1.7688
# epoch:212  d_loss:0.4803  g_loss:1.9124
# epoch:213  d_loss:0.5727  g_loss:1.7675
# epoch:214  d_loss:0.4771  g_loss:2.0641
# epoch:215  d_loss:0.5749  g_loss:1.6289
# epoch:216  d_loss:0.5837  g_loss:1.7981
# epoch:217  d_loss:0.5535  g_loss:1.5551
# epoch:218  d_loss:0.5250  g_loss:1.9304
# epoch:219  d_loss:0.5231  g_loss:1.8184
# epoch:220  d_loss:0.4556  g_loss:1.7660
# epoch:221  d_loss:0.5244  g_loss:1.6523
# epoch:222  d_loss:0.4228  g_loss:2.2131
# epoch:223  d_loss:0.4408  g_loss:2.2148
# epoch:224  d_loss:0.4532  g_loss:2.5191
# epoch:225  d_loss:0.5261  g_loss:2.1217
# epoch:226  d_loss:0.3565  g_loss:1.9078
# epoch:227  d_loss:0.4619  g_loss:1.7801
# epoch:228  d_loss:0.5798  g_loss:1.6969
# epoch:229  d_loss:0.3854  g_loss:1.7800
# epoch:230  d_loss:0.4500  g_loss:1.9222
# epoch:231  d_loss:0.4081  g_loss:2.1170
# epoch:232  d_loss:0.3839  g_loss:1.9284
# epoch:233  d_loss:0.3767  g_loss:2.1047
# epoch:234  d_loss:0.4367  g_loss:1.7262
# epoch:235  d_loss:0.4211  g_loss:1.6404
# epoch:236  d_loss:0.4533  g_loss:1.4534
# epoch:237  d_loss:0.4777  g_loss:1.7536
# epoch:238  d_loss:0.5389  g_loss:2.0396
# epoch:239  d_loss:0.5456  g_loss:1.4855
# epoch:240  d_loss:0.5359  g_loss:1.7417
# epoch:241  d_loss:0.4616  g_loss:1.6336
# epoch:242  d_loss:0.4764  g_loss:1.6578
# epoch:243  d_loss:0.5388  g_loss:1.8139
# epoch:244  d_loss:0.4833  g_loss:1.9177
# epoch:245  d_loss:0.3672  g_loss:1.8064
# epoch:246  d_loss:0.4155  g_loss:2.2137
# epoch:247  d_loss:0.6156  g_loss:1.6904
# epoch:248  d_loss:0.5242  g_loss:1.6654
# epoch:249  d_loss:0.4964  g_loss:1.5104
# epoch:250  d_loss:0.5053  g_loss:1.5934
# epoch:251  d_loss:0.4039  g_loss:1.5917
# epoch:252  d_loss:0.4198  g_loss:1.9520
# epoch:253  d_loss:0.4763  g_loss:2.0619
# epoch:254  d_loss:0.4401  g_loss:2.0593
# epoch:255  d_loss:0.5057  g_loss:1.8148
# epoch:256  d_loss:0.4905  g_loss:1.4885
# epoch:257  d_loss:0.5638  g_loss:1.6512
# epoch:258  d_loss:0.4634  g_loss:1.6109
# epoch:259  d_loss:0.4668  g_loss:1.7036
# epoch:260  d_loss:0.2852  g_loss:2.1168
# epoch:261  d_loss:0.2956  g_loss:1.9937
# epoch:262  d_loss:0.4238  g_loss:1.9185
# epoch:263  d_loss:0.4060  g_loss:1.5708
# epoch:264  d_loss:0.3269  g_loss:1.8002
# epoch:265  d_loss:0.3406  g_loss:1.9776
# epoch:266  d_loss:0.3333  g_loss:1.9720
# epoch:267  d_loss:0.4246  g_loss:1.8598
# epoch:268  d_loss:0.4971  g_loss:1.7947
# epoch:269  d_loss:0.4371  g_loss:1.9012
# epoch:270  d_loss:0.7746  g_loss:2.0953
# epoch:271  d_loss:0.3594  g_loss:2.2048
# epoch:272  d_loss:0.3695  g_loss:2.1363
# epoch:273  d_loss:0.4750  g_loss:2.2783
# epoch:274  d_loss:0.5031  g_loss:2.0541
# epoch:275  d_loss:0.6034  g_loss:2.2589
# epoch:276  d_loss:0.4135  g_loss:2.3767
# epoch:277  d_loss:0.4366  g_loss:2.4794
# epoch:278  d_loss:0.3061  g_loss:2.0380
# epoch:279  d_loss:0.3492  g_loss:2.3547
# epoch:280  d_loss:0.3399  g_loss:2.5009
# epoch:281  d_loss:0.3850  g_loss:2.5116
# epoch:282  d_loss:0.5062  g_loss:1.8110
# epoch:283  d_loss:0.3421  g_loss:2.2474
# epoch:284  d_loss:0.2171  g_loss:3.0064
# epoch:285  d_loss:0.5164  g_loss:2.5847
# epoch:286  d_loss:0.4448  g_loss:2.5616
# epoch:287  d_loss:0.3921  g_loss:2.2708
# epoch:288  d_loss:0.4640  g_loss:2.1509
# epoch:289  d_loss:0.4226  g_loss:2.3934
# epoch:290  d_loss:0.5899  g_loss:2.0678
# epoch:291  d_loss:0.5288  g_loss:2.1351
# epoch:292  d_loss:0.4716  g_loss:2.1203
# epoch:293  d_loss:0.4112  g_loss:2.2632
# epoch:294  d_loss:0.5370  g_loss:2.0284
# epoch:295  d_loss:0.4610  g_loss:2.4691
# epoch:296  d_loss:0.4670  g_loss:1.9978
# epoch:297  d_loss:0.6141  g_loss:1.8854
# epoch:298  d_loss:0.4912  g_loss:1.5458
# epoch:299  d_loss:0.5748  g_loss:1.6849
# epoch:300  d_loss:0.6787  g_loss:1.3475
# epoch:301  d_loss:0.5505  g_loss:1.6528
# epoch:302  d_loss:0.7079  g_loss:1.4596
# epoch:303  d_loss:0.5974  g_loss:1.6401
# epoch:304  d_loss:0.4418  g_loss:2.1164
# epoch:305  d_loss:0.5654  g_loss:2.0889
# epoch:306  d_loss:0.6323  g_loss:1.4578
# epoch:307  d_loss:0.6477  g_loss:1.1580
# epoch:308  d_loss:0.6346  g_loss:1.3093
# epoch:309  d_loss:0.4966  g_loss:1.8345
# epoch:310  d_loss:0.5661  g_loss:1.4236
# epoch:311  d_loss:0.5167  g_loss:1.8304
# epoch:312  d_loss:0.5388  g_loss:1.9962
# epoch:313  d_loss:0.5359  g_loss:1.8192
# epoch:314  d_loss:0.5300  g_loss:1.7192
# epoch:315  d_loss:0.3849  g_loss:1.6561
# epoch:316  d_loss:0.4364  g_loss:1.6558
# epoch:317  d_loss:0.3473  g_loss:1.7798
# epoch:318  d_loss:0.4368  g_loss:2.3746
# epoch:319  d_loss:0.2646  g_loss:2.3766
# epoch:320  d_loss:0.4544  g_loss:2.3851
# epoch:321  d_loss:0.2623  g_loss:2.5054
# epoch:322  d_loss:0.4540  g_loss:1.9497
# epoch:323  d_loss:0.5216  g_loss:2.0450
# epoch:324  d_loss:0.3599  g_loss:2.4010
# epoch:325  d_loss:0.3789  g_loss:2.0832
# epoch:326  d_loss:0.3350  g_loss:2.3470
# epoch:327  d_loss:0.3401  g_loss:2.5157
# epoch:328  d_loss:0.5135  g_loss:2.0538
# epoch:329  d_loss:0.3901  g_loss:2.1414
# epoch:330  d_loss:0.5319  g_loss:1.5006
# epoch:331  d_loss:0.4659  g_loss:1.1910
# epoch:332  d_loss:0.4754  g_loss:1.1906
# epoch:333  d_loss:0.4086  g_loss:1.6786
# epoch:334  d_loss:0.4840  g_loss:1.5746
# epoch:335  d_loss:0.5579  g_loss:1.8917
# epoch:336  d_loss:0.7835  g_loss:1.8085
# epoch:337  d_loss:0.5378  g_loss:1.6914
# epoch:338  d_loss:0.6614  g_loss:1.7900
# epoch:339  d_loss:0.5906  g_loss:1.4741
# epoch:340  d_loss:0.6977  g_loss:1.1956
# epoch:341  d_loss:0.6175  g_loss:1.4142
# epoch:342  d_loss:0.6432  g_loss:1.7573
# epoch:343  d_loss:0.8441  g_loss:1.3455
# epoch:344  d_loss:0.5988  g_loss:1.4712
# epoch:345  d_loss:0.5221  g_loss:1.6432
# epoch:346  d_loss:0.5022  g_loss:1.6320
# epoch:347  d_loss:0.4193  g_loss:2.0369
# epoch:348  d_loss:0.3287  g_loss:2.1627
# epoch:349  d_loss:0.3483  g_loss:2.7403
# epoch:350  d_loss:0.4801  g_loss:2.7078
# epoch:351  d_loss:0.2984  g_loss:2.9143
# epoch:352  d_loss:0.3586  g_loss:2.4692
# epoch:353  d_loss:0.2389  g_loss:2.4378
# epoch:354  d_loss:0.1924  g_loss:2.5527
# epoch:355  d_loss:0.2632  g_loss:2.2507
# epoch:356  d_loss:0.2588  g_loss:2.5196
# epoch:357  d_loss:0.2269  g_loss:2.1915
# epoch:358  d_loss:0.1695  g_loss:2.6427
# epoch:359  d_loss:0.2969  g_loss:2.2192
# epoch:360  d_loss:0.2176  g_loss:2.7846
# epoch:361  d_loss:0.2687  g_loss:2.7669
# epoch:362  d_loss:0.1642  g_loss:2.8723
# epoch:363  d_loss:0.2689  g_loss:2.7633
# epoch:364  d_loss:0.2824  g_loss:2.5592
# epoch:365  d_loss:0.2976  g_loss:2.0699
# epoch:366  d_loss:0.2265  g_loss:2.1446
# epoch:367  d_loss:0.3093  g_loss:2.3365
# epoch:368  d_loss:0.4149  g_loss:2.2696
# epoch:369  d_loss:0.3265  g_loss:2.7742
# epoch:370  d_loss:0.2974  g_loss:2.4529
# epoch:371  d_loss:0.4481  g_loss:2.1328
# epoch:372  d_loss:0.4483  g_loss:2.4112
# epoch:373  d_loss:0.3665  g_loss:2.8364
# epoch:374  d_loss:0.5518  g_loss:2.1083
# epoch:375  d_loss:0.4822  g_loss:1.7179
# epoch:376  d_loss:0.4578  g_loss:1.7486
# epoch:377  d_loss:0.3415  g_loss:2.1615
# epoch:378  d_loss:0.4866  g_loss:3.0009
# epoch:379  d_loss:0.3755  g_loss:3.0836
# epoch:380  d_loss:0.4874  g_loss:2.6278
# epoch:381  d_loss:0.3275  g_loss:2.4194
# epoch:382  d_loss:0.4155  g_loss:2.2720
# epoch:383  d_loss:0.2988  g_loss:2.1577
# epoch:384  d_loss:0.3960  g_loss:2.5995
# epoch:385  d_loss:0.4102  g_loss:2.5708
# epoch:386  d_loss:0.3122  g_loss:2.6570
# epoch:387  d_loss:0.2677  g_loss:3.2478
# epoch:388  d_loss:0.2701  g_loss:3.1668
# epoch:389  d_loss:0.3103  g_loss:2.7946
# epoch:390  d_loss:0.4398  g_loss:2.1122
# epoch:391  d_loss:0.4338  g_loss:2.6937
# epoch:392  d_loss:0.3396  g_loss:2.6749
# epoch:393  d_loss:0.3876  g_loss:2.6118
# epoch:394  d_loss:0.3447  g_loss:2.5197
# epoch:395  d_loss:0.3950  g_loss:2.5860
# epoch:396  d_loss:0.2861  g_loss:2.9992
# epoch:397  d_loss:0.4890  g_loss:2.8092
# epoch:398  d_loss:0.6184  g_loss:2.7226
# epoch:399  d_loss:0.5757  g_loss:1.6012
# epoch:400  d_loss:0.4260  g_loss:1.8447
# epoch:401  d_loss:0.6014  g_loss:1.6549
# epoch:402  d_loss:0.4583  g_loss:2.0398
# epoch:403  d_loss:0.4780  g_loss:1.9056
# epoch:404  d_loss:0.4077  g_loss:2.1603
# epoch:405  d_loss:0.5362  g_loss:1.8297
# epoch:406  d_loss:0.6056  g_loss:1.7221
# epoch:407  d_loss:0.5392  g_loss:1.5375
# epoch:408  d_loss:0.5998  g_loss:1.9241
# epoch:409  d_loss:0.3205  g_loss:2.1679
# epoch:410  d_loss:0.4589  g_loss:2.6096
# epoch:411  d_loss:0.5058  g_loss:2.4526
# epoch:412  d_loss:0.5877  g_loss:2.1953
# epoch:413  d_loss:0.3283  g_loss:2.3659
# epoch:414  d_loss:0.4560  g_loss:1.9290
# epoch:415  d_loss:0.3859  g_loss:1.8316
# epoch:416  d_loss:0.3676  g_loss:2.0353
# epoch:417  d_loss:0.2907  g_loss:2.4131
# epoch:418  d_loss:0.2577  g_loss:2.7214
# epoch:419  d_loss:0.3207  g_loss:2.7674
# epoch:420  d_loss:0.3537  g_loss:2.8344
# epoch:421  d_loss:0.2548  g_loss:2.8985
# epoch:422  d_loss:0.4001  g_loss:1.9330
# epoch:423  d_loss:0.2132  g_loss:2.3603
# epoch:424  d_loss:0.1846  g_loss:2.6972
# epoch:425  d_loss:0.2855  g_loss:2.3230
# epoch:426  d_loss:0.2159  g_loss:2.7201
# epoch:427  d_loss:0.2790  g_loss:2.9435
# epoch:428  d_loss:0.1894  g_loss:2.8456
# epoch:429  d_loss:0.1556  g_loss:3.5046
# epoch:430  d_loss:0.2751  g_loss:2.8065
# epoch:431  d_loss:0.3220  g_loss:2.5315
# epoch:432  d_loss:0.2573  g_loss:2.9455
# epoch:433  d_loss:0.2451  g_loss:2.5937
# epoch:434  d_loss:0.2589  g_loss:2.8998
# epoch:435  d_loss:0.3069  g_loss:2.6943
# epoch:436  d_loss:0.2928  g_loss:2.5197
# epoch:437  d_loss:0.2562  g_loss:2.6109
# epoch:438  d_loss:0.3914  g_loss:2.3582
# epoch:439  d_loss:0.2655  g_loss:2.3602
# epoch:440  d_loss:0.4621  g_loss:2.2922
# epoch:441  d_loss:0.4225  g_loss:2.9320
# epoch:442  d_loss:0.2722  g_loss:3.4040
# epoch:443  d_loss:0.3938  g_loss:2.7207
# epoch:444  d_loss:0.4110  g_loss:1.9246
# epoch:445  d_loss:0.2977  g_loss:1.4796
# epoch:446  d_loss:0.4184  g_loss:1.5991
# epoch:447  d_loss:0.2646  g_loss:2.6157
# epoch:448  d_loss:0.3841  g_loss:2.9750
# epoch:449  d_loss:0.2719  g_loss:3.5049
# epoch:450  d_loss:0.4927  g_loss:2.8311
# epoch:451  d_loss:0.3274  g_loss:2.5130
# epoch:452  d_loss:0.3164  g_loss:2.2296
# epoch:453  d_loss:0.3265  g_loss:2.2240
# epoch:454  d_loss:0.5018  g_loss:1.8937
# epoch:455  d_loss:0.2910  g_loss:1.9377
# epoch:456  d_loss:0.3110  g_loss:1.9542
# epoch:457  d_loss:0.4324  g_loss:2.1201
# epoch:458  d_loss:0.2878  g_loss:2.2710
# epoch:459  d_loss:0.1894  g_loss:2.6183
# epoch:460  d_loss:0.3836  g_loss:2.0819
# epoch:461  d_loss:0.3650  g_loss:2.5043
# epoch:462  d_loss:0.4677  g_loss:2.6397
# epoch:463  d_loss:0.3033  g_loss:2.6765
# epoch:464  d_loss:0.4732  g_loss:1.9044
# epoch:465  d_loss:0.3375  g_loss:2.2181
# epoch:466  d_loss:0.3509  g_loss:2.0644
# epoch:467  d_loss:0.4050  g_loss:3.0460
# epoch:468  d_loss:0.3275  g_loss:2.6136
# epoch:469  d_loss:0.1993  g_loss:3.2843
# epoch:470  d_loss:0.2298  g_loss:3.2664
# epoch:471  d_loss:0.3399  g_loss:2.8118
# epoch:472  d_loss:0.4261  g_loss:2.3099
# epoch:473  d_loss:0.2447  g_loss:2.2129
# epoch:474  d_loss:0.2825  g_loss:2.6903
# epoch:475  d_loss:0.2872  g_loss:2.9347
# epoch:476  d_loss:0.4638  g_loss:2.9135
# epoch:477  d_loss:0.4478  g_loss:2.8217
# epoch:478  d_loss:0.3335  g_loss:2.0996
# epoch:479  d_loss:0.2714  g_loss:2.7590
# epoch:480  d_loss:0.3120  g_loss:2.5758
# epoch:481  d_loss:0.3949  g_loss:2.2188
# epoch:482  d_loss:0.3119  g_loss:2.4117
# epoch:483  d_loss:0.4037  g_loss:2.7301
# epoch:484  d_loss:0.5203  g_loss:2.6837
# epoch:485  d_loss:0.3157  g_loss:2.6800
# epoch:486  d_loss:0.3948  g_loss:2.5171
# epoch:487  d_loss:0.3873  g_loss:2.7339
# epoch:488  d_loss:0.2660  g_loss:2.9151
# epoch:489  d_loss:0.2148  g_loss:2.5576
# epoch:490  d_loss:0.2359  g_loss:2.7614
# epoch:491  d_loss:0.2481  g_loss:2.5963
# epoch:492  d_loss:0.2627  g_loss:2.6638
# epoch:493  d_loss:0.2763  g_loss:2.7972
# epoch:494  d_loss:0.3312  g_loss:2.1741
# epoch:495  d_loss:0.3329  g_loss:2.3738
# epoch:496  d_loss:0.2657  g_loss:3.0913
# epoch:497  d_loss:0.2689  g_loss:2.4021
# epoch:498  d_loss:0.2817  g_loss:2.5914
# epoch:499  d_loss:0.2417  g_loss:3.1262
# epoch:500  d_loss:0.2487  g_loss:2.9731
# epoch:501  d_loss:0.2500  g_loss:2.4931
# epoch:502  d_loss:0.2394  g_loss:2.2793
# epoch:503  d_loss:0.1595  g_loss:3.2089
# epoch:504  d_loss:0.2450  g_loss:3.5629
# epoch:505  d_loss:0.2814  g_loss:2.9115
# epoch:506  d_loss:0.2633  g_loss:2.6227
# epoch:507  d_loss:0.3157  g_loss:2.8768
# epoch:508  d_loss:0.2885  g_loss:2.7305
# epoch:509  d_loss:0.3634  g_loss:3.3594
# epoch:510  d_loss:0.2070  g_loss:3.1708
# epoch:511  d_loss:0.3551  g_loss:2.9765
# epoch:512  d_loss:0.4246  g_loss:2.1024
# epoch:513  d_loss:0.2942  g_loss:2.0068
# epoch:514  d_loss:0.3844  g_loss:2.6290
# epoch:515  d_loss:0.2472  g_loss:2.4706
# epoch:516  d_loss:0.3033  g_loss:2.9362
# epoch:517  d_loss:0.2774  g_loss:2.5571
# epoch:518  d_loss:0.4079  g_loss:2.0924
# epoch:519  d_loss:0.3148  g_loss:2.2313
# epoch:520  d_loss:0.2734  g_loss:2.6534
# epoch:521  d_loss:0.2800  g_loss:2.6132
# epoch:522  d_loss:0.3152  g_loss:2.7664
# epoch:523  d_loss:0.3257  g_loss:2.3228
# epoch:524  d_loss:0.2771  g_loss:2.5363
# epoch:525  d_loss:0.3845  g_loss:2.1566
# epoch:526  d_loss:0.3055  g_loss:1.7891
# epoch:527  d_loss:0.2409  g_loss:2.4938
# epoch:528  d_loss:0.2754  g_loss:2.6358
# epoch:529  d_loss:0.3227  g_loss:2.7503
# epoch:530  d_loss:0.2306  g_loss:2.3823
# epoch:531  d_loss:0.2334  g_loss:2.0601
# epoch:532  d_loss:0.4211  g_loss:1.8046
# epoch:533  d_loss:0.2452  g_loss:2.3487
# epoch:534  d_loss:0.2988  g_loss:2.5242
# epoch:535  d_loss:0.1934  g_loss:2.9732
# epoch:536  d_loss:0.2130  g_loss:2.8850
# epoch:537  d_loss:0.2319  g_loss:2.9858
# epoch:538  d_loss:0.2299  g_loss:2.3262
# epoch:539  d_loss:0.2685  g_loss:2.1138
# epoch:540  d_loss:0.1809  g_loss:2.5683
# epoch:541  d_loss:0.2188  g_loss:2.8796
# epoch:542  d_loss:0.1137  g_loss:3.0260
# epoch:543  d_loss:0.2355  g_loss:3.3940
# epoch:544  d_loss:0.2137  g_loss:2.9682
# epoch:545  d_loss:0.2262  g_loss:2.1619
# epoch:546  d_loss:0.2343  g_loss:2.6000
# epoch:547  d_loss:0.1896  g_loss:2.8692
# epoch:548  d_loss:0.1246  g_loss:3.5013
# epoch:549  d_loss:0.1365  g_loss:3.8004
# epoch:550  d_loss:0.1761  g_loss:3.1059
# epoch:551  d_loss:0.2885  g_loss:2.6939
# epoch:552  d_loss:0.1440  g_loss:3.0615
# epoch:553  d_loss:0.2700  g_loss:2.6531
# epoch:554  d_loss:0.1557  g_loss:3.2412
# epoch:555  d_loss:0.2017  g_loss:3.8057
# epoch:556  d_loss:0.1308  g_loss:3.5281
# epoch:557  d_loss:0.2027  g_loss:3.3570
# epoch:558  d_loss:0.2057  g_loss:2.8380
# epoch:559  d_loss:0.1627  g_loss:3.0433
# epoch:560  d_loss:0.1654  g_loss:2.7342
# epoch:561  d_loss:0.1765  g_loss:3.0185
# epoch:562  d_loss:0.1165  g_loss:3.9910
# epoch:563  d_loss:0.1583  g_loss:3.0471
# epoch:564  d_loss:0.2066  g_loss:3.2928
# epoch:565  d_loss:0.1716  g_loss:3.1295
# epoch:566  d_loss:0.2801  g_loss:2.5625
# epoch:567  d_loss:0.2151  g_loss:2.7664
# epoch:568  d_loss:0.1561  g_loss:2.9743
# epoch:569  d_loss:0.2681  g_loss:2.5333
# epoch:570  d_loss:0.2045  g_loss:3.0769
# epoch:571  d_loss:0.2140  g_loss:3.8289
# epoch:572  d_loss:0.2147  g_loss:2.8838
# epoch:573  d_loss:0.2274  g_loss:2.6340
# epoch:574  d_loss:0.2243  g_loss:2.2625
# epoch:575  d_loss:0.3085  g_loss:2.7953
# epoch:576  d_loss:0.1459  g_loss:3.4793
# epoch:577  d_loss:0.3351  g_loss:3.3470
# epoch:578  d_loss:0.2516  g_loss:2.4584
# epoch:579  d_loss:0.2503  g_loss:2.1827
# epoch:580  d_loss:0.2453  g_loss:2.0042
# epoch:581  d_loss:0.4360  g_loss:2.2852
# epoch:582  d_loss:0.1705  g_loss:2.6907
# epoch:583  d_loss:0.1964  g_loss:3.3783
# epoch:584  d_loss:0.2139  g_loss:3.6010
# epoch:585  d_loss:0.3312  g_loss:3.1071
# epoch:586  d_loss:0.2241  g_loss:2.2303
# epoch:587  d_loss:0.2814  g_loss:2.5694
# epoch:588  d_loss:0.2500  g_loss:3.4249
# epoch:589  d_loss:0.2669  g_loss:3.1451
# epoch:590  d_loss:0.2667  g_loss:2.0657
# epoch:591  d_loss:0.2876  g_loss:2.1972
# epoch:592  d_loss:0.2145  g_loss:2.8197
# epoch:593  d_loss:0.1667  g_loss:3.2386
# epoch:594  d_loss:0.2864  g_loss:2.7623
# epoch:595  d_loss:0.3103  g_loss:2.4725
# epoch:596  d_loss:0.2496  g_loss:2.4507
# epoch:597  d_loss:0.1247  g_loss:2.7273
# epoch:598  d_loss:0.1843  g_loss:2.9296
# epoch:599  d_loss:0.1979  g_loss:2.4952
# epoch:600  d_loss:0.2047  g_loss:2.5997
# epoch:601  d_loss:0.2295  g_loss:2.2415
# epoch:602  d_loss:0.1835  g_loss:2.8805
# epoch:603  d_loss:0.0764  g_loss:4.5232
# epoch:604  d_loss:0.1471  g_loss:4.4663
# epoch:605  d_loss:0.2409  g_loss:2.3328
# epoch:606  d_loss:0.2507  g_loss:2.4702
# epoch:607  d_loss:0.1498  g_loss:2.9372
# epoch:608  d_loss:0.0759  g_loss:3.7598
# epoch:609  d_loss:0.0973  g_loss:4.5706
# epoch:610  d_loss:0.0982  g_loss:3.6244
# epoch:611  d_loss:0.1786  g_loss:3.0562
# epoch:612  d_loss:0.0941  g_loss:2.5069
# epoch:613  d_loss:0.2011  g_loss:2.7555
# epoch:614  d_loss:0.2001  g_loss:2.7249
# epoch:615  d_loss:0.1848  g_loss:2.8901
# epoch:616  d_loss:0.1023  g_loss:3.6591
# epoch:617  d_loss:0.1280  g_loss:3.3605
# epoch:618  d_loss:0.1682  g_loss:3.2091
# epoch:619  d_loss:0.2069  g_loss:2.6894
# epoch:620  d_loss:0.1472  g_loss:2.8015
# epoch:621  d_loss:0.1395  g_loss:2.7658
# epoch:622  d_loss:0.0958  g_loss:3.2858
# epoch:623  d_loss:0.1960  g_loss:2.7315
# epoch:624  d_loss:0.2058  g_loss:2.8694
# epoch:625  d_loss:0.1429  g_loss:2.6919
# epoch:626  d_loss:0.2347  g_loss:2.7317
# epoch:627  d_loss:0.1194  g_loss:4.0046
# epoch:628  d_loss:0.2508  g_loss:3.9391
# epoch:629  d_loss:0.3501  g_loss:3.0196
# epoch:630  d_loss:0.2803  g_loss:2.4144
# epoch:631  d_loss:0.1946  g_loss:2.3762
# epoch:632  d_loss:0.3616  g_loss:2.3410
# epoch:633  d_loss:0.2617  g_loss:2.7941
# epoch:634  d_loss:0.2147  g_loss:2.8865
# epoch:635  d_loss:0.1726  g_loss:2.9008
# epoch:636  d_loss:0.3548  g_loss:3.0431
# epoch:637  d_loss:0.2208  g_loss:4.4881
# epoch:638  d_loss:0.2645  g_loss:3.2116
# epoch:639  d_loss:0.3553  g_loss:2.3247
# epoch:640  d_loss:0.3955  g_loss:2.0457
# epoch:641  d_loss:0.2699  g_loss:2.7784
# epoch:642  d_loss:0.2528  g_loss:3.4188
# epoch:643  d_loss:0.2582  g_loss:3.5692
# epoch:644  d_loss:0.2705  g_loss:2.5481
# epoch:645  d_loss:0.3877  g_loss:2.5388
# epoch:646  d_loss:0.1844  g_loss:3.8968
# epoch:647  d_loss:0.3588  g_loss:3.2836
# epoch:648  d_loss:0.3634  g_loss:2.0718
# epoch:649  d_loss:0.3777  g_loss:1.5035
# epoch:650  d_loss:0.1708  g_loss:3.1411
# epoch:651  d_loss:0.1596  g_loss:3.7680
# epoch:652  d_loss:0.2632  g_loss:3.0058
# epoch:653  d_loss:0.1815  g_loss:2.7528
# epoch:654  d_loss:0.3265  g_loss:1.9403
# epoch:655  d_loss:0.2207  g_loss:1.9181
# epoch:656  d_loss:0.1885  g_loss:2.2187
# epoch:657  d_loss:0.3231  g_loss:2.5597
# epoch:658  d_loss:0.2825  g_loss:2.6692
# epoch:659  d_loss:0.3775  g_loss:2.7773
# epoch:660  d_loss:0.3131  g_loss:2.6163
# epoch:661  d_loss:0.2528  g_loss:2.7361
# epoch:662  d_loss:0.3586  g_loss:2.1852
# epoch:663  d_loss:0.5077  g_loss:1.5231
# epoch:664  d_loss:0.2549  g_loss:1.9992
# epoch:665  d_loss:0.2689  g_loss:2.8231
# epoch:666  d_loss:0.2136  g_loss:3.0790
# epoch:667  d_loss:0.4216  g_loss:1.9259
# epoch:668  d_loss:0.4299  g_loss:1.1488
# epoch:669  d_loss:0.2317  g_loss:1.4452
# epoch:670  d_loss:0.3392  g_loss:2.1075
# epoch:671  d_loss:0.2483  g_loss:2.7205
# epoch:672  d_loss:0.5796  g_loss:1.8138
# epoch:673  d_loss:0.4859  g_loss:1.6405
# epoch:674  d_loss:0.5438  g_loss:1.5816
# epoch:675  d_loss:0.6568  g_loss:1.4113
# epoch:676  d_loss:0.5687  g_loss:1.8890
# epoch:677  d_loss:0.4756  g_loss:1.7432
# epoch:678  d_loss:0.9290  g_loss:1.5195
# epoch:679  d_loss:0.9207  g_loss:1.3306
# epoch:680  d_loss:1.0953  g_loss:1.4304
# epoch:681  d_loss:0.9789  g_loss:2.2058
# epoch:682  d_loss:0.6831  g_loss:2.1674
# epoch:683  d_loss:0.6904  g_loss:1.9986
# epoch:684  d_loss:0.8309  g_loss:2.0477
# epoch:685  d_loss:0.9116  g_loss:3.0545
# epoch:686  d_loss:1.5445  g_loss:2.7132
# epoch:687  d_loss:2.5468  g_loss:1.3743
# epoch:688  d_loss:1.3193  g_loss:2.1967
# epoch:689  d_loss:0.2759  g_loss:6.5601
# epoch:690  d_loss:0.2581  g_loss:11.0972
# epoch:691  d_loss:0.3893  g_loss:13.3220
# epoch:692  d_loss:0.7558  g_loss:10.9501
# epoch:693  d_loss:1.4501  g_loss:7.1493
# epoch:694  d_loss:1.2372  g_loss:4.5213
# epoch:695  d_loss:1.9996  g_loss:2.0030
# epoch:696  d_loss:2.3713  g_loss:1.6176
# epoch:697  d_loss:1.5561  g_loss:1.7273
# epoch:698  d_loss:0.8939  g_loss:2.2639
# epoch:699  d_loss:0.8695  g_loss:2.4079
# epoch:700  d_loss:1.0696  g_loss:1.9640
# epoch:701  d_loss:0.9194  g_loss:1.4019
# epoch:702  d_loss:0.6700  g_loss:1.1436
# epoch:703  d_loss:0.3180  g_loss:1.5817
# epoch:704  d_loss:0.2628  g_loss:2.3283
# epoch:705  d_loss:0.1839  g_loss:3.4550
# epoch:706  d_loss:0.1779  g_loss:4.8511
# epoch:707  d_loss:0.2037  g_loss:4.8653
# epoch:708  d_loss:0.1899  g_loss:4.3116
# epoch:709  d_loss:0.2310  g_loss:3.2251
# epoch:710  d_loss:0.3438  g_loss:3.2487
# epoch:711  d_loss:0.1743  g_loss:3.6358
# epoch:712  d_loss:0.3627  g_loss:3.5055
# epoch:713  d_loss:0.3204  g_loss:4.1530
# epoch:714  d_loss:0.5383  g_loss:3.4125
# epoch:715  d_loss:0.8652  g_loss:3.3363
# epoch:716  d_loss:1.2191  g_loss:1.9913
# epoch:717  d_loss:1.0057  g_loss:1.3951
# epoch:718  d_loss:0.8651  g_loss:1.1699
# epoch:719  d_loss:0.6653  g_loss:1.5024
# epoch:720  d_loss:0.4989  g_loss:2.1601
# epoch:721  d_loss:0.5587  g_loss:2.6365
# epoch:722  d_loss:0.3458  g_loss:3.2521
# epoch:723  d_loss:0.4444  g_loss:3.2641
# epoch:724  d_loss:0.3909  g_loss:3.1319
# epoch:725  d_loss:0.2315  g_loss:2.7827
# epoch:726  d_loss:0.3868  g_loss:2.1754
# epoch:727  d_loss:0.3857  g_loss:2.1952
# epoch:728  d_loss:0.4028  g_loss:2.1548
# epoch:729  d_loss:0.2661  g_loss:2.7675
# epoch:730  d_loss:0.4168  g_loss:2.7565
# epoch:731  d_loss:0.4561  g_loss:2.9520
# epoch:732  d_loss:0.5296  g_loss:2.7710
# epoch:733  d_loss:0.4469  g_loss:2.3501
# epoch:734  d_loss:0.4644  g_loss:2.0249
# epoch:735  d_loss:0.3727  g_loss:1.7136
# epoch:736  d_loss:0.3746  g_loss:2.2972
# epoch:737  d_loss:0.3877  g_loss:1.9891
# epoch:738  d_loss:0.3387  g_loss:2.4012
# epoch:739  d_loss:0.4028  g_loss:2.2750
# epoch:740  d_loss:0.3267  g_loss:2.1403
# epoch:741  d_loss:0.6367  g_loss:1.8885
# epoch:742  d_loss:0.4296  g_loss:1.5213
# epoch:743  d_loss:0.4766  g_loss:1.3926
# epoch:744  d_loss:0.6411  g_loss:1.1089
# epoch:745  d_loss:0.8081  g_loss:1.0607
# epoch:746  d_loss:0.5951  g_loss:0.9958
# epoch:747  d_loss:0.4729  g_loss:1.3345
# epoch:748  d_loss:0.4720  g_loss:1.1117
# epoch:749  d_loss:0.4888  g_loss:1.2229
# epoch:750  d_loss:0.5271  g_loss:1.4866
# epoch:751  d_loss:0.4945  g_loss:1.4353
# epoch:752  d_loss:0.3874  g_loss:1.4442
# epoch:753  d_loss:0.3815  g_loss:1.7752
# epoch:754  d_loss:0.4284  g_loss:1.9349
# epoch:755  d_loss:0.3890  g_loss:1.6687
# epoch:756  d_loss:0.3269  g_loss:2.1491
# epoch:757  d_loss:0.2170  g_loss:2.1740
# epoch:758  d_loss:0.2752  g_loss:2.1610
# epoch:759  d_loss:0.2140  g_loss:2.1458
# epoch:760  d_loss:0.2221  g_loss:2.4449
# epoch:761  d_loss:0.2771  g_loss:2.6396
# epoch:762  d_loss:0.1755  g_loss:2.5970
# epoch:763  d_loss:0.2937  g_loss:2.4158
# epoch:764  d_loss:0.2605  g_loss:2.1446
# epoch:765  d_loss:0.3223  g_loss:2.3240
# epoch:766  d_loss:0.2977  g_loss:2.2306
# epoch:767  d_loss:0.3109  g_loss:2.5464
# epoch:768  d_loss:0.2544  g_loss:2.5007
# epoch:769  d_loss:0.3030  g_loss:2.1016
# epoch:770  d_loss:0.2330  g_loss:1.9236
# epoch:771  d_loss:0.3845  g_loss:2.0658
# epoch:772  d_loss:0.3759  g_loss:1.9001
# epoch:773  d_loss:0.4470  g_loss:2.0702
# epoch:774  d_loss:0.4799  g_loss:1.6345
# epoch:775  d_loss:0.3041  g_loss:1.4945
# epoch:776  d_loss:0.3824  g_loss:1.7439
# epoch:777  d_loss:0.3885  g_loss:1.8712
# epoch:778  d_loss:0.6746  g_loss:1.7891
# epoch:779  d_loss:0.5547  g_loss:1.4929
# epoch:780  d_loss:0.4452  g_loss:1.7341
# epoch:781  d_loss:0.3234  g_loss:2.0253
# epoch:782  d_loss:0.4417  g_loss:1.8130
# epoch:783  d_loss:0.4913  g_loss:1.4604
# epoch:784  d_loss:0.4128  g_loss:1.4440
# epoch:785  d_loss:0.3956  g_loss:1.7092
# epoch:786  d_loss:0.3141  g_loss:1.6712
# epoch:787  d_loss:0.3998  g_loss:1.5675
# epoch:788  d_loss:0.4045  g_loss:1.4949
# epoch:789  d_loss:0.3264  g_loss:1.4782
# epoch:790  d_loss:0.4823  g_loss:1.8306
# epoch:791  d_loss:0.3782  g_loss:1.7325
# epoch:792  d_loss:0.3390  g_loss:2.1319
# epoch:793  d_loss:0.4362  g_loss:1.7350
# epoch:794  d_loss:0.3777  g_loss:1.5708
# epoch:795  d_loss:0.4086  g_loss:1.3403
# epoch:796  d_loss:0.4935  g_loss:1.3826
# epoch:797  d_loss:0.4673  g_loss:1.5862
# epoch:798  d_loss:0.4493  g_loss:1.4895
# epoch:799  d_loss:0.5203  g_loss:1.7790
# epoch:800  d_loss:0.4302  g_loss:1.5226
# epoch:801  d_loss:0.4755  g_loss:1.2941
# epoch:802  d_loss:0.6021  g_loss:1.0601
# epoch:803  d_loss:0.4919  g_loss:1.1646
# epoch:804  d_loss:0.5657  g_loss:1.3511
# epoch:805  d_loss:0.4830  g_loss:1.2569
# epoch:806  d_loss:0.5880  g_loss:1.1815
# epoch:807  d_loss:0.5851  g_loss:1.0081
# epoch:808  d_loss:0.5944  g_loss:1.1219
# epoch:809  d_loss:0.6039  g_loss:1.2380
# epoch:810  d_loss:0.6812  g_loss:1.1509
# epoch:811  d_loss:0.6189  g_loss:1.2864
# epoch:812  d_loss:0.5617  g_loss:1.1207
# epoch:813  d_loss:0.7444  g_loss:0.9586
# epoch:814  d_loss:0.6403  g_loss:0.9653
# epoch:815  d_loss:0.5562  g_loss:0.8066
# epoch:816  d_loss:0.6485  g_loss:0.8758
# epoch:817  d_loss:0.5394  g_loss:1.0859
# epoch:818  d_loss:0.6135  g_loss:1.3170
# epoch:819  d_loss:0.4626  g_loss:1.3334
# epoch:820  d_loss:0.5152  g_loss:1.3123
# epoch:821  d_loss:0.3983  g_loss:1.3669
# epoch:822  d_loss:0.5633  g_loss:1.1728
# epoch:823  d_loss:0.4440  g_loss:1.4673
# epoch:824  d_loss:0.3068  g_loss:1.1822
# epoch:825  d_loss:0.3536  g_loss:1.4787
# epoch:826  d_loss:0.5377  g_loss:1.2107
# epoch:827  d_loss:0.4180  g_loss:1.2563
# epoch:828  d_loss:0.3411  g_loss:1.4624
# epoch:829  d_loss:0.5142  g_loss:1.7246
# epoch:830  d_loss:0.4969  g_loss:1.4705
# epoch:831  d_loss:0.5551  g_loss:1.2443
# epoch:832  d_loss:0.5065  g_loss:1.4759
# epoch:833  d_loss:0.7730  g_loss:1.1560
# epoch:834  d_loss:0.7342  g_loss:1.1428
# epoch:835  d_loss:0.7905  g_loss:1.0322
# epoch:836  d_loss:0.6688  g_loss:1.0064
# epoch:837  d_loss:0.7203  g_loss:0.8989
# epoch:838  d_loss:0.7335  g_loss:1.1857
# epoch:839  d_loss:0.6797  g_loss:0.8710
# epoch:840  d_loss:0.6923  g_loss:0.7960
# epoch:841  d_loss:0.4712  g_loss:1.1035
# epoch:842  d_loss:0.4176  g_loss:1.4310
# epoch:843  d_loss:0.4706  g_loss:1.6957
# epoch:844  d_loss:0.4289  g_loss:1.6243
# epoch:845  d_loss:0.3052  g_loss:1.8343
# epoch:846  d_loss:0.3191  g_loss:1.5271
# epoch:847  d_loss:0.3848  g_loss:1.8122
# epoch:848  d_loss:0.3878  g_loss:1.4900
# epoch:849  d_loss:0.2714  g_loss:1.5630
# epoch:850  d_loss:0.3580  g_loss:1.7239
# epoch:851  d_loss:0.4316  g_loss:1.6067
# epoch:852  d_loss:0.4674  g_loss:1.8972
# epoch:853  d_loss:0.5012  g_loss:2.0372
# epoch:854  d_loss:0.5598  g_loss:1.7168
# epoch:855  d_loss:0.7114  g_loss:1.4586
# epoch:856  d_loss:0.6013  g_loss:1.3443
# epoch:857  d_loss:1.0160  g_loss:0.9460
# epoch:858  d_loss:0.7927  g_loss:1.3967
# epoch:859  d_loss:0.9256  g_loss:1.1824
# epoch:860  d_loss:1.4922  g_loss:1.0091
# epoch:861  d_loss:1.1963  g_loss:1.1713
# epoch:862  d_loss:1.0440  g_loss:1.1478
# epoch:863  d_loss:0.9485  g_loss:1.2921
# epoch:864  d_loss:0.7016  g_loss:1.5000
# epoch:865  d_loss:0.4678  g_loss:2.1432
# epoch:866  d_loss:0.3385  g_loss:2.3074
# epoch:867  d_loss:0.2006  g_loss:2.9398
# epoch:868  d_loss:0.1976  g_loss:2.3944
# epoch:869  d_loss:0.3077  g_loss:2.4728
# epoch:870  d_loss:0.3386  g_loss:2.5089
# epoch:871  d_loss:0.2823  g_loss:2.2256
# epoch:872  d_loss:0.3413  g_loss:2.4134
# epoch:873  d_loss:0.3248  g_loss:1.9511
# epoch:874  d_loss:0.6983  g_loss:2.0198
# epoch:875  d_loss:0.4347  g_loss:1.9937
# epoch:876  d_loss:0.2839  g_loss:1.9340
# epoch:877  d_loss:0.3514  g_loss:2.3002
# epoch:878  d_loss:0.3030  g_loss:2.4298
# epoch:879  d_loss:0.2210  g_loss:2.7853
# epoch:880  d_loss:0.1892  g_loss:2.9826
# epoch:881  d_loss:0.2188  g_loss:2.5786
# epoch:882  d_loss:0.1978  g_loss:2.8870
# epoch:883  d_loss:0.2717  g_loss:3.0158
# epoch:884  d_loss:0.2882  g_loss:3.1300
# epoch:885  d_loss:0.3057  g_loss:3.2264
# epoch:886  d_loss:0.2774  g_loss:3.1149
# epoch:887  d_loss:0.5212  g_loss:2.9449
# epoch:888  d_loss:0.5632  g_loss:2.5294
# epoch:889  d_loss:0.4510  g_loss:2.0439
# epoch:890  d_loss:0.7078  g_loss:1.9991
# epoch:891  d_loss:0.5904  g_loss:1.7822
# epoch:892  d_loss:0.8895  g_loss:1.6243
# epoch:893  d_loss:0.6706  g_loss:1.5557
# epoch:894  d_loss:0.6535  g_loss:1.9381
# epoch:895  d_loss:0.6597  g_loss:1.7375
# epoch:896  d_loss:0.5313  g_loss:1.9011
# epoch:897  d_loss:0.7116  g_loss:1.7527
# epoch:898  d_loss:0.6308  g_loss:2.0343
# epoch:899  d_loss:0.4612  g_loss:2.5667
# epoch:900  d_loss:0.5998  g_loss:1.9470
# epoch:901  d_loss:0.4695  g_loss:1.9959
# epoch:902  d_loss:0.3515  g_loss:2.3924
# epoch:903  d_loss:0.4695  g_loss:2.4606
# epoch:904  d_loss:0.5086  g_loss:1.6446
# epoch:905  d_loss:0.3074  g_loss:1.7938
# epoch:906  d_loss:0.3744  g_loss:2.2224
# epoch:907  d_loss:0.5073  g_loss:1.9791
# epoch:908  d_loss:0.2498  g_loss:2.0425
# epoch:909  d_loss:0.4205  g_loss:2.0921
# epoch:910  d_loss:0.3864  g_loss:2.3292
# epoch:911  d_loss:0.4434  g_loss:2.4664
# epoch:912  d_loss:0.4002  g_loss:2.2885
# epoch:913  d_loss:0.5251  g_loss:2.2475
# epoch:914  d_loss:0.3100  g_loss:2.0502
# epoch:915  d_loss:0.4760  g_loss:1.6895
# epoch:916  d_loss:0.3814  g_loss:1.6343
# epoch:917  d_loss:0.4045  g_loss:1.6977
# epoch:918  d_loss:0.5496  g_loss:1.7465
# epoch:919  d_loss:0.5612  g_loss:1.7719
# epoch:920  d_loss:0.6577  g_loss:1.7158
# epoch:921  d_loss:0.3997  g_loss:1.8078
# epoch:922  d_loss:0.3558  g_loss:1.5684
# epoch:923  d_loss:0.4538  g_loss:1.6353
# epoch:924  d_loss:0.4230  g_loss:1.6882
# epoch:925  d_loss:0.4706  g_loss:1.6868
# epoch:926  d_loss:0.3766  g_loss:1.7785
# epoch:927  d_loss:0.4866  g_loss:1.8443
# epoch:928  d_loss:0.3763  g_loss:1.6118
# epoch:929  d_loss:0.5570  g_loss:1.4595
# epoch:930  d_loss:0.4520  g_loss:1.5940
# epoch:931  d_loss:0.3310  g_loss:2.2681
# epoch:932  d_loss:0.4005  g_loss:2.1012
# epoch:933  d_loss:0.4165  g_loss:1.9515
# epoch:934  d_loss:0.4370  g_loss:2.0196
# epoch:935  d_loss:0.4584  g_loss:1.5897
# epoch:936  d_loss:0.4272  g_loss:1.6770
# epoch:937  d_loss:0.4453  g_loss:1.5940
# epoch:938  d_loss:0.3349  g_loss:1.9171
# epoch:939  d_loss:0.3992  g_loss:1.7714
# epoch:940  d_loss:0.3839  g_loss:1.8975
# epoch:941  d_loss:0.4563  g_loss:1.8656
# epoch:942  d_loss:0.4054  g_loss:2.2082
# epoch:943  d_loss:0.5004  g_loss:1.7659
# epoch:944  d_loss:0.4441  g_loss:1.5014
# epoch:945  d_loss:0.4137  g_loss:1.7322
# epoch:946  d_loss:0.3887  g_loss:1.6273
# epoch:947  d_loss:0.5204  g_loss:1.9111
# epoch:948  d_loss:0.3651  g_loss:2.5087
# epoch:949  d_loss:0.4705  g_loss:2.2302
# epoch:950  d_loss:0.3238  g_loss:2.2002
# epoch:951  d_loss:0.3353  g_loss:2.0266
# epoch:952  d_loss:0.4953  g_loss:1.4330
# epoch:953  d_loss:0.3259  g_loss:1.9458
# epoch:954  d_loss:0.3016  g_loss:1.8638
# epoch:955  d_loss:0.2946  g_loss:1.8544
# epoch:956  d_loss:0.2956  g_loss:1.9173
# epoch:957  d_loss:0.2809  g_loss:2.1180
# epoch:958  d_loss:0.2678  g_loss:2.1800
# epoch:959  d_loss:0.4421  g_loss:1.8140
# epoch:960  d_loss:0.3742  g_loss:2.4758
# epoch:961  d_loss:0.2826  g_loss:1.9425
# epoch:962  d_loss:0.1956  g_loss:2.1642
# epoch:963  d_loss:0.3564  g_loss:1.9668
# epoch:964  d_loss:0.2844  g_loss:1.7355
# epoch:965  d_loss:0.2631  g_loss:1.9271
# epoch:966  d_loss:0.2545  g_loss:2.0087
# epoch:967  d_loss:0.2263  g_loss:2.6237
# epoch:968  d_loss:0.3484  g_loss:2.3136
# epoch:969  d_loss:0.3429  g_loss:2.6037
# epoch:970  d_loss:0.3237  g_loss:2.3629
# epoch:971  d_loss:0.3238  g_loss:2.3983
# epoch:972  d_loss:0.3302  g_loss:1.9149
# epoch:973  d_loss:0.3376  g_loss:1.9826
# epoch:974  d_loss:0.2548  g_loss:2.0567
# epoch:975  d_loss:0.3124  g_loss:1.9053
# epoch:976  d_loss:0.3728  g_loss:2.1940
# epoch:977  d_loss:0.4350  g_loss:2.0214
# epoch:978  d_loss:0.3327  g_loss:1.9617
# epoch:979  d_loss:0.4518  g_loss:2.0193
# epoch:980  d_loss:0.2681  g_loss:1.9434
# epoch:981  d_loss:0.4321  g_loss:2.3975
# epoch:982  d_loss:0.3421  g_loss:1.8095
# epoch:983  d_loss:0.4884  g_loss:1.8266
# epoch:984  d_loss:0.3491  g_loss:2.1765
# epoch:985  d_loss:0.4306  g_loss:1.7275
# epoch:986  d_loss:0.4432  g_loss:1.7945
# epoch:987  d_loss:0.3854  g_loss:1.6853
# epoch:988  d_loss:0.5102  g_loss:1.4044
# epoch:989  d_loss:0.4639  g_loss:1.8997
# epoch:990  d_loss:0.4357  g_loss:1.8950
# epoch:991  d_loss:0.4844  g_loss:2.0064
# epoch:992  d_loss:0.4292  g_loss:1.9113
# epoch:993  d_loss:0.4873  g_loss:1.6267
# epoch:994  d_loss:0.5157  g_loss:1.8390
# epoch:995  d_loss:0.5726  g_loss:1.3752
# epoch:996  d_loss:0.5272  g_loss:1.3940
# epoch:997  d_loss:0.6670  g_loss:1.6308
# epoch:998  d_loss:0.4292  g_loss:2.1904
# epoch:999  d_loss:0.6925  g_loss:2.1676
# epoch:1000  d_loss:0.6427  g_loss:1.8349
# epoch:1001  d_loss:0.4130  g_loss:1.3687
# epoch:1002  d_loss:0.4480  g_loss:1.5729
# epoch:1003  d_loss:0.4050  g_loss:1.9026
# epoch:1004  d_loss:0.4907  g_loss:1.9701
# epoch:1005  d_loss:0.5475  g_loss:1.8124
# epoch:1006  d_loss:0.4443  g_loss:1.8827
# epoch:1007  d_loss:0.4922  g_loss:1.7428
# epoch:1008  d_loss:0.4841  g_loss:1.9089
# epoch:1009  d_loss:0.4756  g_loss:1.9008
# epoch:1010  d_loss:0.5580  g_loss:1.6809
# epoch:1011  d_loss:0.4242  g_loss:2.1765
# epoch:1012  d_loss:0.5488  g_loss:1.9552
# epoch:1013  d_loss:0.3931  g_loss:2.0907
# epoch:1014  d_loss:0.3742  g_loss:1.7666
# epoch:1015  d_loss:0.5195  g_loss:1.8513
# epoch:1016  d_loss:0.4601  g_loss:2.1961
# epoch:1017  d_loss:0.3475  g_loss:2.2428
# epoch:1018  d_loss:0.4162  g_loss:2.1986
# epoch:1019  d_loss:0.2333  g_loss:2.4648
# epoch:1020  d_loss:0.2412  g_loss:2.5235
# epoch:1021  d_loss:0.3215  g_loss:2.3983
# epoch:1022  d_loss:0.3015  g_loss:2.0666
# epoch:1023  d_loss:0.3422  g_loss:2.2103
# epoch:1024  d_loss:0.3476  g_loss:2.0213
# epoch:1025  d_loss:0.3875  g_loss:1.8705
# epoch:1026  d_loss:0.2462  g_loss:2.5562
# epoch:1027  d_loss:0.3826  g_loss:2.2754
# epoch:1028  d_loss:0.3721  g_loss:2.6554
# epoch:1029  d_loss:0.3000  g_loss:2.1542
# epoch:1030  d_loss:0.3808  g_loss:1.6936
# epoch:1031  d_loss:0.3714  g_loss:1.6304
# epoch:1032  d_loss:0.3552  g_loss:1.8243
# epoch:1033  d_loss:0.3199  g_loss:2.0637
# epoch:1034  d_loss:0.3438  g_loss:2.0044
# epoch:1035  d_loss:0.4283  g_loss:1.8583
# epoch:1036  d_loss:0.4147  g_loss:1.7458
# epoch:1037  d_loss:0.3998  g_loss:1.6389
# epoch:1038  d_loss:0.5033  g_loss:1.6623
# epoch:1039  d_loss:0.4745  g_loss:1.6375
# epoch:1040  d_loss:0.5895  g_loss:1.8635
# epoch:1041  d_loss:0.4945  g_loss:1.6838
# epoch:1042  d_loss:0.4120  g_loss:1.6433
# epoch:1043  d_loss:0.5124  g_loss:1.4987
# epoch:1044  d_loss:0.4976  g_loss:2.0193
# epoch:1045  d_loss:0.3695  g_loss:1.9091
# epoch:1046  d_loss:0.4808  g_loss:1.7375
# epoch:1047  d_loss:0.3161  g_loss:2.1337
# epoch:1048  d_loss:0.4357  g_loss:1.9394
# epoch:1049  d_loss:0.3207  g_loss:2.1514
# epoch:1050  d_loss:0.3682  g_loss:2.2059
# epoch:1051  d_loss:0.2116  g_loss:2.6070
# epoch:1052  d_loss:0.3672  g_loss:1.9993
# epoch:1053  d_loss:0.3841  g_loss:2.2214
# epoch:1054  d_loss:0.3604  g_loss:2.2663
# epoch:1055  d_loss:0.2569  g_loss:2.1746
# epoch:1056  d_loss:0.5528  g_loss:2.1504
# epoch:1057  d_loss:0.4506  g_loss:2.1887
# epoch:1058  d_loss:0.3010  g_loss:2.1141
# epoch:1059  d_loss:0.3278  g_loss:1.9682
# epoch:1060  d_loss:0.3168  g_loss:1.8285
# epoch:1061  d_loss:0.3134  g_loss:2.6264
# epoch:1062  d_loss:0.2510  g_loss:2.7040
# epoch:1063  d_loss:0.4193  g_loss:2.0348
# epoch:1064  d_loss:0.6008  g_loss:1.8827
# epoch:1065  d_loss:0.5334  g_loss:1.7628
# epoch:1066  d_loss:0.3281  g_loss:2.0671
# epoch:1067  d_loss:0.6557  g_loss:2.0413
# epoch:1068  d_loss:0.4429  g_loss:2.0086
# epoch:1069  d_loss:0.5204  g_loss:1.5665
# epoch:1070  d_loss:0.5236  g_loss:1.5392
# epoch:1071  d_loss:0.5251  g_loss:1.6497
# epoch:1072  d_loss:0.5985  g_loss:1.3074
# epoch:1073  d_loss:0.4849  g_loss:2.0285
# epoch:1074  d_loss:0.5977  g_loss:2.0922
# epoch:1075  d_loss:0.7256  g_loss:1.2720
# epoch:1076  d_loss:0.5784  g_loss:1.7768
# epoch:1077  d_loss:0.5286  g_loss:1.3097
# epoch:1078  d_loss:0.5837  g_loss:1.6989
# epoch:1079  d_loss:0.5418  g_loss:2.2596
# epoch:1080  d_loss:0.6600  g_loss:1.6736
# epoch:1081  d_loss:0.5005  g_loss:1.6215
# epoch:1082  d_loss:0.4272  g_loss:1.6706
# epoch:1083  d_loss:0.3488  g_loss:1.8918
# epoch:1084  d_loss:0.3969  g_loss:2.1768
# epoch:1085  d_loss:0.3964  g_loss:2.0125
# epoch:1086  d_loss:0.3805  g_loss:1.9306
# epoch:1087  d_loss:0.3944  g_loss:1.7815
# epoch:1088  d_loss:0.3741  g_loss:1.7522
# epoch:1089  d_loss:0.3358  g_loss:1.7820
# epoch:1090  d_loss:0.4279  g_loss:2.4625
# epoch:1091  d_loss:0.2859  g_loss:2.4275
# epoch:1092  d_loss:0.2752  g_loss:2.4742
# epoch:1093  d_loss:0.4793  g_loss:2.1669
# epoch:1094  d_loss:0.3141  g_loss:2.3849
# epoch:1095  d_loss:0.3663  g_loss:2.0717
# epoch:1096  d_loss:0.3167  g_loss:1.9175
# epoch:1097  d_loss:0.3159  g_loss:1.8758
# epoch:1098  d_loss:0.2293  g_loss:2.6792
# epoch:1099  d_loss:0.4257  g_loss:2.3837
# epoch:1100  d_loss:0.3566  g_loss:2.3142
# epoch:1101  d_loss:0.3232  g_loss:2.3438
# epoch:1102  d_loss:0.2639  g_loss:2.2755
# epoch:1103  d_loss:0.2915  g_loss:2.1525
# epoch:1104  d_loss:0.3169  g_loss:1.9887
# epoch:1105  d_loss:0.4282  g_loss:1.9760
# epoch:1106  d_loss:0.3728  g_loss:1.8835
# epoch:1107  d_loss:0.2666  g_loss:2.3647
# epoch:1108  d_loss:0.3858  g_loss:2.5873
# epoch:1109  d_loss:0.5111  g_loss:2.0923
# ...
# epoch:1611  d_loss:0.4724  g_loss:1.6106
# epoch:1612  d_loss:0.3890  g_loss:1.6663
# epoch:1613  d_loss:0.4580  g_loss:1.5360
# epoch:1614  d_loss:0.4400  g_loss:1.5331
# epoch:1615  d_loss:0.5145  g_loss:1.3699
# epoch:1616  d_loss:0.4234  g_loss:1.5965
# epoch:1617  d_loss:0.4158  g_loss:1.5867
# epoch:1618  d_loss:0.5300  g_loss:1.8455
# epoch:1619  d_loss:0.4382  g_loss:1.6262
# epoch:1620  d_loss:0.5358  g_loss:1.1601
# epoch:1621  d_loss:0.5310  g_loss:1.5818
# epoch:1622  d_loss:0.5858  g_loss:1.4873
# epoch:1623  d_loss:0.5237  g_loss:1.5292
# epoch:1624  d_loss:0.4669  g_loss:1.9691
# epoch:1625  d_loss:0.5205  g_loss:1.6055
# epoch:1626  d_loss:0.3657  g_loss:1.3370
# epoch:1627  d_loss:0.6137  g_loss:1.0014
# epoch:1628  d_loss:0.6078  g_loss:1.3477
# epoch:1629  d_loss:0.5351  g_loss:1.4414
# epoch:1630  d_loss:0.4403  g_loss:1.5694
# epoch:1631  d_loss:0.4638  g_loss:1.6597
# epoch:1632  d_loss:0.4298  g_loss:1.7926
# epoch:1633  d_loss:0.7157  g_loss:1.5555
# epoch:1634  d_loss:0.5528  g_loss:1.1976
# epoch:1635  d_loss:0.4862  g_loss:1.5415
# epoch:1636  d_loss:0.4717  g_loss:1.5359
# epoch:1637  d_loss:0.4795  g_loss:1.5161
# epoch:1638  d_loss:0.4624  g_loss:1.6842
# epoch:1639  d_loss:0.5215  g_loss:1.5186
# epoch:1640  d_loss:0.4371  g_loss:1.6392
# epoch:1641  d_loss:0.3855  g_loss:1.6140
# epoch:1642  d_loss:0.3997  g_loss:1.8039
# epoch:1643  d_loss:0.5137  g_loss:1.6356
# epoch:1644  d_loss:0.5744  g_loss:1.5728
# epoch:1645  d_loss:0.4358  g_loss:1.5044
# epoch:1646  d_loss:0.3553  g_loss:1.7114
# epoch:1647  d_loss:0.3967  g_loss:1.8427
# epoch:1648  d_loss:0.3922  g_loss:1.6596
# epoch:1649  d_loss:0.4781  g_loss:1.7573
# epoch:1650  d_loss:0.4920  g_loss:1.7803
# epoch:1651  d_loss:0.4881  g_loss:1.4876
# epoch:1652  d_loss:0.4223  g_loss:1.3619
# epoch:1653  d_loss:0.4802  g_loss:1.6448
# epoch:1654  d_loss:0.5535  g_loss:1.6617
# epoch:1655  d_loss:0.4746  g_loss:1.7707
# epoch:1656  d_loss:0.4097  g_loss:1.5205
# epoch:1657  d_loss:0.5490  g_loss:1.5235
# epoch:1658  d_loss:0.4962  g_loss:1.6873
# epoch:1659  d_loss:0.4985  g_loss:1.6098
# epoch:1660  d_loss:0.3796  g_loss:1.7160
# epoch:1661  d_loss:0.4321  g_loss:1.7822
# epoch:1662  d_loss:0.5363  g_loss:1.8349
# epoch:1663  d_loss:0.5165  g_loss:1.4477
# epoch:1664  d_loss:0.5051  g_loss:1.2203
# epoch:1665  d_loss:0.4475  g_loss:1.4723
# epoch:1666  d_loss:0.5241  g_loss:1.3274
# epoch:1667  d_loss:0.5759  g_loss:1.4714
# epoch:1668  d_loss:0.5213  g_loss:1.4386
# epoch:1669  d_loss:0.4874  g_loss:1.7317
# epoch:1670  d_loss:0.5157  g_loss:1.7838
# epoch:1671  d_loss:0.5555  g_loss:1.4925
# epoch:1672  d_loss:0.5526  g_loss:1.5666
# epoch:1673  d_loss:0.6452  g_loss:1.2963
# epoch:1674  d_loss:0.5198  g_loss:1.4459
# epoch:1675  d_loss:0.6406  g_loss:1.2533
# epoch:1676  d_loss:0.5337  g_loss:1.2912
# epoch:1677  d_loss:0.5362  g_loss:1.1479
# epoch:1678  d_loss:0.5014  g_loss:1.4361
# epoch:1679  d_loss:0.4392  g_loss:1.7288
# epoch:1680  d_loss:0.4540  g_loss:1.3858
# epoch:1681  d_loss:0.5082  g_loss:1.4436
# epoch:1682  d_loss:0.4047  g_loss:1.6459
# epoch:1683  d_loss:0.5229  g_loss:1.2936
# epoch:1684  d_loss:0.4767  g_loss:1.6357
# epoch:1685  d_loss:0.4524  g_loss:1.5244
# epoch:1686  d_loss:0.4484  g_loss:1.5205
# epoch:1687  d_loss:0.4697  g_loss:1.4378
# epoch:1688  d_loss:0.4342  g_loss:1.6005
# epoch:1689  d_loss:0.3808  g_loss:1.6921
# epoch:1690  d_loss:0.3926  g_loss:1.8213
# epoch:1691  d_loss:0.4346  g_loss:1.7269
# epoch:1692  d_loss:0.4633  g_loss:1.4582
# epoch:1693  d_loss:0.3696  g_loss:1.5590
# epoch:1694  d_loss:0.4462  g_loss:1.4429
# epoch:1695  d_loss:0.3382  g_loss:1.6740
# epoch:1696  d_loss:0.4008  g_loss:2.1292
# epoch:1697  d_loss:0.3714  g_loss:1.8722
# epoch:1698  d_loss:0.4572  g_loss:1.6171
# epoch:1699  d_loss:0.3957  g_loss:1.5771
# epoch:1700  d_loss:0.5741  g_loss:1.4486
# epoch:1701  d_loss:0.5061  g_loss:1.7072
# epoch:1702  d_loss:0.5312  g_loss:1.6152
# epoch:1703  d_loss:0.4468  g_loss:1.9567
# epoch:1704  d_loss:0.4881  g_loss:1.6085
# epoch:1705  d_loss:0.4719  g_loss:1.6455
# epoch:1706  d_loss:0.4606  g_loss:1.6982
# epoch:1707  d_loss:0.3840  g_loss:1.4022
# epoch:1708  d_loss:0.3845  g_loss:1.5827
# epoch:1709  d_loss:0.4835  g_loss:1.4782
# epoch:1710  d_loss:0.3687  g_loss:1.8623
# epoch:1711  d_loss:0.4224  g_loss:2.0597
# epoch:1712  d_loss:0.6713  g_loss:1.9319
# epoch:1713  d_loss:0.4896  g_loss:1.5668
# epoch:1714  d_loss:0.5079  g_loss:1.4763
# epoch:1715  d_loss:0.4595  g_loss:1.5311
# epoch:1716  d_loss:0.4408  g_loss:1.5540
# epoch:1717  d_loss:0.4479  g_loss:1.9422
# epoch:1718  d_loss:0.4468  g_loss:1.7636
# epoch:1719  d_loss:0.4341  g_loss:1.8067
# epoch:1720  d_loss:0.4396  g_loss:1.5845
# epoch:1721  d_loss:0.5191  g_loss:1.6685
# epoch:1722  d_loss:0.4333  g_loss:1.3268
# epoch:1723  d_loss:0.5257  g_loss:1.6299
# epoch:1724  d_loss:0.4582  g_loss:1.6190
# epoch:1725  d_loss:0.5120  g_loss:1.7504
# epoch:1726  d_loss:0.4719  g_loss:1.9913
# epoch:1727  d_loss:0.4434  g_loss:2.0519
# epoch:1728  d_loss:0.3803  g_loss:2.0032
# epoch:1729  d_loss:0.5007  g_loss:1.6050
# epoch:1730  d_loss:0.4399  g_loss:1.4077
# epoch:1731  d_loss:0.4859  g_loss:1.4203
# epoch:1732  d_loss:0.5064  g_loss:1.4519
# epoch:1733  d_loss:0.5698  g_loss:1.4685
# epoch:1734  d_loss:0.5393  g_loss:1.3385
# epoch:1735  d_loss:0.4821  g_loss:1.6435
# epoch:1736  d_loss:0.4535  g_loss:1.7400
# epoch:1737  d_loss:0.5063  g_loss:1.4015
# epoch:1738  d_loss:0.4553  g_loss:1.6286
# epoch:1739  d_loss:0.4203  g_loss:1.3812
# epoch:1740  d_loss:0.5674  g_loss:1.3156
# epoch:1741  d_loss:0.4305  g_loss:1.4375
# epoch:1742  d_loss:0.4013  g_loss:1.7114
# epoch:1743  d_loss:0.4021  g_loss:1.4995
# epoch:1744  d_loss:0.5117  g_loss:1.4558
# epoch:1745  d_loss:0.5823  g_loss:1.5522
# epoch:1746  d_loss:0.3687  g_loss:1.1344
# epoch:1747  d_loss:0.4187  g_loss:1.4800
# epoch:1748  d_loss:0.5160  g_loss:1.5636
# epoch:1749  d_loss:0.4829  g_loss:1.5429
# epoch:1750  d_loss:0.5073  g_loss:1.8739
# epoch:1751  d_loss:0.4535  g_loss:1.5583
# epoch:1752  d_loss:0.4534  g_loss:1.7043
# epoch:1753  d_loss:0.5975  g_loss:1.6567
# epoch:1754  d_loss:0.5371  g_loss:1.4065
# epoch:1755  d_loss:0.4326  g_loss:1.8023
# epoch:1756  d_loss:0.4436  g_loss:1.7920
# epoch:1757  d_loss:0.3250  g_loss:2.0427
# epoch:1758  d_loss:0.5177  g_loss:1.6890
# epoch:1759  d_loss:0.4580  g_loss:1.8984
# epoch:1760  d_loss:0.5140  g_loss:1.5729
# epoch:1761  d_loss:0.4275  g_loss:1.5587
# epoch:1762  d_loss:0.4964  g_loss:1.4419
# epoch:1763  d_loss:0.3905  g_loss:2.1715
# epoch:1764  d_loss:0.4978  g_loss:1.6133
# epoch:1765  d_loss:0.4450  g_loss:1.7622
# epoch:1766  d_loss:0.4661  g_loss:2.0160
# epoch:1767  d_loss:0.4085  g_loss:1.5639
# epoch:1768  d_loss:0.5237  g_loss:1.7067
# epoch:1769  d_loss:0.4986  g_loss:1.4379
# epoch:1770  d_loss:0.5329  g_loss:1.5190
# epoch:1771  d_loss:0.4991  g_loss:1.3242
# epoch:1772  d_loss:0.4491  g_loss:1.4158
# epoch:1773  d_loss:0.5173  g_loss:1.3677
# epoch:1774  d_loss:0.4667  g_loss:1.6629
# epoch:1775  d_loss:0.5450  g_loss:1.7091
# epoch:1776  d_loss:0.4400  g_loss:1.8989
# epoch:1777  d_loss:0.6078  g_loss:1.4885
# epoch:1778  d_loss:0.4777  g_loss:1.4029
# epoch:1779  d_loss:0.5008  g_loss:1.4126
# epoch:1780  d_loss:0.4556  g_loss:1.4829
# epoch:1781  d_loss:0.5690  g_loss:1.3699
# epoch:1782  d_loss:0.4827  g_loss:1.4094
# epoch:1783  d_loss:0.5471  g_loss:1.4891
# epoch:1784  d_loss:0.5004  g_loss:1.5245
# epoch:1785  d_loss:0.4136  g_loss:1.9594
# epoch:1786  d_loss:0.4935  g_loss:2.1161
# epoch:1787  d_loss:0.5551  g_loss:2.0561
# epoch:1788  d_loss:0.5417  g_loss:1.5921
# epoch:1789  d_loss:0.5761  g_loss:1.4477
# epoch:1790  d_loss:0.5693  g_loss:1.1771
# epoch:1791  d_loss:0.3785  g_loss:1.6157
# epoch:1792  d_loss:0.5408  g_loss:1.6751
# epoch:1793  d_loss:0.3881  g_loss:1.8071
# epoch:1794  d_loss:0.4374  g_loss:1.8199
# epoch:1795  d_loss:0.4811  g_loss:1.8162
# epoch:1796  d_loss:0.5042  g_loss:1.6964
# epoch:1797  d_loss:0.4168  g_loss:1.5612
# epoch:1798  d_loss:0.5261  g_loss:1.6165
# epoch:1799  d_loss:0.4364  g_loss:1.3901
# epoch:1800  d_loss:0.4608  g_loss:2.0642
# epoch:1801  d_loss:0.4064  g_loss:2.2367
# epoch:1802  d_loss:0.5331  g_loss:1.7854
# epoch:1803  d_loss:0.5184  g_loss:1.8975
# epoch:1804  d_loss:0.5332  g_loss:1.5904
# epoch:1805  d_loss:0.4479  g_loss:1.4659
# epoch:1806  d_loss:0.5712  g_loss:1.2695
# epoch:1807  d_loss:0.4842  g_loss:1.5765
# epoch:1808  d_loss:0.5299  g_loss:1.8980
# epoch:1809  d_loss:0.5022  g_loss:1.7994
# epoch:1810  d_loss:0.4885  g_loss:1.5757
# epoch:1811  d_loss:0.5502  g_loss:1.7085
# epoch:1812  d_loss:0.6410  g_loss:1.1605
# epoch:1813  d_loss:0.4126  g_loss:1.5357
# epoch:1814  d_loss:0.3911  g_loss:1.9614
# epoch:1815  d_loss:0.5443  g_loss:1.4409
# epoch:1816  d_loss:0.4064  g_loss:1.6911
# epoch:1817  d_loss:0.5740  g_loss:1.7144
# epoch:1818  d_loss:0.4724  g_loss:1.5057
# epoch:1819  d_loss:0.4212  g_loss:1.5933
# epoch:1820  d_loss:0.4883  g_loss:1.6464
# epoch:1821  d_loss:0.3424  g_loss:1.6824
# epoch:1822  d_loss:0.4713  g_loss:1.6213
# epoch:1823  d_loss:0.4461  g_loss:1.6916
# epoch:1824  d_loss:0.5107  g_loss:1.5633
# epoch:1825  d_loss:0.3518  g_loss:1.7952
# epoch:1826  d_loss:0.4416  g_loss:1.9562
# epoch:1827  d_loss:0.3579  g_loss:1.9688
# epoch:1828  d_loss:0.3709  g_loss:2.0523
# epoch:1829  d_loss:0.5065  g_loss:1.6108
# epoch:1830  d_loss:0.4094  g_loss:1.6303
# epoch:1831  d_loss:0.4166  g_loss:1.6908
# epoch:1832  d_loss:0.5258  g_loss:1.5819
# epoch:1833  d_loss:0.4100  g_loss:1.8361
# epoch:1834  d_loss:0.3467  g_loss:2.0668
# epoch:1835  d_loss:0.3847  g_loss:1.4588
# epoch:1836  d_loss:0.5088  g_loss:1.7935
# epoch:1837  d_loss:0.5787  g_loss:1.4720
# epoch:1838  d_loss:0.5411  g_loss:1.9415
# epoch:1839  d_loss:0.5689  g_loss:1.4928
# epoch:1840  d_loss:0.4752  g_loss:1.4236
# epoch:1841  d_loss:0.5381  g_loss:1.3282
# epoch:1842  d_loss:0.4831  g_loss:1.4610
# epoch:1843  d_loss:0.4613  g_loss:1.6319
# epoch:1844  d_loss:0.4406  g_loss:1.5111
# epoch:1845  d_loss:0.6746  g_loss:1.6821
# epoch:1846  d_loss:0.7161  g_loss:1.3319
# epoch:1847  d_loss:0.6197  g_loss:1.1595
# epoch:1848  d_loss:0.5885  g_loss:1.3663
# epoch:1849  d_loss:0.4591  g_loss:1.4391
# epoch:1850  d_loss:0.5286  g_loss:1.5451
# epoch:1851  d_loss:0.4686  g_loss:1.6239
# epoch:1852  d_loss:0.4563  g_loss:1.9025
# epoch:1853  d_loss:0.5395  g_loss:1.2624
# epoch:1854  d_loss:0.4381  g_loss:1.3570
# epoch:1855  d_loss:0.5408  g_loss:1.2868
# epoch:1856  d_loss:0.5331  g_loss:1.3122
# epoch:1857  d_loss:0.4173  g_loss:1.5691
# epoch:1858  d_loss:0.4676  g_loss:1.5916
# epoch:1859  d_loss:0.4332  g_loss:1.3627
# epoch:1860  d_loss:0.5377  g_loss:1.4482
# epoch:1861  d_loss:0.5631  g_loss:1.5922
# epoch:1862  d_loss:0.5248  g_loss:1.7643
# epoch:1863  d_loss:0.5177  g_loss:1.5501
# epoch:1864  d_loss:0.3118  g_loss:1.6699
# epoch:1865  d_loss:0.3492  g_loss:2.0142
# epoch:1866  d_loss:0.4987  g_loss:1.9746
# epoch:1867  d_loss:0.4777  g_loss:2.1162
# epoch:1868  d_loss:0.4984  g_loss:1.7136
# epoch:1869  d_loss:0.5919  g_loss:1.5907
# epoch:1870  d_loss:0.4476  g_loss:1.7165
# epoch:1871  d_loss:0.4258  g_loss:1.4827
# epoch:1872  d_loss:0.3044  g_loss:1.9339
# epoch:1873  d_loss:0.4655  g_loss:1.7978
# epoch:1874  d_loss:0.4350  g_loss:1.6920
# epoch:1875  d_loss:0.4258  g_loss:1.7946
# epoch:1876  d_loss:0.5376  g_loss:1.3901
# epoch:1877  d_loss:0.4311  g_loss:2.0225
# epoch:1878  d_loss:0.4363  g_loss:1.4624
# epoch:1879  d_loss:0.4935  g_loss:1.5433
# epoch:1880  d_loss:0.4429  g_loss:1.5460
# epoch:1881  d_loss:0.5913  g_loss:1.3748
# epoch:1882  d_loss:0.6242  g_loss:1.6975
# epoch:1883  d_loss:0.5362  g_loss:1.6255
# epoch:1884  d_loss:0.4880  g_loss:1.8172
# epoch:1885  d_loss:0.4794  g_loss:1.6783
# epoch:1886  d_loss:0.5924  g_loss:1.4672
# epoch:1887  d_loss:0.5154  g_loss:1.4992
# epoch:1888  d_loss:0.5390  g_loss:1.4805
# epoch:1889  d_loss:0.5261  g_loss:1.2705
# epoch:1890  d_loss:0.5189  g_loss:1.5527
# epoch:1891  d_loss:0.5175  g_loss:1.3630
# epoch:1892  d_loss:0.5650  g_loss:1.3637
# epoch:1893  d_loss:0.5212  g_loss:1.5286
# epoch:1894  d_loss:0.5537  g_loss:1.6023
# epoch:1895  d_loss:0.5369  g_loss:1.5105
# epoch:1896  d_loss:0.5308  g_loss:1.5029
# epoch:1897  d_loss:0.4908  g_loss:1.6547
# epoch:1898  d_loss:0.6525  g_loss:1.4463
# epoch:1899  d_loss:0.4960  g_loss:1.5256
# epoch:1900  d_loss:0.5485  g_loss:1.0994
# epoch:1901  d_loss:0.5838  g_loss:1.6082
# epoch:1902  d_loss:0.4689  g_loss:1.6493
# epoch:1903  d_loss:0.4914  g_loss:1.7249
# epoch:1904  d_loss:0.4322  g_loss:1.4710
# epoch:1905  d_loss:0.3655  g_loss:1.5057
# epoch:1906  d_loss:0.3786  g_loss:1.8150
# epoch:1907  d_loss:0.4382  g_loss:1.6786
# epoch:1908  d_loss:0.5622  g_loss:1.3517
# epoch:1909  d_loss:0.4504  g_loss:1.5885
# epoch:1910  d_loss:0.4734  g_loss:1.3219
# epoch:1911  d_loss:0.4864  g_loss:1.4612
# epoch:1912  d_loss:0.5727  g_loss:1.5038
# epoch:1913  d_loss:0.5057  g_loss:1.6332
# epoch:1914  d_loss:0.4992  g_loss:1.4966
# epoch:1915  d_loss:0.3948  g_loss:1.6395
# epoch:1916  d_loss:0.4375  g_loss:1.7363
# epoch:1917  d_loss:0.4968  g_loss:1.6789
# epoch:1918  d_loss:0.5112  g_loss:1.2772
# epoch:1919  d_loss:0.4258  g_loss:1.5528
# epoch:1920  d_loss:0.5586  g_loss:1.3191
# epoch:1921  d_loss:0.5062  g_loss:1.5672
# epoch:1922  d_loss:0.5664  g_loss:1.3286
# epoch:1923  d_loss:0.4854  g_loss:1.5039
# epoch:1924  d_loss:0.4687  g_loss:1.5077
# epoch:1925  d_loss:0.4962  g_loss:1.5828
# epoch:1926  d_loss:0.4466  g_loss:1.7838
# epoch:1927  d_loss:0.4306  g_loss:1.7072
# epoch:1928  d_loss:0.3444  g_loss:1.8091
# epoch:1929  d_loss:0.4816  g_loss:1.5702
# epoch:1930  d_loss:0.3959  g_loss:1.7143
# epoch:1931  d_loss:0.5279  g_loss:1.7232
# epoch:1932  d_loss:0.4082  g_loss:2.1107
# epoch:1933  d_loss:0.5301  g_loss:2.1862
# epoch:1934  d_loss:0.5133  g_loss:2.0760
# epoch:1935  d_loss:0.3888  g_loss:1.9943
# epoch:1936  d_loss:0.4895  g_loss:1.7589
# epoch:1937  d_loss:0.6823  g_loss:1.2370
# epoch:1938  d_loss:0.5274  g_loss:1.3603
# epoch:1939  d_loss:0.3444  g_loss:1.9348
# epoch:1940  d_loss:0.5613  g_loss:2.0572
# epoch:1941  d_loss:0.3561  g_loss:2.3099
# epoch:1942  d_loss:0.4715  g_loss:2.0236
# epoch:1943  d_loss:0.4243  g_loss:1.6297
# epoch:1944  d_loss:0.5129  g_loss:1.6036
# epoch:1945  d_loss:0.4998  g_loss:1.5677
# epoch:1946  d_loss:0.5307  g_loss:1.5145
# epoch:1947  d_loss:0.4859  g_loss:1.8316
# epoch:1948  d_loss:0.4478  g_loss:1.8440
# epoch:1949  d_loss:0.4359  g_loss:2.0150
# epoch:1950  d_loss:0.5601  g_loss:1.6990
# epoch:1951  d_loss:0.7761  g_loss:1.6517
# epoch:1952  d_loss:0.6170  g_loss:1.3471
# epoch:1953  d_loss:0.7073  g_loss:1.2040
# epoch:1954  d_loss:0.6137  g_loss:1.4062
# epoch:1955  d_loss:0.5591  g_loss:1.8268
# epoch:1956  d_loss:0.6287  g_loss:1.7859
# epoch:1957  d_loss:0.7363  g_loss:1.2594
# epoch:1958  d_loss:0.7976  g_loss:0.9300
# epoch:1959  d_loss:0.7290  g_loss:0.6483
# epoch:1960  d_loss:0.6474  g_loss:1.3275
# epoch:1961  d_loss:0.4105  g_loss:1.9709
# epoch:1962  d_loss:0.4069  g_loss:2.2262
# epoch:1963  d_loss:0.4948  g_loss:2.0301
# epoch:1964  d_loss:0.4815  g_loss:1.7978
# epoch:1965  d_loss:0.4079  g_loss:1.5811
# epoch:1966  d_loss:0.5757  g_loss:1.2042
# epoch:1967  d_loss:0.3609  g_loss:1.6086
# epoch:1968  d_loss:0.4668  g_loss:1.5163
# epoch:1969  d_loss:0.3377  g_loss:1.9310
# epoch:1970  d_loss:0.3940  g_loss:1.9959
# epoch:1971  d_loss:0.4820  g_loss:1.8872
# epoch:1972  d_loss:0.3139  g_loss:2.0775
# epoch:1973  d_loss:0.3937  g_loss:1.8578
# epoch:1974  d_loss:0.5085  g_loss:1.2567
# epoch:1975  d_loss:0.4081  g_loss:1.3735
# epoch:1976  d_loss:0.5030  g_loss:1.7603
# epoch:1977  d_loss:0.4948  g_loss:1.8241
# epoch:1978  d_loss:0.4663  g_loss:1.5377
# epoch:1979  d_loss:0.5165  g_loss:1.6100
# epoch:1980  d_loss:0.5609  g_loss:1.6167
# epoch:1981  d_loss:0.4714  g_loss:1.7981
# epoch:1982  d_loss:0.5205  g_loss:1.9722
# epoch:1983  d_loss:0.3783  g_loss:1.9495
# epoch:1984  d_loss:0.5362  g_loss:1.9074
# epoch:1985  d_loss:0.5366  g_loss:1.8263
# epoch:1986  d_loss:0.5793  g_loss:1.4302
# epoch:1987  d_loss:0.6123  g_loss:0.9770
# epoch:1988  d_loss:0.6165  g_loss:1.4261
# epoch:1989  d_loss:0.5058  g_loss:1.2077
# epoch:1990  d_loss:0.4885  g_loss:1.5564
# epoch:1991  d_loss:0.4629  g_loss:1.8684
# epoch:1992  d_loss:0.5414  g_loss:1.8044
# epoch:1993  d_loss:0.4957  g_loss:1.5054
# epoch:1994  d_loss:0.7005  g_loss:1.6196
# epoch:1995  d_loss:0.4774  g_loss:1.9941
# epoch:1996  d_loss:0.4126  g_loss:1.5635
# epoch:1997  d_loss:0.6096  g_loss:1.0915
# epoch:1998  d_loss:0.4421  g_loss:1.4288
# epoch:1999  d_loss:0.3838  g_loss:1.7984
# epoch:2000  d_loss:0.5553  g_loss:1.9354

# %% [markdown]
# ## 4. 이미지의 특징을 추출하는 오토인코더

# %% [markdown]
# ### 실습: 오토인코더 실습하기

# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, UpSampling2D, Flatten, Reshape

import matplotlib.pyplot as plt
import numpy as np

# MNIST 데이터셋을 불러옵니다.

(X_train, _), (X_test, _) = mnist.load_data()
X_train = X_train.reshape(X_train.shape[0], 28, 28, 1).astype('float32') / 255
X_test = X_test.reshape(X_test.shape[0], 28, 28, 1).astype('float32') / 255

# 생성자 모델을 만듭니다.
autoencoder = Sequential()

# 인코딩 부분입니다.
autoencoder.add(Conv2D(16, kernel_size=3, padding='same', input_shape=(28,28,1), activation='relu'))
autoencoder.add(MaxPooling2D(pool_size=2, padding='same'))
autoencoder.add(Conv2D(8, kernel_size=3, activation='relu', padding='same'))
autoencoder.add(MaxPooling2D(pool_size=2, padding='same'))
autoencoder.add(Conv2D(8, kernel_size=3, strides=2, padding='same', activation='relu'))

# 디코딩 부분입니다.
autoencoder.add(Conv2D(8, kernel_size=3, padding='same', activation='relu'))
autoencoder.add(UpSampling2D())
autoencoder.add(Conv2D(8, kernel_size=3, padding='same', activation='relu'))
autoencoder.add(UpSampling2D())
autoencoder.add(Conv2D(16, kernel_size=3, activation='relu'))
autoencoder.add(UpSampling2D())
autoencoder.add(Conv2D(1, kernel_size=3, padding='same', activation='sigmoid'))

# 전체 구조를 확인합니다.
autoencoder.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_18 (Conv2D)          (None, 28, 28, 16)        160
#
#  max_pooling2d_4 (MaxPooling  (None, 14, 14, 16)       0
#  2D)
#
#  conv2d_19 (Conv2D)          (None, 14, 14, 8)         1160
#
#  max_pooling2d_5 (MaxPooling  (None, 7, 7, 8)          0
#  2D)
#
#  conv2d_20 (Conv2D)          (None, 4, 4, 8)           584
#
#  conv2d_21 (Conv2D)          (None, 4, 4, 8)           584
#
#  up_sampling2d_8 (UpSampling  (None, 8, 8, 8)          0
#  2D)
#
#  conv2d_22 (Conv2D)          (None, 8, 8, 8)           584
#
#  up_sampling2d_9 (UpSampling  (None, 16, 16, 8)        0
#  2D)
#
#  conv2d_23 (Conv2D)          (None, 14, 14, 16)        1168
#
#  up_sampling2d_10 (UpSamplin  (None, 28, 28, 16)       0
#  g2D)
#
#  conv2d_24 (Conv2D)          (None, 28, 28, 1)         145
#
# =================================================================
# Total params: 4,385
# Trainable params: 4,385
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 컴파일 및 학습을 하는 부분입니다.
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')
autoencoder.fit(X_train, X_train, epochs=50, batch_size=128, validation_data=(X_test, X_test))

# 학습된 결과를 출력하는 부분입니다.
random_test = np.random.randint(X_test.shape[0], size=5)  # 테스트할 이미지를 랜덤하게 불러옵니다.
ae_imgs = autoencoder.predict(X_test)                     # 앞서 만든 오토인코더 모델에 집어 넣습니다.

plt.figure(figsize=(7, 2))                         # 출력될 이미지의 크기를 정합니다.

for i, image_idx in enumerate(random_test):        # 랜덤하게 뽑은 이미지를 차례로 나열합니다.
   ax = plt.subplot(2, 7, i + 1)
   plt.imshow(X_test[image_idx].reshape(28, 28))   # 테스트할 이미지를 먼저 그대로 보여줍니다.
   ax.axis('off')
   ax = plt.subplot(2, 7, 7 + i +1)
   plt.imshow(ae_imgs[image_idx].reshape(28, 28))  # 오토인코딩 결과를 다음열에 출력합니다.
   ax.axis('off')
plt.show()
# Out:
# Epoch 1/50
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x0000012BC0C5A288> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x0000012BC0C5A288> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 463/469 [============================>.] - ETA: 0s - loss: 0.0861WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x0000012BC0C77708> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x0000012BC0C77708> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0861 - val_loss: 0.0841
# Epoch 2/50
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0850 - val_loss: 0.0841
# Epoch 3/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0851 - val_loss: 0.0844
# Epoch 4/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0851 - val_loss: 0.0839
# Epoch 5/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0850 - val_loss: 0.0840
# Epoch 6/50
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0849 - val_loss: 0.0839
# Epoch 7/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0849 - val_loss: 0.0840
# Epoch 8/50
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0848 - val_loss: 0.0837
# Epoch 9/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0847 - val_loss: 0.0840
# Epoch 10/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0847 - val_loss: 0.0839
# Epoch 11/50
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0847 - val_loss: 0.0841
# Epoch 12/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0845 - val_loss: 0.0836
# Epoch 13/50
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0845 - val_loss: 0.0837
# Epoch 14/50
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0845 - val_loss: 0.0838
# Epoch 15/50
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0844 - val_loss: 0.0834
# Epoch 16/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0844 - val_loss: 0.0839
# Epoch 17/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0844 - val_loss: 0.0838
# Epoch 18/50
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0843 - val_loss: 0.0832
# Epoch 19/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0843 - val_loss: 0.0835
# Epoch 20/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0842 - val_loss: 0.0835
# Epoch 21/50
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0841 - val_loss: 0.0835
# Epoch 22/50
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0841 - val_loss: 0.0832
# Epoch 23/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0841 - val_loss: 0.0832
# Epoch 24/50
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0840 - val_loss: 0.0836
# Epoch 25/50
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0840 - val_loss: 0.0834
# Epoch 26/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0839 - val_loss: 0.0830
# Epoch 27/50
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0839 - val_loss: 0.0830
# Epoch 28/50
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0839 - val_loss: 0.0829
# Epoch 29/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0838 - val_loss: 0.0829
# Epoch 30/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0837 - val_loss: 0.0828
# Epoch 31/50
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0837 - val_loss: 0.0829
# Epoch 32/50
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0836 - val_loss: 0.0827
# Epoch 33/50
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0837 - val_loss: 0.0828
# Epoch 34/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0836 - val_loss: 0.0827
# Epoch 35/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0836 - val_loss: 0.0827
# Epoch 36/50
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0835 - val_loss: 0.0832
# Epoch 37/50
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0835 - val_loss: 0.0825
# Epoch 38/50
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0835 - val_loss: 0.0824
# Epoch 39/50
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0834 - val_loss: 0.0824
# Epoch 40/50
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0834 - val_loss: 0.0827
# Epoch 41/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0833 - val_loss: 0.0824
# Epoch 42/50
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0833 - val_loss: 0.0824
# Epoch 43/50
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0832 - val_loss: 0.0823
# Epoch 44/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0832 - val_loss: 0.0823
# Epoch 45/50
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0832 - val_loss: 0.0829
# Epoch 46/50
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0831 - val_loss: 0.0822
# Epoch 47/50
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0831 - val_loss: 0.0821
# Epoch 48/50
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0831 - val_loss: 0.0822
# Epoch 49/50
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0830 - val_loss: 0.0820
# Epoch 50/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0829 - val_loss: 0.0825
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x0000012BC0DFB798> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x0000012BC0DFB798> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
