# %%
import numpy as np
import cv2


def detect_face():
    src = cv2.imread('kids.png')

    if src is None:
        print('Image load failed!')
        return

    classifier = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

    if classifier.empty():
        print('XML load failed!')
        return

    faces = classifier.detectMultiScale(src)

    for (x, y, w, h) in faces:
        cv2.rectangle(src, (x, y), (x + w, y + h), (255, 0, 255), 2)

    cv2.imshow('src', src)
    cv2.waitKey()
    cv2.destroyAllWindows()


def detect_eyes():
    src = cv2.imread('kids.png')

    if src is None:
        print('Image load failed!')
        return

    face_classifier = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
    eye_classifier = cv2.CascadeClassifier('haarcascade_eye.xml')

    if face_classifier.empty() or eye_classifier.empty():
        print('XML load failed!')
        return

    faces = face_classifier.detectMultiScale(src)

    for (x1, y1, w1, h1) in faces:
        cv2.rectangle(src, (x1, y1), (x1 + w1, y1 + h1), (255, 0, 255), 2)

        faceROI = src[y1:y1 + h1, x1:x1 + w1]
        eyes = eye_classifier.detectMultiScale(faceROI)

        for (x2, y2, w2, h2) in eyes:
            center = (int(x2 + w2 / 2), int(y2 + h2 / 2))
            cv2.circle(faceROI, center, int(w2 / 2), (255, 0, 0), 2, cv2.LINE_AA)

    cv2.imshow('src', src)
    cv2.waitKey()
    cv2.destroyAllWindows()


if __name__ == '__main__':
    detect_face()
    detect_eyes()

# %%
import numpy as np
import cv2


def detect_face():
    # 이미지 읽기
    src = cv2.imread('C:\ex\py\cv\img\m.jpg')

    # 이미지 파일이 없을 경우 에러 메시지 출력
    if src is None:
        print('이미지를 불러올 수 없습니다!')
        return

    # 얼굴 검출을 위한 분류기 로드
    classifier = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

    # 분류기 파일을 읽지 못했을 경우 에러 메시지 출력
    if classifier.empty():
        print('XML 파일을 불러올 수 없습니다!')
        return

    # 얼굴 검출
    faces = classifier.detectMultiScale(src)

    # 검출된 얼굴에 사각형 그리기
    for (x, y, w, h) in faces:
        cv2.rectangle(src, (x, y), (x + w, y + h), (255, 0, 255), 2)

    cv2.imwrite('C:/Users/winrr/Pictures/Screenshots/pfile/cascade1.jpg',src) 

    # 결과 이미지 출력
    cv2.imshow('src', src)
    cv2.waitKey()
    cv2.destroyAllWindows()


def detect_eyes():
    # 이미지 읽기
    src = cv2.imread('C:\ex\py\cv\img\m.jpg')

    # 이미지 파일이 없을 경우 에러 메시지 출력
    if src is None:
        print('이미지를 불러올 수 없습니다!')
        return

    # 얼굴과 눈을 검출하기 위한 분류기 로드
    face_classifier = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
    eye_classifier = cv2.CascadeClassifier('haarcascade_eye.xml')

    # 분류기 파일을 읽지 못했을 경우 에러 메시지 출력
    if face_classifier.empty() or eye_classifier.empty():
        print('XML 파일을 불러올 수 없습니다!')
        return

    # 얼굴 검출
    faces = face_classifier.detectMultiScale(src)

    # 검출된 얼굴에 사각형 그리기
    for (x1, y1, w1, h1) in faces:
        cv2.rectangle(src, (x1, y1), (x1 + w1, y1 + h1), (255, 0, 255), 2)

        # 얼굴 부분에서 눈 검출
        faceROI = src[y1:y1 + h1, x1:x1 + w1]
        eyes = eye_classifier.detectMultiScale(faceROI)

        # 검출된 눈에 원 그리기
        for (x2, y2, w2, h2) in eyes:
            center = (int(x2 + w2 / 2), int(y2 + h2 / 2))
            cv2.circle(faceROI, center, int(w2 / 2), (255, 0, 0), 2, cv2.LINE_AA)

    cv2.imwrite('C:/Users/winrr/Pictures/Screenshots/pfile/cascade2.jpg',src) 

    # 결과 이미지 출력
    cv2.imshow('src', src)
    cv2.waitKey()
    cv2.destroyAllWindows()


if __name__ == '__main__':
    detect_face()  # 얼굴 검출 함수 실행
    detect_eyes()  # 얼굴과 눈 검출 함수 실행
