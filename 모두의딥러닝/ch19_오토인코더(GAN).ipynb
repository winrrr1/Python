# %% [markdown]
# # 19장 세상에 없는 얼굴 GAN, 오토인코더

# %% [markdown]
# ## 3. 적대적 신경망 실행하기

# %% [markdown]
# ### 실습: GAN 모델 만들기

# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.layers import Input, Dense, Reshape, Flatten, Dropout
from tensorflow.keras.layers import BatchNormalization, Activation, LeakyReLU, UpSampling2D, Conv2D
from tensorflow.keras.models import Sequential, Model

import numpy as np
import matplotlib.pyplot as plt

# 생성자 모델을 만듭니다.
generator = Sequential()
generator.add(Dense(128*7*7, input_dim=100, activation=LeakyReLU(0.2)))
generator.add(BatchNormalization())
generator.add(Reshape((7, 7, 128)))
generator.add(UpSampling2D())
generator.add(Conv2D(64, kernel_size=5, padding='same'))
generator.add(BatchNormalization())
generator.add(Activation(LeakyReLU(0.2)))
generator.add(UpSampling2D())
generator.add(Conv2D(1, kernel_size=5, padding='same', activation='tanh'))

# 판별자 모델을 만듭니다.
discriminator = Sequential()
discriminator.add(Conv2D(64, kernel_size=5, strides=2, input_shape=(28,28,1), padding="same"))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Conv2D(128, kernel_size=5, strides=2, padding="same"))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Flatten())
discriminator.add(Dense(1, activation='sigmoid'))
discriminator.compile(loss='binary_crossentropy', optimizer='adam')
discriminator.trainable = False

# 생성자와 판별자 모델을 연결시키는 gan 모델을 만듭니다.
ginput = Input(shape=(100,))
dis_output = discriminator(generator(ginput))
gan = Model(ginput, dis_output)
gan.compile(loss='binary_crossentropy', optimizer='adam')
gan.summary()

# 신경망을 실행시키는 함수를 만듭니다.
def gan_train(epoch, batch_size, saving_interval):

  # MNIST 데이터를 불러옵니다.

  (X_train, _), (_, _) = mnist.load_data()  # 앞서 불러온 적 있는 MNIST를 다시 이용합니다. 단, 테스트 과정은 필요 없고 이미지만 사용할 것이기 때문에 X_train만 불러왔습니다.
  X_train = X_train.reshape(X_train.shape[0], 28, 28, 1).astype('float32')
  X_train = (X_train - 127.5) / 127.5  # 픽셀 값은 0에서 255 사이의 값입니다. 이전에 255로 나누어 줄때는 이를 0~1 사이의 값으로 바꾸었던 것인데, 여기서는 127.5를 빼준 뒤 127.5로 나누어 줌으로 인해 -1에서 1사이의 값으로 바뀌게 됩니다.
  # X_train.shape, Y_train.shape, X_test.shape, Y_test.shape

  true = np.ones((batch_size, 1))
  fake = np.zeros((batch_size, 1))

  for i in range(epoch):
          # 실제 데이터를 판별자에 입력하는 부분입니다.
          idx = np.random.randint(0, X_train.shape[0], batch_size)
          imgs = X_train[idx]
          d_loss_real = discriminator.train_on_batch(imgs, true)

          # 가상 이미지를 판별자에 입력하는 부분입니다.
          noise = np.random.normal(0, 1, (batch_size, 100))
          gen_imgs = generator.predict(noise)
          d_loss_fake = discriminator.train_on_batch(gen_imgs, fake)

          # 판별자와 생성자의 오차를 계산합니다.
          d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)
          g_loss = gan.train_on_batch(noise, true)

          print('epoch:%d' % i, ' d_loss:%.4f' % d_loss, ' g_loss:%.4f' % g_loss)

        # 이 부분은 중간 과정을 이미지로 저장해 주는 부분입니다. 이 장의 주요 내용과 관련이 없어 
        # 소스 코드만 첨부합니다. 만들어진 이미지들은 gan_images 폴더에 저장됩니다.
          if i % saving_interval == 0:
              #r, c = 5, 5
              noise = np.random.normal(0, 1, (25, 100))
              gen_imgs = generator.predict(noise)

              # Rescale images 0 - 1
              gen_imgs = 0.5 * gen_imgs + 0.5

              fig, axs = plt.subplots(5, 5)
              count = 0
              for j in range(5):
                  for k in range(5):
                      axs[j, k].imshow(gen_imgs[count, :, :, 0], cmap='gray')
                      axs[j, k].axis('off')
                      count += 1
              fig.savefig("./gan_mnist_%d.png" % i)

gan_train(2001, 32, 200)  # 2000번 반복되고, 배치 사이즈는 32,  200번마다 결과가 저장되게 하였습니다.
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 100)]             0
#
#  sequential (Sequential)     (None, 28, 28, 1)         865281
#
#  sequential_1 (Sequential)   (None, 1)                 212865
#
# =================================================================
# Total params: 1,078,146
# Trainable params: 852,609
# Non-trainable params: 225,537
# _________________________________________________________________
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000001EA087A1E18> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000001EA087A1E18> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001EA09CAFEA0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001EA09CAFEA0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000001EA0A0F7D90> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000001EA0A0F7D90> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# epoch:0  d_loss:0.6848  g_loss:0.5586
# epoch:1  d_loss:0.5022  g_loss:0.2373
# epoch:2  d_loss:0.4913  g_loss:0.0707
# epoch:3  d_loss:0.4947  g_loss:0.0479
# epoch:4  d_loss:0.5022  g_loss:0.0917
# epoch:5  d_loss:0.4658  g_loss:0.2370
# epoch:6  d_loss:0.4456  g_loss:0.4552
# epoch:7  d_loss:0.4369  g_loss:0.6326
# epoch:8  d_loss:0.4483  g_loss:0.6879
# epoch:9  d_loss:0.4382  g_loss:0.6926
# epoch:10  d_loss:0.3966  g_loss:0.6854
# epoch:11  d_loss:0.3837  g_loss:0.7834
# epoch:12  d_loss:0.4940  g_loss:0.7862
# epoch:13  d_loss:0.5005  g_loss:1.0229
# epoch:14  d_loss:0.5738  g_loss:1.0695
# epoch:15  d_loss:0.5576  g_loss:0.9838
# epoch:16  d_loss:0.6318  g_loss:0.7486
# epoch:17  d_loss:0.4957  g_loss:0.3598
# epoch:18  d_loss:0.3546  g_loss:0.2865
# epoch:19  d_loss:0.2745  g_loss:0.3928
# epoch:20  d_loss:0.2059  g_loss:0.6273
# epoch:21  d_loss:0.1697  g_loss:0.6715
# epoch:22  d_loss:0.1501  g_loss:0.5212
# epoch:23  d_loss:0.1387  g_loss:0.2577
# epoch:24  d_loss:0.1131  g_loss:0.5828
# epoch:25  d_loss:0.1132  g_loss:0.2980
# epoch:26  d_loss:0.1022  g_loss:0.1645
# epoch:27  d_loss:0.1200  g_loss:0.1837
# epoch:28  d_loss:0.1826  g_loss:0.1542
# epoch:29  d_loss:0.2140  g_loss:0.2481
# epoch:30  d_loss:0.2721  g_loss:0.1003
# epoch:31  d_loss:0.6784  g_loss:0.1877
# epoch:32  d_loss:0.9820  g_loss:0.1848
# epoch:33  d_loss:1.1054  g_loss:0.3116
# epoch:34  d_loss:1.0439  g_loss:0.1863
# epoch:35  d_loss:1.5574  g_loss:0.2381
# epoch:36  d_loss:1.2447  g_loss:0.3998
# epoch:37  d_loss:0.8098  g_loss:0.4687
# epoch:38  d_loss:0.6696  g_loss:0.4476
# epoch:39  d_loss:0.2955  g_loss:0.6051
# epoch:40  d_loss:0.1708  g_loss:1.0222
# epoch:41  d_loss:0.1111  g_loss:1.6439
# epoch:42  d_loss:0.0657  g_loss:2.1627
# epoch:43  d_loss:0.0404  g_loss:2.6558
# epoch:44  d_loss:0.0415  g_loss:2.6843
# epoch:45  d_loss:0.0295  g_loss:2.7912
# epoch:46  d_loss:0.0191  g_loss:2.4711
# epoch:47  d_loss:0.0285  g_loss:2.5532
# epoch:48  d_loss:0.0170  g_loss:1.9894
# epoch:49  d_loss:0.0592  g_loss:1.9416
# epoch:50  d_loss:0.0852  g_loss:1.8869
# epoch:51  d_loss:0.2363  g_loss:2.5412
# epoch:52  d_loss:0.0604  g_loss:3.2489
# epoch:53  d_loss:0.3132  g_loss:3.8641
# epoch:54  d_loss:0.1259  g_loss:3.2867
# epoch:55  d_loss:0.1841  g_loss:3.9804
# epoch:56  d_loss:0.3534  g_loss:3.3009
# epoch:57  d_loss:0.1535  g_loss:2.7997
# epoch:58  d_loss:0.4037  g_loss:3.1205
# epoch:59  d_loss:0.3210  g_loss:3.0187
# epoch:60  d_loss:0.3758  g_loss:2.8810
# epoch:61  d_loss:0.4734  g_loss:2.7664
# epoch:62  d_loss:0.2382  g_loss:2.6501
# epoch:63  d_loss:0.2697  g_loss:3.0630
# epoch:64  d_loss:0.2776  g_loss:2.7698
# epoch:65  d_loss:0.4466  g_loss:2.8666
# epoch:66  d_loss:0.2904  g_loss:2.6419
# epoch:67  d_loss:0.3670  g_loss:2.2754
# epoch:68  d_loss:0.2664  g_loss:2.3543
# epoch:69  d_loss:0.2937  g_loss:2.8446
# epoch:70  d_loss:0.5116  g_loss:2.5412
# epoch:71  d_loss:0.3657  g_loss:2.7019
# epoch:72  d_loss:0.2983  g_loss:1.9994
# epoch:73  d_loss:0.3828  g_loss:2.2023
# epoch:74  d_loss:0.4206  g_loss:2.1170
# epoch:75  d_loss:0.4440  g_loss:2.2284
# epoch:76  d_loss:0.3812  g_loss:1.8107
# epoch:77  d_loss:0.4708  g_loss:1.7082
# epoch:78  d_loss:0.4324  g_loss:1.7837
# epoch:79  d_loss:0.4216  g_loss:1.8180
# epoch:80  d_loss:0.4386  g_loss:1.8912
# epoch:81  d_loss:0.4445  g_loss:1.7425
# epoch:82  d_loss:0.4212  g_loss:2.0747
# epoch:83  d_loss:0.5086  g_loss:1.6939
# epoch:84  d_loss:0.3412  g_loss:1.8397
# epoch:85  d_loss:0.4499  g_loss:1.5747
# epoch:86  d_loss:0.5698  g_loss:1.7529
# epoch:87  d_loss:0.3654  g_loss:1.5886
# epoch:88  d_loss:0.4283  g_loss:1.6458
# epoch:89  d_loss:0.4093  g_loss:1.9017
# epoch:90  d_loss:0.4355  g_loss:1.4274
# epoch:91  d_loss:0.5149  g_loss:1.5770
# epoch:92  d_loss:0.3602  g_loss:1.8813
# epoch:93  d_loss:0.3309  g_loss:2.3802
# epoch:94  d_loss:0.4954  g_loss:2.0557
# epoch:95  d_loss:0.3824  g_loss:1.9146
# epoch:96  d_loss:0.5435  g_loss:1.7734
# epoch:97  d_loss:0.5046  g_loss:1.6054
# epoch:98  d_loss:0.4626  g_loss:1.7490
# epoch:99  d_loss:0.5028  g_loss:2.0224
# epoch:100  d_loss:0.4985  g_loss:2.1370
# epoch:101  d_loss:0.4282  g_loss:2.2193
# epoch:102  d_loss:0.4724  g_loss:1.6432
# epoch:103  d_loss:0.4606  g_loss:1.5069
# epoch:104  d_loss:0.5182  g_loss:1.6373
# epoch:105  d_loss:0.3210  g_loss:2.2116
# epoch:106  d_loss:0.3410  g_loss:3.0381
# epoch:107  d_loss:0.5028  g_loss:2.2611
# epoch:108  d_loss:0.4386  g_loss:2.2570
# epoch:109  d_loss:0.3671  g_loss:1.8043
# epoch:110  d_loss:0.4921  g_loss:2.2163
# epoch:111  d_loss:0.3285  g_loss:2.8152
# epoch:112  d_loss:0.3756  g_loss:3.0000
# epoch:113  d_loss:0.4485  g_loss:2.3281
# epoch:114  d_loss:0.3730  g_loss:2.0039
# epoch:115  d_loss:0.4744  g_loss:1.9928
# epoch:116  d_loss:0.4805  g_loss:2.2943
# epoch:117  d_loss:0.3721  g_loss:2.8182
# epoch:118  d_loss:0.3560  g_loss:2.9493
# epoch:119  d_loss:0.3952  g_loss:2.6638
# epoch:120  d_loss:0.4502  g_loss:2.5594
# epoch:121  d_loss:0.4291  g_loss:2.7900
# epoch:122  d_loss:0.3179  g_loss:3.0622
# epoch:123  d_loss:0.4143  g_loss:3.2324
# epoch:124  d_loss:0.5725  g_loss:2.5367
# epoch:125  d_loss:0.6374  g_loss:2.2461
# epoch:126  d_loss:0.7135  g_loss:2.3322
# epoch:127  d_loss:0.5917  g_loss:2.9223
# epoch:128  d_loss:0.7283  g_loss:2.7319
# epoch:129  d_loss:0.9661  g_loss:1.6949
# epoch:130  d_loss:1.1053  g_loss:0.9722
# epoch:131  d_loss:0.6135  g_loss:1.2946
# epoch:132  d_loss:0.6301  g_loss:1.4366
# epoch:133  d_loss:0.5810  g_loss:1.6888
# epoch:134  d_loss:0.6803  g_loss:1.3900
# epoch:135  d_loss:0.6679  g_loss:0.8878
# epoch:136  d_loss:0.6991  g_loss:0.8473
# epoch:137  d_loss:0.4712  g_loss:1.4191
# epoch:138  d_loss:0.6288  g_loss:1.3073
# epoch:139  d_loss:0.6136  g_loss:0.9981
# epoch:140  d_loss:0.5890  g_loss:0.9107
# epoch:141  d_loss:0.7073  g_loss:0.8280
# epoch:142  d_loss:0.6372  g_loss:0.8013
# epoch:143  d_loss:0.6414  g_loss:0.8456
# epoch:144  d_loss:0.6045  g_loss:1.0405
# epoch:145  d_loss:0.7649  g_loss:0.9276
# epoch:146  d_loss:0.6225  g_loss:1.0504
# epoch:147  d_loss:0.5971  g_loss:1.0624
# epoch:148  d_loss:0.5334  g_loss:1.0546
# epoch:149  d_loss:0.5477  g_loss:1.1470
# epoch:150  d_loss:0.4534  g_loss:1.4074
# epoch:151  d_loss:0.4168  g_loss:1.7344
# epoch:152  d_loss:0.3995  g_loss:1.9439
# epoch:153  d_loss:0.3464  g_loss:1.9140
# epoch:154  d_loss:0.3767  g_loss:1.9578
# epoch:155  d_loss:0.3599  g_loss:1.9907
# epoch:156  d_loss:0.4993  g_loss:1.9141
# epoch:157  d_loss:0.3980  g_loss:1.4999
# epoch:158  d_loss:0.6995  g_loss:1.4585
# epoch:159  d_loss:0.9794  g_loss:1.5795
# epoch:160  d_loss:0.9176  g_loss:1.4784
# epoch:161  d_loss:0.9094  g_loss:1.5694
# epoch:162  d_loss:1.0403  g_loss:1.4300
# epoch:163  d_loss:0.9833  g_loss:1.4935
# epoch:164  d_loss:0.8144  g_loss:1.4152
# epoch:165  d_loss:0.7657  g_loss:1.5519
# epoch:166  d_loss:0.7257  g_loss:1.4514
# epoch:167  d_loss:0.6614  g_loss:1.6630
# epoch:168  d_loss:0.5378  g_loss:1.7286
# epoch:169  d_loss:0.4888  g_loss:1.8982
# epoch:170  d_loss:0.4355  g_loss:1.7265
# epoch:171  d_loss:0.4073  g_loss:1.5595
# epoch:172  d_loss:0.3528  g_loss:1.6268
# epoch:173  d_loss:0.2074  g_loss:1.7932
# epoch:174  d_loss:0.2315  g_loss:1.8053
# epoch:175  d_loss:0.2933  g_loss:1.7967
# epoch:176  d_loss:0.2588  g_loss:1.5232
# epoch:177  d_loss:0.2532  g_loss:1.4717
# epoch:178  d_loss:0.3711  g_loss:1.2337
# epoch:179  d_loss:0.3310  g_loss:1.1856
# epoch:180  d_loss:0.2107  g_loss:1.3062
# epoch:181  d_loss:0.2956  g_loss:1.6503
# epoch:182  d_loss:0.4137  g_loss:1.4198
# epoch:183  d_loss:0.4288  g_loss:1.1352
# epoch:184  d_loss:0.6748  g_loss:0.7826
# epoch:185  d_loss:0.7251  g_loss:0.7124
# epoch:186  d_loss:0.7490  g_loss:0.8523
# epoch:187  d_loss:0.9201  g_loss:0.6386
# epoch:188  d_loss:0.9144  g_loss:0.5739
# epoch:189  d_loss:1.3638  g_loss:0.7104
# epoch:190  d_loss:1.0301  g_loss:0.6124
# epoch:191  d_loss:1.0967  g_loss:0.5919
# epoch:192  d_loss:0.9463  g_loss:0.6259
# epoch:193  d_loss:0.8915  g_loss:0.6437
# epoch:194  d_loss:0.8333  g_loss:0.6811
# epoch:195  d_loss:0.6883  g_loss:0.7363
# epoch:196  d_loss:0.6290  g_loss:0.8010
# epoch:197  d_loss:0.5443  g_loss:0.9978
# epoch:198  d_loss:0.4739  g_loss:1.0288
# epoch:199  d_loss:0.4240  g_loss:1.2121
# epoch:200  d_loss:0.4152  g_loss:1.3222
# epoch:201  d_loss:0.3676  g_loss:1.3936
# epoch:202  d_loss:0.2980  g_loss:1.6773
# epoch:203  d_loss:0.2309  g_loss:1.8977
# epoch:204  d_loss:0.2599  g_loss:2.0280
# epoch:205  d_loss:0.1464  g_loss:2.1784
# epoch:206  d_loss:0.2013  g_loss:2.1498
# epoch:207  d_loss:0.1659  g_loss:2.4450
# epoch:208  d_loss:0.1497  g_loss:2.5811
# epoch:209  d_loss:0.1959  g_loss:2.6277
# epoch:210  d_loss:0.1477  g_loss:2.7959
# epoch:211  d_loss:0.1718  g_loss:2.9530
# epoch:212  d_loss:0.2692  g_loss:3.0268
# epoch:213  d_loss:0.3450  g_loss:2.6950
# epoch:214  d_loss:0.5562  g_loss:2.1745
# epoch:215  d_loss:0.4866  g_loss:2.3456
# epoch:216  d_loss:0.5974  g_loss:2.1762
# epoch:217  d_loss:0.6996  g_loss:2.0631
# epoch:218  d_loss:0.9488  g_loss:1.7599
# epoch:219  d_loss:1.0536  g_loss:1.5147
# epoch:220  d_loss:1.0257  g_loss:1.3746
# epoch:221  d_loss:1.1470  g_loss:1.3482
# epoch:222  d_loss:1.0657  g_loss:1.6453
# epoch:223  d_loss:1.0592  g_loss:1.2647
# epoch:224  d_loss:0.8614  g_loss:1.2218
# epoch:225  d_loss:0.7195  g_loss:1.3131
# epoch:226  d_loss:0.8297  g_loss:1.1565
# epoch:227  d_loss:0.8475  g_loss:0.9650
# epoch:228  d_loss:0.7292  g_loss:1.3357
# epoch:229  d_loss:0.5957  g_loss:1.4150
# epoch:230  d_loss:0.5622  g_loss:1.5131
# epoch:231  d_loss:0.6315  g_loss:1.4783
# epoch:232  d_loss:0.6716  g_loss:1.4094
# epoch:233  d_loss:0.5378  g_loss:1.4893
# epoch:234  d_loss:0.6537  g_loss:1.4497
# epoch:235  d_loss:0.5477  g_loss:1.2300
# epoch:236  d_loss:0.4792  g_loss:1.3133
# epoch:237  d_loss:0.5384  g_loss:1.3944
# epoch:238  d_loss:0.5214  g_loss:1.5476
# epoch:239  d_loss:0.4922  g_loss:1.6732
# epoch:240  d_loss:0.4704  g_loss:1.8634
# epoch:241  d_loss:0.5493  g_loss:1.6498
# epoch:242  d_loss:0.4717  g_loss:1.5894
# epoch:243  d_loss:0.5474  g_loss:1.5860
# epoch:244  d_loss:0.4633  g_loss:1.7735
# epoch:245  d_loss:0.4470  g_loss:1.6355
# epoch:246  d_loss:0.3903  g_loss:1.5485
# epoch:247  d_loss:0.4924  g_loss:1.6227
# epoch:248  d_loss:0.3948  g_loss:1.8651
# epoch:249  d_loss:0.4060  g_loss:1.8802
# epoch:250  d_loss:0.3605  g_loss:1.7272
# epoch:251  d_loss:0.4115  g_loss:1.7736
# epoch:252  d_loss:0.3920  g_loss:1.8471
# epoch:253  d_loss:0.4262  g_loss:1.8322
# epoch:254  d_loss:0.4660  g_loss:1.6893
# epoch:255  d_loss:0.4309  g_loss:1.6695
# epoch:256  d_loss:0.4586  g_loss:1.6866
# epoch:257  d_loss:0.4228  g_loss:1.8144
# epoch:258  d_loss:0.4561  g_loss:1.6995
# epoch:259  d_loss:0.4183  g_loss:1.6603
# epoch:260  d_loss:0.3953  g_loss:1.7597
# epoch:261  d_loss:0.3845  g_loss:1.6815
# epoch:262  d_loss:0.4393  g_loss:1.5730
# epoch:263  d_loss:0.4059  g_loss:1.8383
# epoch:264  d_loss:0.5837  g_loss:1.5918
# epoch:265  d_loss:0.4905  g_loss:1.4230
# epoch:266  d_loss:0.6871  g_loss:1.1243
# epoch:267  d_loss:0.6685  g_loss:1.0978
# epoch:268  d_loss:0.5628  g_loss:1.3362
# epoch:269  d_loss:0.5235  g_loss:1.3171
# epoch:270  d_loss:0.7803  g_loss:1.0659
# epoch:271  d_loss:0.7468  g_loss:1.1388
# epoch:272  d_loss:0.7230  g_loss:1.1930
# epoch:273  d_loss:0.7233  g_loss:1.1308
# epoch:274  d_loss:0.7348  g_loss:1.0710
# epoch:275  d_loss:0.6775  g_loss:0.9743
# epoch:276  d_loss:0.6231  g_loss:1.0731
# epoch:277  d_loss:0.7395  g_loss:1.0030
# epoch:278  d_loss:0.7598  g_loss:0.8834
# epoch:279  d_loss:0.6321  g_loss:0.8688
# epoch:280  d_loss:0.5996  g_loss:1.1065
# epoch:281  d_loss:0.5468  g_loss:1.1764
# epoch:282  d_loss:0.5580  g_loss:1.2764
# epoch:283  d_loss:0.5281  g_loss:1.1792
# epoch:284  d_loss:0.4429  g_loss:1.4059
# epoch:285  d_loss:0.5198  g_loss:1.3456
# epoch:286  d_loss:0.4173  g_loss:1.4601
# epoch:287  d_loss:0.2698  g_loss:1.9767
# epoch:288  d_loss:0.2968  g_loss:1.9290
# epoch:289  d_loss:0.3051  g_loss:2.2281
# epoch:290  d_loss:0.2870  g_loss:2.4024
# epoch:291  d_loss:0.3589  g_loss:2.1792
# epoch:292  d_loss:0.3239  g_loss:2.4564
# epoch:293  d_loss:0.3198  g_loss:2.3922
# epoch:294  d_loss:0.4086  g_loss:2.2221
# epoch:295  d_loss:0.4988  g_loss:2.6038
# epoch:296  d_loss:0.6215  g_loss:2.6765
# epoch:297  d_loss:0.5646  g_loss:2.8666
# epoch:298  d_loss:0.7962  g_loss:2.2404
# epoch:299  d_loss:0.6871  g_loss:1.7778
# epoch:300  d_loss:0.6813  g_loss:1.6140
# epoch:301  d_loss:0.8361  g_loss:1.4049
# epoch:302  d_loss:0.7223  g_loss:1.1386
# epoch:303  d_loss:0.6551  g_loss:1.1349
# epoch:304  d_loss:0.5197  g_loss:1.4683
# epoch:305  d_loss:0.7120  g_loss:1.6319
# epoch:306  d_loss:0.6484  g_loss:1.6423
# epoch:307  d_loss:0.8041  g_loss:1.2885
# epoch:308  d_loss:0.6742  g_loss:1.3375
# epoch:309  d_loss:0.6318  g_loss:1.4312
# epoch:310  d_loss:0.6220  g_loss:1.4697
# epoch:311  d_loss:0.6594  g_loss:1.0402
# epoch:312  d_loss:0.6245  g_loss:1.1308
# epoch:313  d_loss:0.5686  g_loss:1.3785
# epoch:314  d_loss:0.5898  g_loss:1.1564
# epoch:315  d_loss:0.5528  g_loss:1.2479
# epoch:316  d_loss:0.5703  g_loss:1.3156
# epoch:317  d_loss:0.5694  g_loss:1.7408
# epoch:318  d_loss:0.5107  g_loss:1.4079
# epoch:319  d_loss:0.5367  g_loss:1.2824
# epoch:320  d_loss:0.5116  g_loss:1.2636
# epoch:321  d_loss:0.4957  g_loss:1.3838
# epoch:322  d_loss:0.4904  g_loss:1.5879
# epoch:323  d_loss:0.4885  g_loss:1.7210
# epoch:324  d_loss:0.4000  g_loss:1.6888
# epoch:325  d_loss:0.4511  g_loss:1.6492
# epoch:326  d_loss:0.6518  g_loss:1.3743
# epoch:327  d_loss:0.4473  g_loss:1.3609
# epoch:328  d_loss:0.4706  g_loss:1.4054
# epoch:329  d_loss:0.4174  g_loss:1.3992
# epoch:330  d_loss:0.4487  g_loss:1.3125
# epoch:331  d_loss:0.4374  g_loss:1.4939
# epoch:332  d_loss:0.4262  g_loss:2.0171
# epoch:333  d_loss:0.3918  g_loss:1.9132
# epoch:334  d_loss:0.4362  g_loss:1.5350
# epoch:335  d_loss:0.5354  g_loss:1.3065
# epoch:336  d_loss:0.4660  g_loss:1.3683
# epoch:337  d_loss:0.5154  g_loss:1.3424
# epoch:338  d_loss:0.5460  g_loss:1.3917
# epoch:339  d_loss:0.3751  g_loss:1.4361
# epoch:340  d_loss:0.4263  g_loss:1.3924
# epoch:341  d_loss:0.5134  g_loss:1.6253
# epoch:342  d_loss:0.6029  g_loss:1.5680
# epoch:343  d_loss:0.5045  g_loss:1.1728
# epoch:344  d_loss:0.4962  g_loss:1.3490
# epoch:345  d_loss:0.5452  g_loss:1.2826
# epoch:346  d_loss:0.4909  g_loss:1.3281
# epoch:347  d_loss:0.5756  g_loss:1.3990
# epoch:348  d_loss:0.6121  g_loss:1.6428
# epoch:349  d_loss:0.4934  g_loss:1.4491
# epoch:350  d_loss:0.5112  g_loss:1.4760
# epoch:351  d_loss:0.4626  g_loss:1.3575
# epoch:352  d_loss:0.5800  g_loss:1.3224
# epoch:353  d_loss:0.5279  g_loss:1.3846
# epoch:354  d_loss:0.6701  g_loss:1.1616
# epoch:355  d_loss:0.7568  g_loss:1.0652
# epoch:356  d_loss:0.5117  g_loss:1.1929
# epoch:357  d_loss:0.4879  g_loss:1.0215
# epoch:358  d_loss:0.7068  g_loss:1.0685
# epoch:359  d_loss:0.5196  g_loss:1.0119
# epoch:360  d_loss:0.5918  g_loss:1.2446
# epoch:361  d_loss:0.5736  g_loss:1.1520
# epoch:362  d_loss:0.5628  g_loss:1.0715
# epoch:363  d_loss:0.5363  g_loss:1.3120
# epoch:364  d_loss:0.5050  g_loss:1.1881
# epoch:365  d_loss:0.4445  g_loss:1.4030
# epoch:366  d_loss:0.4785  g_loss:1.4501
# epoch:367  d_loss:0.5513  g_loss:1.3709
# epoch:368  d_loss:0.4831  g_loss:1.5330
# epoch:369  d_loss:0.3867  g_loss:1.2807
# epoch:370  d_loss:0.4834  g_loss:1.3600
# epoch:371  d_loss:0.4336  g_loss:1.3436
# epoch:372  d_loss:0.3788  g_loss:1.5041
# epoch:373  d_loss:0.4483  g_loss:1.5133
# epoch:374  d_loss:0.3939  g_loss:1.5562
# epoch:375  d_loss:0.4346  g_loss:1.5508
# epoch:376  d_loss:0.6161  g_loss:1.4671
# epoch:377  d_loss:0.3201  g_loss:1.5734
# epoch:378  d_loss:0.4388  g_loss:1.5863
# epoch:379  d_loss:0.3822  g_loss:1.8191
# epoch:380  d_loss:0.4297  g_loss:1.8338
# epoch:381  d_loss:0.3135  g_loss:1.7028
# epoch:382  d_loss:0.4536  g_loss:1.8039
# epoch:383  d_loss:0.4366  g_loss:1.4840
# epoch:384  d_loss:0.5331  g_loss:1.4328
# epoch:385  d_loss:0.4017  g_loss:1.4473
# epoch:386  d_loss:0.5420  g_loss:1.4171
# epoch:387  d_loss:0.5078  g_loss:1.6092
# epoch:388  d_loss:0.4659  g_loss:1.6976
# epoch:389  d_loss:0.5164  g_loss:1.5649
# epoch:390  d_loss:0.4828  g_loss:1.5896
# epoch:391  d_loss:0.5486  g_loss:1.3488
# epoch:392  d_loss:0.5502  g_loss:1.0021
# epoch:393  d_loss:0.6765  g_loss:1.1689
# epoch:394  d_loss:0.6272  g_loss:1.2013
# epoch:395  d_loss:0.4843  g_loss:1.4028
# epoch:396  d_loss:0.5227  g_loss:1.3600
# epoch:397  d_loss:0.5445  g_loss:1.3349
# epoch:398  d_loss:0.4560  g_loss:1.5115
# epoch:399  d_loss:0.5364  g_loss:1.3907
# epoch:400  d_loss:0.5297  g_loss:1.2688
# epoch:401  d_loss:0.5299  g_loss:1.1552
# epoch:402  d_loss:0.5843  g_loss:1.0301
# epoch:403  d_loss:0.4990  g_loss:1.0792
# epoch:404  d_loss:0.5864  g_loss:1.2269
# epoch:405  d_loss:0.5023  g_loss:1.3436
# epoch:406  d_loss:0.4868  g_loss:1.5025
# epoch:407  d_loss:0.5885  g_loss:1.3211
# epoch:408  d_loss:0.4407  g_loss:1.4027
# epoch:409  d_loss:0.4060  g_loss:1.6081
# epoch:410  d_loss:0.4330  g_loss:1.6067
# epoch:411  d_loss:0.4014  g_loss:1.7189
# epoch:412  d_loss:0.3654  g_loss:1.6710
# epoch:413  d_loss:0.4325  g_loss:1.8431
# epoch:414  d_loss:0.4542  g_loss:1.8768
# epoch:415  d_loss:0.3578  g_loss:1.7130
# epoch:416  d_loss:0.4826  g_loss:1.5849
# epoch:417  d_loss:0.4152  g_loss:1.3744
# epoch:418  d_loss:0.3129  g_loss:1.5193
# epoch:419  d_loss:0.3162  g_loss:1.4052
# epoch:420  d_loss:0.3699  g_loss:1.6335
# epoch:421  d_loss:0.3194  g_loss:1.7838
# epoch:422  d_loss:0.4510  g_loss:2.0595
# epoch:423  d_loss:0.4409  g_loss:2.0434
# epoch:424  d_loss:0.3684  g_loss:1.8275
# epoch:425  d_loss:0.5836  g_loss:1.4829
# epoch:426  d_loss:0.3500  g_loss:1.6513
# epoch:427  d_loss:0.3248  g_loss:1.9136
# epoch:428  d_loss:0.3791  g_loss:1.9054
# epoch:429  d_loss:0.4929  g_loss:1.7323
# epoch:430  d_loss:0.4396  g_loss:1.7605
# epoch:431  d_loss:0.4636  g_loss:2.0187
# epoch:432  d_loss:0.2851  g_loss:2.0844
# epoch:433  d_loss:0.3860  g_loss:1.8221
# epoch:434  d_loss:0.6622  g_loss:1.4133
# epoch:435  d_loss:0.3502  g_loss:1.5680
# epoch:436  d_loss:0.3919  g_loss:1.5313
# epoch:437  d_loss:0.4173  g_loss:1.4966
# epoch:438  d_loss:0.3189  g_loss:2.0490
# epoch:439  d_loss:0.4506  g_loss:1.5486
# epoch:440  d_loss:0.4326  g_loss:1.5826
# epoch:441  d_loss:0.4565  g_loss:1.6108
# epoch:442  d_loss:0.3278  g_loss:1.9531
# epoch:443  d_loss:0.4195  g_loss:1.8909
# epoch:444  d_loss:0.5083  g_loss:1.8343
# epoch:445  d_loss:0.5396  g_loss:1.6529
# epoch:446  d_loss:0.3775  g_loss:1.8340
# epoch:447  d_loss:0.3777  g_loss:1.5506
# epoch:448  d_loss:0.3877  g_loss:1.6311
# epoch:449  d_loss:0.3204  g_loss:1.5850
# epoch:450  d_loss:0.3598  g_loss:1.7417
# epoch:451  d_loss:0.4222  g_loss:1.8170
# epoch:452  d_loss:0.3464  g_loss:2.1281
# epoch:453  d_loss:0.4196  g_loss:1.8194
# epoch:454  d_loss:0.4589  g_loss:1.5576
# epoch:455  d_loss:0.4236  g_loss:1.5606
# epoch:456  d_loss:0.4620  g_loss:1.7266
# epoch:457  d_loss:0.4668  g_loss:1.7896
# epoch:458  d_loss:0.4909  g_loss:1.6733
# epoch:459  d_loss:0.4490  g_loss:1.3972
# epoch:460  d_loss:0.4893  g_loss:1.6088
# epoch:461  d_loss:0.4685  g_loss:1.4805
# epoch:462  d_loss:0.4777  g_loss:1.5018
# epoch:463  d_loss:0.4512  g_loss:1.5524
# epoch:464  d_loss:0.4874  g_loss:1.4869
# epoch:465  d_loss:0.4541  g_loss:1.4769
# epoch:466  d_loss:0.4726  g_loss:1.5459
# epoch:467  d_loss:0.4106  g_loss:1.4067
# epoch:468  d_loss:0.4703  g_loss:1.3180
# epoch:469  d_loss:0.3933  g_loss:1.7379
# epoch:470  d_loss:0.4552  g_loss:1.5795
# epoch:471  d_loss:0.3520  g_loss:2.0270
# epoch:472  d_loss:0.4764  g_loss:1.4044
# epoch:473  d_loss:0.3784  g_loss:1.3814
# epoch:474  d_loss:0.3232  g_loss:1.4897
# epoch:475  d_loss:0.3685  g_loss:1.9252
# epoch:476  d_loss:0.3767  g_loss:1.8388
# epoch:477  d_loss:0.3222  g_loss:2.2987
# epoch:478  d_loss:0.3649  g_loss:2.0189
# epoch:479  d_loss:0.3744  g_loss:2.2430
# epoch:480  d_loss:0.4328  g_loss:1.9854
# epoch:481  d_loss:0.3559  g_loss:1.9348
# epoch:482  d_loss:0.3571  g_loss:1.6795
# epoch:483  d_loss:0.2623  g_loss:1.9843
# epoch:484  d_loss:0.2713  g_loss:1.8282
# epoch:485  d_loss:0.3213  g_loss:1.7993
# epoch:486  d_loss:0.3145  g_loss:2.0268
# epoch:487  d_loss:0.3532  g_loss:2.1794
# epoch:488  d_loss:0.2762  g_loss:2.0609
# epoch:489  d_loss:0.3164  g_loss:2.0777
# epoch:490  d_loss:0.3694  g_loss:1.5725
# epoch:491  d_loss:0.3472  g_loss:1.8948
# epoch:492  d_loss:0.3587  g_loss:1.6680
# epoch:493  d_loss:0.2481  g_loss:2.3864
# epoch:494  d_loss:0.3924  g_loss:2.2596
# epoch:495  d_loss:0.4457  g_loss:1.9603
# epoch:496  d_loss:0.3548  g_loss:2.4547
# epoch:497  d_loss:0.3262  g_loss:2.2006
# epoch:498  d_loss:0.2372  g_loss:2.1720
# epoch:499  d_loss:0.2852  g_loss:1.9647
# epoch:500  d_loss:0.3512  g_loss:1.9050
# epoch:501  d_loss:0.4664  g_loss:1.4662
# epoch:502  d_loss:0.2755  g_loss:2.2761
# epoch:503  d_loss:0.2828  g_loss:2.3612
# epoch:504  d_loss:0.2848  g_loss:2.1573
# epoch:505  d_loss:0.3348  g_loss:2.1043
# epoch:506  d_loss:0.3532  g_loss:1.9106
# epoch:507  d_loss:0.4110  g_loss:1.9108
# epoch:508  d_loss:0.3372  g_loss:2.2407
# epoch:509  d_loss:0.2459  g_loss:2.4570
# epoch:510  d_loss:0.2677  g_loss:2.2468
# epoch:511  d_loss:0.3275  g_loss:1.8406
# epoch:512  d_loss:0.2809  g_loss:1.8574
# epoch:513  d_loss:0.3489  g_loss:2.1989
# epoch:514  d_loss:0.3562  g_loss:2.1881
# epoch:515  d_loss:0.2808  g_loss:2.3478
# epoch:516  d_loss:0.3630  g_loss:1.9051
# epoch:517  d_loss:0.3129  g_loss:2.0660
# epoch:518  d_loss:0.3163  g_loss:1.8341
# epoch:519  d_loss:0.2940  g_loss:2.0686
# epoch:520  d_loss:0.3536  g_loss:1.9458
# epoch:521  d_loss:0.3181  g_loss:1.6363
# epoch:522  d_loss:0.3907  g_loss:1.8864
# epoch:523  d_loss:0.3233  g_loss:1.8832
# epoch:524  d_loss:0.4053  g_loss:2.0366
# epoch:525  d_loss:0.3397  g_loss:2.2840
# epoch:526  d_loss:0.2467  g_loss:2.7017
# epoch:527  d_loss:0.3784  g_loss:2.1498
# epoch:528  d_loss:0.3866  g_loss:1.8518
# epoch:529  d_loss:0.3920  g_loss:1.8816
# epoch:530  d_loss:0.3648  g_loss:2.4389
# epoch:531  d_loss:0.3117  g_loss:2.8003
# epoch:532  d_loss:0.3006  g_loss:2.5153
# epoch:533  d_loss:0.3869  g_loss:2.0890
# epoch:534  d_loss:0.3398  g_loss:1.9179
# epoch:535  d_loss:0.2146  g_loss:2.4456
# epoch:536  d_loss:0.2518  g_loss:2.7085
# epoch:537  d_loss:0.2803  g_loss:2.4456
# epoch:538  d_loss:0.2218  g_loss:2.4296
# epoch:539  d_loss:0.2352  g_loss:2.2452
# epoch:540  d_loss:0.1935  g_loss:2.4213
# epoch:541  d_loss:0.2428  g_loss:2.9305
# epoch:542  d_loss:0.2205  g_loss:2.9775
# epoch:543  d_loss:0.2111  g_loss:3.0213
# epoch:544  d_loss:0.2649  g_loss:3.1055
# epoch:545  d_loss:0.2363  g_loss:3.3844
# epoch:546  d_loss:0.2405  g_loss:3.2316
# epoch:547  d_loss:0.3225  g_loss:2.8036
# epoch:548  d_loss:0.2032  g_loss:3.1508
# epoch:549  d_loss:0.2394  g_loss:2.5027
# epoch:550  d_loss:0.1914  g_loss:2.6170
# epoch:551  d_loss:0.2543  g_loss:2.9184
# epoch:552  d_loss:0.1936  g_loss:2.8387
# epoch:553  d_loss:0.2576  g_loss:2.6552
# epoch:554  d_loss:0.3058  g_loss:2.4935
# epoch:555  d_loss:0.2886  g_loss:2.3205
# epoch:556  d_loss:0.2446  g_loss:2.2997
# epoch:557  d_loss:0.2405  g_loss:2.4120
# epoch:558  d_loss:0.2081  g_loss:2.6991
# epoch:559  d_loss:0.2721  g_loss:2.8742
# epoch:560  d_loss:0.3090  g_loss:2.3877
# epoch:561  d_loss:0.2214  g_loss:2.1513
# epoch:562  d_loss:0.3603  g_loss:2.1152
# epoch:563  d_loss:0.2119  g_loss:2.9493
# epoch:564  d_loss:0.1881  g_loss:3.1825
# epoch:565  d_loss:0.2280  g_loss:3.4683
# epoch:566  d_loss:0.3903  g_loss:2.5739
# epoch:567  d_loss:0.2846  g_loss:2.6470
# epoch:568  d_loss:0.2277  g_loss:2.8964
# epoch:569  d_loss:0.2423  g_loss:2.8365
# epoch:570  d_loss:0.3461  g_loss:2.1555
# epoch:571  d_loss:0.3224  g_loss:2.5396
# epoch:572  d_loss:0.3119  g_loss:2.2126
# epoch:573  d_loss:0.4230  g_loss:1.6771
# epoch:574  d_loss:0.3223  g_loss:2.1980
# epoch:575  d_loss:0.3233  g_loss:2.5276
# epoch:576  d_loss:0.3040  g_loss:2.3388
# epoch:577  d_loss:0.3145  g_loss:2.5374
# epoch:578  d_loss:0.3613  g_loss:2.3051
# epoch:579  d_loss:0.3055  g_loss:2.2847
# epoch:580  d_loss:0.2404  g_loss:2.4444
# epoch:581  d_loss:0.2285  g_loss:2.9279
# epoch:582  d_loss:0.1415  g_loss:3.1167
# epoch:583  d_loss:0.1780  g_loss:3.0959
# epoch:584  d_loss:0.2218  g_loss:2.7869
# epoch:585  d_loss:0.1835  g_loss:2.9862
# epoch:586  d_loss:0.1419  g_loss:2.5750
# epoch:587  d_loss:0.1491  g_loss:2.6760
# epoch:588  d_loss:0.1569  g_loss:3.0521
# epoch:589  d_loss:0.1478  g_loss:2.8356
# epoch:590  d_loss:0.1282  g_loss:2.8951
# epoch:591  d_loss:0.1462  g_loss:3.0129
# epoch:592  d_loss:0.2283  g_loss:2.7602
# epoch:593  d_loss:0.2612  g_loss:2.4307
# epoch:594  d_loss:0.2577  g_loss:3.0307
# epoch:595  d_loss:0.1716  g_loss:2.6731
# epoch:596  d_loss:0.2409  g_loss:3.3456
# epoch:597  d_loss:0.1422  g_loss:3.3478
# epoch:598  d_loss:0.2216  g_loss:2.9286
# epoch:599  d_loss:0.1711  g_loss:2.3262
# epoch:600  d_loss:0.1602  g_loss:2.8559
# epoch:601  d_loss:0.3215  g_loss:2.5578
# epoch:602  d_loss:0.2883  g_loss:2.4029
# epoch:603  d_loss:0.1795  g_loss:2.9310
# epoch:604  d_loss:0.3034  g_loss:2.8414
# epoch:605  d_loss:0.3700  g_loss:2.3649
# epoch:606  d_loss:0.3981  g_loss:1.7141
# epoch:607  d_loss:0.1898  g_loss:2.8953
# epoch:608  d_loss:0.3101  g_loss:2.8031
# epoch:609  d_loss:0.2807  g_loss:2.2965
# epoch:610  d_loss:0.1500  g_loss:2.9612
# epoch:611  d_loss:0.3165  g_loss:2.7031
# epoch:612  d_loss:0.2429  g_loss:2.8678
# epoch:613  d_loss:0.2004  g_loss:3.3058
# epoch:614  d_loss:0.2384  g_loss:2.8049
# epoch:615  d_loss:0.2175  g_loss:2.4104
# epoch:616  d_loss:0.1518  g_loss:2.5618
# epoch:617  d_loss:0.2201  g_loss:3.5051
# epoch:618  d_loss:0.1472  g_loss:4.2689
# epoch:619  d_loss:0.1574  g_loss:5.0860
# epoch:620  d_loss:0.4194  g_loss:3.5089
# epoch:621  d_loss:0.1778  g_loss:2.1806
# epoch:622  d_loss:0.1264  g_loss:2.4422
# epoch:623  d_loss:0.1261  g_loss:3.6098
# epoch:624  d_loss:0.0989  g_loss:4.1611
# epoch:625  d_loss:0.1794  g_loss:4.3785
# epoch:626  d_loss:0.1870  g_loss:3.8389
# epoch:627  d_loss:0.0975  g_loss:3.1925
# epoch:628  d_loss:0.1042  g_loss:2.8789
# epoch:629  d_loss:0.1341  g_loss:3.0941
# epoch:630  d_loss:0.1454  g_loss:4.0048
# epoch:631  d_loss:0.0988  g_loss:5.3839
# epoch:632  d_loss:0.2128  g_loss:4.8468
# epoch:633  d_loss:0.2007  g_loss:3.7437
# epoch:634  d_loss:0.1071  g_loss:3.2476
# epoch:635  d_loss:0.2353  g_loss:3.2515
# epoch:636  d_loss:0.2306  g_loss:4.2812
# epoch:637  d_loss:0.1175  g_loss:4.1637
# epoch:638  d_loss:0.2536  g_loss:3.7955
# epoch:639  d_loss:0.2743  g_loss:4.1795
# epoch:640  d_loss:0.2563  g_loss:2.9595
# epoch:641  d_loss:0.3484  g_loss:2.0915
# epoch:642  d_loss:0.2922  g_loss:1.7905
# epoch:643  d_loss:0.3169  g_loss:2.8454
# epoch:644  d_loss:0.2871  g_loss:3.4200
# epoch:645  d_loss:0.4662  g_loss:3.0840
# epoch:646  d_loss:0.3826  g_loss:2.0622
# epoch:647  d_loss:0.5677  g_loss:2.1261
# epoch:648  d_loss:0.1605  g_loss:3.1434
# epoch:649  d_loss:0.3967  g_loss:2.7774
# epoch:650  d_loss:0.3701  g_loss:3.1894
# epoch:651  d_loss:0.6667  g_loss:2.1971
# epoch:652  d_loss:0.2017  g_loss:2.3133
# epoch:653  d_loss:0.2619  g_loss:2.4654
# epoch:654  d_loss:0.2317  g_loss:2.5820
# epoch:655  d_loss:0.2726  g_loss:2.8577
# epoch:656  d_loss:0.2332  g_loss:2.7530
# epoch:657  d_loss:0.2674  g_loss:2.8217
# epoch:658  d_loss:0.2314  g_loss:2.5297
# epoch:659  d_loss:0.2174  g_loss:1.8463
# epoch:660  d_loss:0.2535  g_loss:2.5645
# epoch:661  d_loss:0.1304  g_loss:3.2258
# epoch:662  d_loss:0.3554  g_loss:2.7883
# epoch:663  d_loss:0.2616  g_loss:2.5983
# epoch:664  d_loss:0.1576  g_loss:2.8329
# epoch:665  d_loss:0.2429  g_loss:2.7914
# epoch:666  d_loss:0.2382  g_loss:2.7041
# epoch:667  d_loss:0.1649  g_loss:3.5923
# epoch:668  d_loss:0.1253  g_loss:2.8168
# epoch:669  d_loss:0.2202  g_loss:3.3973
# epoch:670  d_loss:0.1497  g_loss:2.3469
# epoch:671  d_loss:0.1388  g_loss:2.3649
# epoch:672  d_loss:0.1999  g_loss:1.9257
# epoch:673  d_loss:0.1437  g_loss:1.9761
# epoch:674  d_loss:0.1694  g_loss:2.8223
# epoch:675  d_loss:0.2500  g_loss:2.4017
# epoch:676  d_loss:0.1995  g_loss:3.5648
# epoch:677  d_loss:0.2665  g_loss:2.5505
# epoch:678  d_loss:0.1919  g_loss:2.3786
# epoch:679  d_loss:0.1883  g_loss:2.3404
# epoch:680  d_loss:0.2871  g_loss:2.0796
# epoch:681  d_loss:0.2739  g_loss:2.8784
# epoch:682  d_loss:0.2322  g_loss:2.5052
# epoch:683  d_loss:0.2393  g_loss:3.5020
# epoch:684  d_loss:0.4653  g_loss:2.1446
# epoch:685  d_loss:0.3122  g_loss:1.8468
# epoch:686  d_loss:0.3589  g_loss:2.1070
# epoch:687  d_loss:0.1585  g_loss:3.0056
# epoch:688  d_loss:0.3370  g_loss:3.0417
# epoch:689  d_loss:0.4685  g_loss:1.9025
# epoch:690  d_loss:0.4903  g_loss:0.8705
# epoch:691  d_loss:0.3796  g_loss:1.5858
# epoch:692  d_loss:0.3324  g_loss:2.9476
# epoch:693  d_loss:0.4093  g_loss:4.0803
# epoch:694  d_loss:0.4121  g_loss:4.6924
# epoch:695  d_loss:0.5638  g_loss:2.7249
# epoch:696  d_loss:0.4927  g_loss:1.6437
# epoch:697  d_loss:0.4469  g_loss:1.2608
# epoch:698  d_loss:0.3186  g_loss:2.1070
# epoch:699  d_loss:0.2676  g_loss:2.8281
# epoch:700  d_loss:0.1882  g_loss:3.4027
# epoch:701  d_loss:0.4223  g_loss:2.2535
# epoch:702  d_loss:0.3776  g_loss:1.3097
# epoch:703  d_loss:0.5217  g_loss:1.0845
# epoch:704  d_loss:0.4106  g_loss:1.2779
# epoch:705  d_loss:0.2833  g_loss:1.8310
# epoch:706  d_loss:0.6956  g_loss:1.2311
# epoch:707  d_loss:0.5740  g_loss:1.4235
# epoch:708  d_loss:0.4958  g_loss:1.1408
# epoch:709  d_loss:0.6275  g_loss:1.0267
# epoch:710  d_loss:0.6876  g_loss:1.3086
# epoch:711  d_loss:0.3414  g_loss:1.7662
# epoch:712  d_loss:0.4048  g_loss:1.5974
# epoch:713  d_loss:0.4284  g_loss:1.8420
# epoch:714  d_loss:0.3972  g_loss:1.6932
# epoch:715  d_loss:0.3291  g_loss:1.9056
# epoch:716  d_loss:0.4358  g_loss:2.1230
# epoch:717  d_loss:0.3459  g_loss:1.6493
# epoch:718  d_loss:0.3314  g_loss:1.9188
# epoch:719  d_loss:0.4491  g_loss:1.5927
# epoch:720  d_loss:0.5548  g_loss:1.4227
# epoch:721  d_loss:0.4460  g_loss:1.3183
# epoch:722  d_loss:0.4413  g_loss:1.5077
# epoch:723  d_loss:0.6616  g_loss:0.9629
# epoch:724  d_loss:0.3247  g_loss:1.5929
# epoch:725  d_loss:0.3076  g_loss:1.9421
# epoch:726  d_loss:0.5192  g_loss:0.9787
# epoch:727  d_loss:0.4962  g_loss:1.4668
# epoch:728  d_loss:0.4816  g_loss:0.9210
# epoch:729  d_loss:0.5722  g_loss:0.5880
# epoch:730  d_loss:0.6997  g_loss:0.7407
# epoch:731  d_loss:0.8005  g_loss:1.1451
# epoch:732  d_loss:0.4769  g_loss:1.3553
# epoch:733  d_loss:0.5393  g_loss:1.8485
# epoch:734  d_loss:0.5340  g_loss:2.3917
# epoch:735  d_loss:0.5719  g_loss:1.7540
# epoch:736  d_loss:0.4861  g_loss:1.8762
# epoch:737  d_loss:0.9239  g_loss:1.3475
# epoch:738  d_loss:0.8730  g_loss:1.6537
# epoch:739  d_loss:0.6957  g_loss:1.9857
# epoch:740  d_loss:0.9135  g_loss:2.3586
# epoch:741  d_loss:0.4215  g_loss:1.9243
# epoch:742  d_loss:0.8230  g_loss:2.0409
# epoch:743  d_loss:0.7732  g_loss:1.6027
# epoch:744  d_loss:0.8126  g_loss:1.1032
# epoch:745  d_loss:0.6293  g_loss:1.2887
# epoch:746  d_loss:0.4882  g_loss:1.3275
# epoch:747  d_loss:0.4490  g_loss:1.3628
# epoch:748  d_loss:0.2626  g_loss:2.0289
# epoch:749  d_loss:0.4944  g_loss:2.2588
# epoch:750  d_loss:0.5356  g_loss:1.7743
# epoch:751  d_loss:0.6591  g_loss:1.3354
# epoch:752  d_loss:0.8046  g_loss:1.1480
# epoch:753  d_loss:1.2443  g_loss:0.7652
# epoch:754  d_loss:0.3779  g_loss:1.1700
# epoch:755  d_loss:0.3367  g_loss:1.5614
# epoch:756  d_loss:0.2651  g_loss:2.3092
# epoch:757  d_loss:0.2357  g_loss:2.8633
# epoch:758  d_loss:0.3827  g_loss:2.3667
# epoch:759  d_loss:0.3759  g_loss:2.0736
# epoch:760  d_loss:0.7301  g_loss:1.6552
# epoch:761  d_loss:0.3757  g_loss:1.7159
# epoch:762  d_loss:0.4609  g_loss:1.8451
# epoch:763  d_loss:0.5342  g_loss:1.7825
# epoch:764  d_loss:0.5174  g_loss:1.6649
# epoch:765  d_loss:0.7729  g_loss:1.2892
# epoch:766  d_loss:0.4537  g_loss:1.4875
# epoch:767  d_loss:0.6388  g_loss:1.7451
# epoch:768  d_loss:0.3401  g_loss:1.8597
# epoch:769  d_loss:0.4749  g_loss:1.4936
# epoch:770  d_loss:0.3421  g_loss:1.5897
# epoch:771  d_loss:0.3817  g_loss:1.5243
# epoch:772  d_loss:0.5033  g_loss:1.4090
# epoch:773  d_loss:0.4432  g_loss:1.4138
# epoch:774  d_loss:0.4759  g_loss:1.3061
# epoch:775  d_loss:0.4799  g_loss:1.6349
# epoch:776  d_loss:0.5047  g_loss:1.4278
# epoch:777  d_loss:0.6057  g_loss:1.1662
# epoch:778  d_loss:0.4486  g_loss:1.1397
# epoch:779  d_loss:0.4610  g_loss:1.2891
# epoch:780  d_loss:0.4340  g_loss:1.4272
# epoch:781  d_loss:0.3321  g_loss:1.3997
# epoch:782  d_loss:0.3405  g_loss:1.6274
# epoch:783  d_loss:0.3935  g_loss:2.0908
# epoch:784  d_loss:0.3683  g_loss:2.4491
# epoch:785  d_loss:0.4878  g_loss:2.3024
# epoch:786  d_loss:0.4278  g_loss:2.0324
# epoch:787  d_loss:0.5070  g_loss:1.8122
# epoch:788  d_loss:0.6491  g_loss:1.6464
# epoch:789  d_loss:0.4301  g_loss:1.7172
# epoch:790  d_loss:0.2915  g_loss:1.8128
# epoch:791  d_loss:0.4635  g_loss:1.6048
# epoch:792  d_loss:0.4442  g_loss:1.3632
# epoch:793  d_loss:0.5189  g_loss:1.1986
# epoch:794  d_loss:0.6072  g_loss:1.2613
# epoch:795  d_loss:0.4240  g_loss:1.0471
# epoch:796  d_loss:0.4440  g_loss:1.9304
# epoch:797  d_loss:0.4114  g_loss:1.9290
# epoch:798  d_loss:0.6328  g_loss:1.9433
# epoch:799  d_loss:0.5114  g_loss:1.4429
# epoch:800  d_loss:0.5120  g_loss:1.2234
# epoch:801  d_loss:0.5897  g_loss:1.0362
# epoch:802  d_loss:0.5789  g_loss:1.2468
# epoch:803  d_loss:0.4845  g_loss:1.2811
# epoch:804  d_loss:0.4696  g_loss:1.4445
# epoch:805  d_loss:0.7202  g_loss:1.6896
# epoch:806  d_loss:0.8080  g_loss:1.5297
# epoch:807  d_loss:0.7021  g_loss:1.2828
# epoch:808  d_loss:0.7370  g_loss:1.3072
# epoch:809  d_loss:0.7246  g_loss:1.2567
# epoch:810  d_loss:0.6754  g_loss:1.3247
# epoch:811  d_loss:0.5516  g_loss:1.5969
# epoch:812  d_loss:0.4198  g_loss:1.3455
# epoch:813  d_loss:0.3724  g_loss:1.3075
# epoch:814  d_loss:0.4337  g_loss:1.4973
# epoch:815  d_loss:0.3723  g_loss:1.8679
# epoch:816  d_loss:0.3488  g_loss:2.3053
# epoch:817  d_loss:0.4918  g_loss:1.9963
# epoch:818  d_loss:0.4448  g_loss:1.7145
# epoch:819  d_loss:0.4594  g_loss:1.6284
# epoch:820  d_loss:0.4139  g_loss:1.5313
# epoch:821  d_loss:0.5171  g_loss:1.3708
# epoch:822  d_loss:0.6218  g_loss:1.3064
# epoch:823  d_loss:0.4591  g_loss:1.4474
# epoch:824  d_loss:0.5589  g_loss:1.5257
# epoch:825  d_loss:0.6191  g_loss:1.4330
# epoch:826  d_loss:0.4097  g_loss:1.7048
# epoch:827  d_loss:0.5665  g_loss:1.4791
# epoch:828  d_loss:0.4938  g_loss:1.3440
# epoch:829  d_loss:0.3039  g_loss:1.6705
# epoch:830  d_loss:0.4798  g_loss:1.8187
# epoch:831  d_loss:0.4976  g_loss:1.7259
# epoch:832  d_loss:0.3939  g_loss:1.7823
# epoch:833  d_loss:0.3242  g_loss:2.0233
# epoch:834  d_loss:0.3382  g_loss:1.8017
# epoch:835  d_loss:0.3892  g_loss:1.7142
# epoch:836  d_loss:0.3503  g_loss:1.7588
# epoch:837  d_loss:0.3605  g_loss:1.8955
# epoch:838  d_loss:0.3467  g_loss:2.1824
# epoch:839  d_loss:0.2954  g_loss:2.6827
# epoch:840  d_loss:0.3613  g_loss:2.0731
# epoch:841  d_loss:0.3157  g_loss:2.0610
# epoch:842  d_loss:0.2609  g_loss:2.1063
# epoch:843  d_loss:0.3952  g_loss:2.0330
# epoch:844  d_loss:0.3394  g_loss:2.1926
# epoch:845  d_loss:0.2869  g_loss:2.8598
# epoch:846  d_loss:0.3244  g_loss:2.0275
# epoch:847  d_loss:0.3953  g_loss:2.2454
# epoch:848  d_loss:0.4293  g_loss:1.6916
# epoch:849  d_loss:0.2639  g_loss:2.3943
# epoch:850  d_loss:0.5445  g_loss:1.8380
# epoch:851  d_loss:0.3737  g_loss:2.3582
# epoch:852  d_loss:0.4851  g_loss:1.9953
# epoch:853  d_loss:0.5806  g_loss:1.9460
# epoch:854  d_loss:0.5156  g_loss:2.0071
# epoch:855  d_loss:0.5608  g_loss:1.5972
# epoch:856  d_loss:0.7212  g_loss:1.3350
# epoch:857  d_loss:0.5320  g_loss:1.3497
# epoch:858  d_loss:0.6673  g_loss:1.5915
# epoch:859  d_loss:0.6762  g_loss:1.5477
# epoch:860  d_loss:0.5354  g_loss:1.4550
# epoch:861  d_loss:0.4959  g_loss:1.6383
# epoch:862  d_loss:0.5368  g_loss:1.5348
# epoch:863  d_loss:0.4295  g_loss:1.9725
# epoch:864  d_loss:0.3626  g_loss:1.8912
# epoch:865  d_loss:0.3201  g_loss:1.9168
# epoch:866  d_loss:0.4013  g_loss:1.8411
# epoch:867  d_loss:0.2600  g_loss:2.3441
# epoch:868  d_loss:0.3236  g_loss:2.5555
# epoch:869  d_loss:0.3455  g_loss:2.3026
# epoch:870  d_loss:0.3305  g_loss:1.8323
# epoch:871  d_loss:0.4310  g_loss:1.6657
# epoch:872  d_loss:0.2602  g_loss:2.3527
# epoch:873  d_loss:0.3934  g_loss:2.4302
# epoch:874  d_loss:0.4178  g_loss:2.9859
# epoch:875  d_loss:0.5242  g_loss:1.9564
# epoch:876  d_loss:0.3851  g_loss:1.9923
# epoch:877  d_loss:0.4994  g_loss:1.9069
# epoch:878  d_loss:0.4507  g_loss:1.8097
# epoch:879  d_loss:0.4968  g_loss:2.1259
# epoch:880  d_loss:0.4300  g_loss:2.3527
# epoch:881  d_loss:0.6360  g_loss:2.3171
# epoch:882  d_loss:0.4521  g_loss:2.4506
# epoch:883  d_loss:0.6946  g_loss:1.7706
# epoch:884  d_loss:0.6138  g_loss:1.7669
# epoch:885  d_loss:0.5782  g_loss:1.5750
# epoch:886  d_loss:0.7236  g_loss:1.3876
# epoch:887  d_loss:0.7129  g_loss:1.4029
# epoch:888  d_loss:0.8237  g_loss:1.6183
# epoch:889  d_loss:0.6596  g_loss:1.3842
# epoch:890  d_loss:0.4194  g_loss:1.2217
# epoch:891  d_loss:0.5265  g_loss:1.4971
# epoch:892  d_loss:0.4020  g_loss:1.7307
# epoch:893  d_loss:0.4527  g_loss:1.6878
# epoch:894  d_loss:0.4550  g_loss:2.1852
# epoch:895  d_loss:0.4739  g_loss:1.5677
# epoch:896  d_loss:0.4834  g_loss:1.6360
# epoch:897  d_loss:0.3789  g_loss:2.1555
# epoch:898  d_loss:0.3455  g_loss:2.1494
# epoch:899  d_loss:0.2641  g_loss:2.2128
# epoch:900  d_loss:0.3060  g_loss:2.4790
# epoch:901  d_loss:0.3234  g_loss:2.2268
# epoch:902  d_loss:0.3026  g_loss:2.2124
# epoch:903  d_loss:0.2377  g_loss:2.3615
# epoch:904  d_loss:0.2212  g_loss:2.7051
# epoch:905  d_loss:0.2571  g_loss:2.7995
# epoch:906  d_loss:0.1604  g_loss:3.0271
# epoch:907  d_loss:0.2893  g_loss:2.5779
# epoch:908  d_loss:0.2565  g_loss:2.8112
# epoch:909  d_loss:0.2983  g_loss:2.6183
# epoch:910  d_loss:0.2775  g_loss:2.4377
# epoch:911  d_loss:0.4176  g_loss:2.2182
# epoch:912  d_loss:0.3396  g_loss:2.0582
# epoch:913  d_loss:0.4939  g_loss:2.0533
# epoch:914  d_loss:0.4284  g_loss:2.3625
# epoch:915  d_loss:0.4434  g_loss:2.0271
# epoch:916  d_loss:0.6179  g_loss:2.0249
# epoch:917  d_loss:0.5574  g_loss:2.2555
# epoch:918  d_loss:0.5025  g_loss:1.6288
# epoch:919  d_loss:0.5711  g_loss:1.6268
# epoch:920  d_loss:0.5714  g_loss:1.5516
# epoch:921  d_loss:0.5046  g_loss:1.6988
# epoch:922  d_loss:0.5150  g_loss:1.7402
# epoch:923  d_loss:0.3450  g_loss:2.1185
# epoch:924  d_loss:0.4127  g_loss:2.2239
# epoch:925  d_loss:0.5068  g_loss:1.8043
# epoch:926  d_loss:0.3537  g_loss:1.6751
# epoch:927  d_loss:0.3031  g_loss:2.0091
# epoch:928  d_loss:0.2846  g_loss:2.4641
# epoch:929  d_loss:0.3290  g_loss:2.5048
# epoch:930  d_loss:0.2226  g_loss:3.0891
# epoch:931  d_loss:0.4157  g_loss:2.4442
# epoch:932  d_loss:0.3680  g_loss:2.5926
# epoch:933  d_loss:0.2354  g_loss:2.7060
# epoch:934  d_loss:0.2319  g_loss:2.4211
# epoch:935  d_loss:0.2408  g_loss:2.5376
# epoch:936  d_loss:0.3078  g_loss:2.8167
# epoch:937  d_loss:0.2418  g_loss:2.7140
# epoch:938  d_loss:0.2065  g_loss:3.0864
# epoch:939  d_loss:0.2020  g_loss:3.2326
# epoch:940  d_loss:0.2548  g_loss:2.7876
# epoch:941  d_loss:0.2039  g_loss:2.6369
# epoch:942  d_loss:0.3178  g_loss:2.2477
# epoch:943  d_loss:0.3632  g_loss:1.8976
# epoch:944  d_loss:0.2547  g_loss:2.2535
# epoch:945  d_loss:0.3347  g_loss:2.3923
# epoch:946  d_loss:0.3751  g_loss:2.6844
# epoch:947  d_loss:0.4285  g_loss:2.2978
# epoch:948  d_loss:0.2603  g_loss:2.6438
# epoch:949  d_loss:0.4025  g_loss:2.1645
# epoch:950  d_loss:0.5539  g_loss:1.7699
# epoch:951  d_loss:0.5636  g_loss:1.2271
# epoch:952  d_loss:0.7258  g_loss:1.4116
# epoch:953  d_loss:0.6155  g_loss:1.9643
# epoch:954  d_loss:0.8356  g_loss:1.7924
# epoch:955  d_loss:0.5448  g_loss:1.8910
# epoch:956  d_loss:0.5812  g_loss:1.7698
# epoch:957  d_loss:0.5457  g_loss:1.3086
# epoch:958  d_loss:0.5776  g_loss:1.3193
# epoch:959  d_loss:0.5783  g_loss:1.3682
# epoch:960  d_loss:0.4982  g_loss:1.5990
# epoch:961  d_loss:0.3471  g_loss:2.0660
# epoch:962  d_loss:0.5858  g_loss:1.9732
# epoch:963  d_loss:0.5737  g_loss:1.6149
# epoch:964  d_loss:0.5195  g_loss:1.4617
# epoch:965  d_loss:0.3953  g_loss:1.7464
# epoch:966  d_loss:0.4205  g_loss:1.6015
# epoch:967  d_loss:0.4664  g_loss:1.9890
# epoch:968  d_loss:0.3830  g_loss:1.9548
# epoch:969  d_loss:0.4565  g_loss:2.0370
# epoch:970  d_loss:0.4294  g_loss:2.1098
# epoch:971  d_loss:0.4436  g_loss:2.1076
# epoch:972  d_loss:0.3649  g_loss:2.2130
# epoch:973  d_loss:0.3865  g_loss:2.3345
# epoch:974  d_loss:0.5460  g_loss:2.0055
# epoch:975  d_loss:0.4905  g_loss:1.6953
# epoch:976  d_loss:0.4152  g_loss:1.8328
# epoch:977  d_loss:0.3544  g_loss:2.1912
# epoch:978  d_loss:0.3769  g_loss:1.9896
# epoch:979  d_loss:0.4662  g_loss:2.1693
# epoch:980  d_loss:0.4181  g_loss:2.0707
# epoch:981  d_loss:0.4887  g_loss:1.9614
# epoch:982  d_loss:0.3879  g_loss:1.8137
# epoch:983  d_loss:0.5925  g_loss:1.4300
# epoch:984  d_loss:0.5250  g_loss:1.5807
# epoch:985  d_loss:0.6248  g_loss:1.2627
# epoch:986  d_loss:0.3957  g_loss:2.0203
# epoch:987  d_loss:0.5563  g_loss:1.7728
# epoch:988  d_loss:0.5214  g_loss:1.3849
# epoch:989  d_loss:0.5170  g_loss:1.2520
# epoch:990  d_loss:0.5439  g_loss:1.5893
# epoch:991  d_loss:0.5807  g_loss:1.4744
# epoch:992  d_loss:0.4807  g_loss:1.6904
# epoch:993  d_loss:0.5150  g_loss:1.8172
# epoch:994  d_loss:0.4108  g_loss:2.0159
# epoch:995  d_loss:0.4391  g_loss:1.8439
# epoch:996  d_loss:0.6215  g_loss:1.5676
# epoch:997  d_loss:0.4933  g_loss:2.0584
# epoch:998  d_loss:0.3921  g_loss:1.7613
# epoch:999  d_loss:0.4562  g_loss:2.2077
# epoch:1000  d_loss:0.3970  g_loss:1.7113
# epoch:1001  d_loss:0.4438  g_loss:2.2703
# epoch:1002  d_loss:0.3384  g_loss:2.6633
# epoch:1003  d_loss:0.4240  g_loss:2.5184
# epoch:1004  d_loss:0.4322  g_loss:2.0545
# epoch:1005  d_loss:0.4406  g_loss:2.0204
# epoch:1006  d_loss:0.3207  g_loss:2.4022
# epoch:1007  d_loss:0.3281  g_loss:2.2065
# epoch:1008  d_loss:0.3670  g_loss:2.2801
# epoch:1009  d_loss:0.3671  g_loss:2.4838
# epoch:1010  d_loss:0.2345  g_loss:2.6634
# epoch:1011  d_loss:0.2134  g_loss:2.5220
# epoch:1012  d_loss:0.2177  g_loss:2.4075
# epoch:1013  d_loss:0.2711  g_loss:2.0943
# epoch:1014  d_loss:0.2845  g_loss:2.2792
# epoch:1015  d_loss:0.3890  g_loss:1.9961
# epoch:1016  d_loss:0.3544  g_loss:2.3413
# epoch:1017  d_loss:0.3115  g_loss:2.5726
# epoch:1018  d_loss:0.3403  g_loss:2.3655
# epoch:1019  d_loss:0.3635  g_loss:2.4720
# epoch:1020  d_loss:0.3817  g_loss:1.9849
# epoch:1021  d_loss:0.5033  g_loss:2.1230
# epoch:1022  d_loss:0.5043  g_loss:1.9038
# epoch:1023  d_loss:0.4106  g_loss:1.6604
# epoch:1024  d_loss:0.5887  g_loss:1.7222
# epoch:1025  d_loss:0.5756  g_loss:1.9816
# epoch:1026  d_loss:0.6423  g_loss:1.7321
# epoch:1027  d_loss:0.5644  g_loss:1.9792
# epoch:1028  d_loss:0.5516  g_loss:1.8567
# epoch:1029  d_loss:0.7867  g_loss:1.2375
# epoch:1030  d_loss:0.7769  g_loss:1.2502
# epoch:1031  d_loss:0.5585  g_loss:1.3060
# epoch:1032  d_loss:0.5974  g_loss:1.1233
# epoch:1033  d_loss:0.5892  g_loss:1.3284
# epoch:1034  d_loss:0.6411  g_loss:1.5029
# epoch:1035  d_loss:0.5506  g_loss:1.6391
# epoch:1036  d_loss:0.4700  g_loss:1.3867
# epoch:1037  d_loss:0.4668  g_loss:1.6918
# epoch:1038  d_loss:0.3447  g_loss:1.8800
# epoch:1039  d_loss:0.3548  g_loss:1.9462
# epoch:1040  d_loss:0.2796  g_loss:2.5969
# epoch:1041  d_loss:0.2993  g_loss:2.9001
# epoch:1042  d_loss:0.3310  g_loss:2.3407
# epoch:1043  d_loss:0.2465  g_loss:2.3165
# epoch:1044  d_loss:0.2598  g_loss:2.5649
# epoch:1045  d_loss:0.2440  g_loss:2.7438
# epoch:1046  d_loss:0.3142  g_loss:2.7928
# epoch:1047  d_loss:0.2971  g_loss:2.4962
# epoch:1048  d_loss:0.3025  g_loss:2.2927
# epoch:1049  d_loss:0.3268  g_loss:2.2551
# epoch:1050  d_loss:0.2484  g_loss:2.0566
# epoch:1051  d_loss:0.2962  g_loss:2.1638
# epoch:1052  d_loss:0.1987  g_loss:2.4688
# epoch:1053  d_loss:0.3593  g_loss:2.0819
# epoch:1054  d_loss:0.4060  g_loss:2.7040
# epoch:1055  d_loss:0.4044  g_loss:2.4359
# epoch:1056  d_loss:0.6745  g_loss:1.6162
# epoch:1057  d_loss:0.3571  g_loss:2.1962
# epoch:1058  d_loss:0.3216  g_loss:2.4927
# epoch:1059  d_loss:0.3264  g_loss:1.8954
# epoch:1060  d_loss:0.5394  g_loss:2.0805
# epoch:1061  d_loss:0.4754  g_loss:2.2215
# epoch:1062  d_loss:0.7582  g_loss:1.6681
# epoch:1063  d_loss:0.4583  g_loss:1.4970
# epoch:1064  d_loss:0.5344  g_loss:1.2107
# epoch:1065  d_loss:0.5796  g_loss:1.6239
# epoch:1066  d_loss:0.5917  g_loss:1.9902
# epoch:1067  d_loss:0.4661  g_loss:2.1084
# epoch:1068  d_loss:0.5858  g_loss:1.7555
# epoch:1069  d_loss:0.5305  g_loss:1.5276
# epoch:1070  d_loss:0.6956  g_loss:1.2871
# epoch:1071  d_loss:0.3442  g_loss:1.6321
# epoch:1072  d_loss:0.2847  g_loss:2.0654
# epoch:1073  d_loss:0.3951  g_loss:2.2494
# epoch:1074  d_loss:0.4489  g_loss:2.0544
# epoch:1075  d_loss:0.5287  g_loss:1.7666
# epoch:1076  d_loss:0.3706  g_loss:1.9385
# epoch:1077  d_loss:0.3060  g_loss:1.7510
# epoch:1078  d_loss:0.3070  g_loss:2.0263
# epoch:1079  d_loss:0.2095  g_loss:2.5262
# epoch:1080  d_loss:0.2469  g_loss:2.8994
# epoch:1081  d_loss:0.2631  g_loss:2.5677
# epoch:1082  d_loss:0.3447  g_loss:2.0503
# epoch:1083  d_loss:0.3691  g_loss:1.7131
# epoch:1084  d_loss:0.2709  g_loss:1.8609
# epoch:1085  d_loss:0.3008  g_loss:2.4094
# epoch:1086  d_loss:0.3067  g_loss:2.2783
# epoch:1087  d_loss:0.2720  g_loss:2.5562
# epoch:1088  d_loss:0.3028  g_loss:3.0023
# epoch:1089  d_loss:0.3469  g_loss:1.8435
# epoch:1090  d_loss:0.2889  g_loss:2.2875
# epoch:1091  d_loss:0.3212  g_loss:2.4670
# epoch:1092  d_loss:0.4855  g_loss:2.0735
# epoch:1093  d_loss:0.4007  g_loss:1.9457
# epoch:1094  d_loss:0.3750  g_loss:1.9473
# epoch:1095  d_loss:0.6552  g_loss:1.6137
# epoch:1096  d_loss:0.4000  g_loss:2.1893
# epoch:1097  d_loss:0.4601  g_loss:2.4314
# epoch:1098  d_loss:0.4337  g_loss:2.0835
# epoch:1099  d_loss:0.5966  g_loss:1.7209
# epoch:1100  d_loss:0.6134  g_loss:1.9219
# epoch:1101  d_loss:0.5925  g_loss:1.6888
# epoch:1102  d_loss:0.6185  g_loss:1.4841
# epoch:1103  d_loss:0.6169  g_loss:1.4407
# epoch:1104  d_loss:0.5594  g_loss:1.9132
# epoch:1105  d_loss:0.5538  g_loss:1.8818
# epoch:1106  d_loss:0.6797  g_loss:1.3681
# epoch:1107  d_loss:0.5432  g_loss:1.4916
# epoch:1108  d_loss:0.6630  g_loss:1.2480
# epoch:1109  d_loss:0.5816  g_loss:1.3632
# ...
# epoch:1611  d_loss:0.4543  g_loss:1.6339
# epoch:1612  d_loss:0.3529  g_loss:2.0341
# epoch:1613  d_loss:0.6826  g_loss:1.4709
# epoch:1614  d_loss:0.5586  g_loss:1.3261
# epoch:1615  d_loss:0.3944  g_loss:1.5851
# epoch:1616  d_loss:0.3008  g_loss:2.1833
# epoch:1617  d_loss:0.4322  g_loss:1.8233
# epoch:1618  d_loss:0.5792  g_loss:1.2886
# epoch:1619  d_loss:0.4158  g_loss:1.6320
# epoch:1620  d_loss:0.5131  g_loss:1.5141
# epoch:1621  d_loss:0.3790  g_loss:1.6404
# epoch:1622  d_loss:0.3829  g_loss:1.6657
# epoch:1623  d_loss:0.4467  g_loss:1.7118
# epoch:1624  d_loss:0.4959  g_loss:1.6215
# epoch:1625  d_loss:0.4523  g_loss:1.7472
# epoch:1626  d_loss:0.3633  g_loss:1.5783
# epoch:1627  d_loss:0.4014  g_loss:2.0287
# epoch:1628  d_loss:0.4349  g_loss:1.3636
# epoch:1629  d_loss:0.3978  g_loss:1.6835
# epoch:1630  d_loss:0.4271  g_loss:1.9461
# epoch:1631  d_loss:0.5381  g_loss:1.8022
# epoch:1632  d_loss:0.4554  g_loss:1.8775
# epoch:1633  d_loss:0.3822  g_loss:1.4354
# epoch:1634  d_loss:0.4533  g_loss:1.4323
# epoch:1635  d_loss:0.3632  g_loss:1.7270
# epoch:1636  d_loss:0.5695  g_loss:1.5049
# epoch:1637  d_loss:0.4847  g_loss:1.4670
# epoch:1638  d_loss:0.5828  g_loss:1.5040
# epoch:1639  d_loss:0.5417  g_loss:1.4522
# epoch:1640  d_loss:0.6195  g_loss:1.2238
# epoch:1641  d_loss:0.5453  g_loss:1.4139
# epoch:1642  d_loss:0.5700  g_loss:1.4511
# epoch:1643  d_loss:0.5269  g_loss:1.5902
# epoch:1644  d_loss:0.5874  g_loss:1.5997
# epoch:1645  d_loss:0.6181  g_loss:1.5673
# epoch:1646  d_loss:0.4703  g_loss:1.5008
# epoch:1647  d_loss:0.5349  g_loss:1.2909
# epoch:1648  d_loss:0.5807  g_loss:1.4327
# epoch:1649  d_loss:0.3944  g_loss:1.9376
# epoch:1650  d_loss:0.5890  g_loss:1.5170
# epoch:1651  d_loss:0.5639  g_loss:1.8117
# epoch:1652  d_loss:0.3707  g_loss:1.5855
# epoch:1653  d_loss:0.6204  g_loss:1.2790
# epoch:1654  d_loss:0.3987  g_loss:1.9816
# epoch:1655  d_loss:0.4976  g_loss:1.5686
# epoch:1656  d_loss:0.4992  g_loss:1.3990
# epoch:1657  d_loss:0.4156  g_loss:1.7841
# epoch:1658  d_loss:0.5014  g_loss:1.4266
# epoch:1659  d_loss:0.3902  g_loss:1.8103
# epoch:1660  d_loss:0.5706  g_loss:1.7553
# epoch:1661  d_loss:0.4047  g_loss:1.8270
# epoch:1662  d_loss:0.4065  g_loss:1.5424
# epoch:1663  d_loss:0.5009  g_loss:1.4296
# epoch:1664  d_loss:0.4242  g_loss:1.7704
# epoch:1665  d_loss:0.3950  g_loss:1.8763
# epoch:1666  d_loss:0.3552  g_loss:1.7372
# epoch:1667  d_loss:0.4039  g_loss:2.1057
# epoch:1668  d_loss:0.3891  g_loss:1.9431
# epoch:1669  d_loss:0.4695  g_loss:1.6761
# epoch:1670  d_loss:0.5571  g_loss:1.4367
# epoch:1671  d_loss:0.3515  g_loss:1.7848
# epoch:1672  d_loss:0.4929  g_loss:1.8155
# epoch:1673  d_loss:0.5135  g_loss:2.1948
# epoch:1674  d_loss:0.4196  g_loss:2.1839
# epoch:1675  d_loss:0.4052  g_loss:1.9202
# epoch:1676  d_loss:0.3718  g_loss:2.0286
# epoch:1677  d_loss:0.4180  g_loss:1.6509
# epoch:1678  d_loss:0.5847  g_loss:1.4814
# epoch:1679  d_loss:0.7330  g_loss:1.6012
# epoch:1680  d_loss:0.5457  g_loss:1.5883
# epoch:1681  d_loss:0.4021  g_loss:1.9095
# epoch:1682  d_loss:0.4561  g_loss:1.8384
# epoch:1683  d_loss:0.5285  g_loss:1.6205
# epoch:1684  d_loss:0.4598  g_loss:1.8765
# epoch:1685  d_loss:0.4955  g_loss:1.6252
# epoch:1686  d_loss:0.6385  g_loss:1.2617
# epoch:1687  d_loss:0.3729  g_loss:2.1152
# epoch:1688  d_loss:0.4305  g_loss:1.8740
# epoch:1689  d_loss:0.5174  g_loss:1.8084
# epoch:1690  d_loss:0.6586  g_loss:1.6650
# epoch:1691  d_loss:0.6710  g_loss:1.1910
# epoch:1692  d_loss:0.6067  g_loss:1.2619
# epoch:1693  d_loss:0.5126  g_loss:1.2191
# epoch:1694  d_loss:0.5754  g_loss:1.2951
# epoch:1695  d_loss:0.4887  g_loss:1.8175
# epoch:1696  d_loss:0.5549  g_loss:1.7900
# epoch:1697  d_loss:0.5428  g_loss:1.6978
# epoch:1698  d_loss:0.4799  g_loss:1.0586
# epoch:1699  d_loss:0.5280  g_loss:1.3919
# epoch:1700  d_loss:0.4903  g_loss:1.4987
# epoch:1701  d_loss:0.3976  g_loss:1.8071
# epoch:1702  d_loss:0.4637  g_loss:1.5869
# epoch:1703  d_loss:0.4541  g_loss:1.7162
# epoch:1704  d_loss:0.3932  g_loss:1.7781
# epoch:1705  d_loss:0.4598  g_loss:1.4548
# epoch:1706  d_loss:0.5017  g_loss:1.5842
# epoch:1707  d_loss:0.4166  g_loss:1.5706
# epoch:1708  d_loss:0.3709  g_loss:1.6662
# epoch:1709  d_loss:0.4710  g_loss:2.0176
# epoch:1710  d_loss:0.4440  g_loss:1.9386
# epoch:1711  d_loss:0.3999  g_loss:1.7325
# epoch:1712  d_loss:0.4955  g_loss:1.6827
# epoch:1713  d_loss:0.4690  g_loss:1.4757
# epoch:1714  d_loss:0.4911  g_loss:1.2579
# epoch:1715  d_loss:0.4707  g_loss:1.6824
# epoch:1716  d_loss:0.6551  g_loss:1.4805
# epoch:1717  d_loss:0.4634  g_loss:2.1488
# epoch:1718  d_loss:0.4103  g_loss:2.4479
# epoch:1719  d_loss:0.4854  g_loss:2.3554
# epoch:1720  d_loss:0.6795  g_loss:1.5141
# epoch:1721  d_loss:0.4986  g_loss:1.5135
# epoch:1722  d_loss:0.5910  g_loss:1.2774
# epoch:1723  d_loss:0.5101  g_loss:1.4919
# epoch:1724  d_loss:0.5726  g_loss:1.4139
# epoch:1725  d_loss:0.4639  g_loss:1.7503
# epoch:1726  d_loss:0.5221  g_loss:1.6429
# epoch:1727  d_loss:0.5986  g_loss:2.0096
# epoch:1728  d_loss:0.5387  g_loss:1.8846
# epoch:1729  d_loss:0.4905  g_loss:1.7635
# epoch:1730  d_loss:0.4556  g_loss:1.3740
# epoch:1731  d_loss:0.4472  g_loss:1.2244
# epoch:1732  d_loss:0.5415  g_loss:1.5169
# epoch:1733  d_loss:0.5098  g_loss:1.5442
# epoch:1734  d_loss:0.3897  g_loss:2.0208
# epoch:1735  d_loss:0.4563  g_loss:2.3871
# epoch:1736  d_loss:0.3998  g_loss:2.1507
# epoch:1737  d_loss:0.3836  g_loss:2.1480
# epoch:1738  d_loss:0.3769  g_loss:1.7603
# epoch:1739  d_loss:0.5039  g_loss:1.5711
# epoch:1740  d_loss:0.4474  g_loss:1.5959
# epoch:1741  d_loss:0.4829  g_loss:1.8076
# epoch:1742  d_loss:0.4155  g_loss:1.6754
# epoch:1743  d_loss:0.3455  g_loss:2.4612
# epoch:1744  d_loss:0.4810  g_loss:2.1327
# epoch:1745  d_loss:0.5110  g_loss:1.9011
# epoch:1746  d_loss:0.4697  g_loss:1.7614
# epoch:1747  d_loss:0.4854  g_loss:1.5507
# epoch:1748  d_loss:0.5661  g_loss:1.5929
# epoch:1749  d_loss:0.4544  g_loss:1.3616
# epoch:1750  d_loss:0.4090  g_loss:1.7211
# epoch:1751  d_loss:0.4743  g_loss:1.8915
# epoch:1752  d_loss:0.6639  g_loss:1.4262
# epoch:1753  d_loss:0.5579  g_loss:1.5637
# epoch:1754  d_loss:0.4068  g_loss:1.7103
# epoch:1755  d_loss:0.4076  g_loss:1.6286
# epoch:1756  d_loss:0.5178  g_loss:1.5414
# epoch:1757  d_loss:0.6876  g_loss:1.6845
# epoch:1758  d_loss:0.4612  g_loss:1.3823
# epoch:1759  d_loss:0.6042  g_loss:1.3452
# epoch:1760  d_loss:0.5612  g_loss:1.4202
# epoch:1761  d_loss:0.5611  g_loss:1.7544
# epoch:1762  d_loss:0.4956  g_loss:1.7566
# epoch:1763  d_loss:0.4955  g_loss:1.6612
# epoch:1764  d_loss:0.5136  g_loss:1.4587
# epoch:1765  d_loss:0.5888  g_loss:1.3073
# epoch:1766  d_loss:0.5372  g_loss:1.3792
# epoch:1767  d_loss:0.5710  g_loss:1.4630
# epoch:1768  d_loss:0.5174  g_loss:1.6343
# epoch:1769  d_loss:0.5042  g_loss:1.8116
# epoch:1770  d_loss:0.6208  g_loss:1.6177
# epoch:1771  d_loss:0.5817  g_loss:1.3217
# epoch:1772  d_loss:0.5489  g_loss:1.2890
# epoch:1773  d_loss:0.4126  g_loss:1.4185
# epoch:1774  d_loss:0.4655  g_loss:1.6504
# epoch:1775  d_loss:0.4577  g_loss:1.8875
# epoch:1776  d_loss:0.4312  g_loss:1.6086
# epoch:1777  d_loss:0.4630  g_loss:1.6205
# epoch:1778  d_loss:0.4760  g_loss:1.6382
# epoch:1779  d_loss:0.4099  g_loss:1.6542
# epoch:1780  d_loss:0.4687  g_loss:1.4676
# epoch:1781  d_loss:0.4642  g_loss:1.7513
# epoch:1782  d_loss:0.4052  g_loss:1.6917
# epoch:1783  d_loss:0.4163  g_loss:1.9009
# epoch:1784  d_loss:0.4637  g_loss:1.9581
# epoch:1785  d_loss:0.3404  g_loss:1.7808
# epoch:1786  d_loss:0.4968  g_loss:1.7303
# epoch:1787  d_loss:0.4094  g_loss:1.6355
# epoch:1788  d_loss:0.3517  g_loss:1.7408
# epoch:1789  d_loss:0.3358  g_loss:1.9745
# epoch:1790  d_loss:0.3482  g_loss:2.0934
# epoch:1791  d_loss:0.3549  g_loss:2.2619
# epoch:1792  d_loss:0.4549  g_loss:1.8437
# epoch:1793  d_loss:0.4243  g_loss:1.4893
# epoch:1794  d_loss:0.4296  g_loss:1.3394
# epoch:1795  d_loss:0.4078  g_loss:1.7386
# epoch:1796  d_loss:0.6221  g_loss:1.7246
# epoch:1797  d_loss:0.5132  g_loss:1.8934
# epoch:1798  d_loss:0.4992  g_loss:1.6218
# epoch:1799  d_loss:0.4978  g_loss:1.8100
# epoch:1800  d_loss:0.6325  g_loss:1.9311
# epoch:1801  d_loss:0.4953  g_loss:1.4111
# epoch:1802  d_loss:0.6530  g_loss:1.1730
# epoch:1803  d_loss:0.6341  g_loss:1.4180
# epoch:1804  d_loss:0.5496  g_loss:1.8311
# epoch:1805  d_loss:0.4740  g_loss:1.6123
# epoch:1806  d_loss:0.5033  g_loss:1.9607
# epoch:1807  d_loss:0.4461  g_loss:1.5532
# epoch:1808  d_loss:0.6054  g_loss:1.4549
# epoch:1809  d_loss:0.4571  g_loss:1.5008
# epoch:1810  d_loss:0.6674  g_loss:1.3149
# epoch:1811  d_loss:0.4376  g_loss:1.6957
# epoch:1812  d_loss:0.5342  g_loss:2.1183
# epoch:1813  d_loss:0.5332  g_loss:1.3462
# epoch:1814  d_loss:0.5274  g_loss:1.5312
# epoch:1815  d_loss:0.4664  g_loss:1.1913
# epoch:1816  d_loss:0.5067  g_loss:1.5626
# epoch:1817  d_loss:0.4699  g_loss:1.3955
# epoch:1818  d_loss:0.5703  g_loss:1.6242
# epoch:1819  d_loss:0.5485  g_loss:1.7266
# epoch:1820  d_loss:0.6429  g_loss:1.4836
# epoch:1821  d_loss:0.4090  g_loss:1.6780
# epoch:1822  d_loss:0.5569  g_loss:1.2441
# epoch:1823  d_loss:0.4625  g_loss:2.1387
# epoch:1824  d_loss:0.6167  g_loss:1.9765
# epoch:1825  d_loss:0.4079  g_loss:2.1680
# epoch:1826  d_loss:0.5188  g_loss:1.9531
# epoch:1827  d_loss:0.4551  g_loss:1.5991
# epoch:1828  d_loss:0.4132  g_loss:1.8429
# epoch:1829  d_loss:0.5191  g_loss:1.4174
# epoch:1830  d_loss:0.4446  g_loss:1.3421
# epoch:1831  d_loss:0.4925  g_loss:1.4167
# epoch:1832  d_loss:0.5415  g_loss:1.9204
# epoch:1833  d_loss:0.4999  g_loss:1.9123
# epoch:1834  d_loss:0.5078  g_loss:1.4947
# epoch:1835  d_loss:0.3625  g_loss:1.6481
# epoch:1836  d_loss:0.6153  g_loss:1.6517
# epoch:1837  d_loss:0.5575  g_loss:1.2537
# epoch:1838  d_loss:0.4364  g_loss:1.8312
# epoch:1839  d_loss:0.4232  g_loss:1.8188
# epoch:1840  d_loss:0.4695  g_loss:1.7339
# epoch:1841  d_loss:0.6349  g_loss:1.2278
# epoch:1842  d_loss:0.4308  g_loss:1.7123
# epoch:1843  d_loss:0.5528  g_loss:1.7762
# epoch:1844  d_loss:0.3795  g_loss:1.6021
# epoch:1845  d_loss:0.4451  g_loss:1.5323
# epoch:1846  d_loss:0.5948  g_loss:1.4392
# epoch:1847  d_loss:0.4641  g_loss:1.4371
# epoch:1848  d_loss:0.5082  g_loss:1.5114
# epoch:1849  d_loss:0.5252  g_loss:1.6429
# epoch:1850  d_loss:0.4532  g_loss:1.9143
# epoch:1851  d_loss:0.6626  g_loss:1.8056
# epoch:1852  d_loss:0.7225  g_loss:1.1874
# epoch:1853  d_loss:0.6420  g_loss:1.2650
# epoch:1854  d_loss:0.5973  g_loss:1.1463
# epoch:1855  d_loss:0.6081  g_loss:1.2285
# epoch:1856  d_loss:0.4579  g_loss:1.9922
# epoch:1857  d_loss:0.4707  g_loss:2.2548
# epoch:1858  d_loss:0.5230  g_loss:1.5795
# epoch:1859  d_loss:0.5848  g_loss:1.3593
# epoch:1860  d_loss:0.4765  g_loss:1.3504
# epoch:1861  d_loss:0.4929  g_loss:1.2169
# epoch:1862  d_loss:0.4184  g_loss:1.6610
# epoch:1863  d_loss:0.3913  g_loss:1.9698
# epoch:1864  d_loss:0.5244  g_loss:1.7382
# epoch:1865  d_loss:0.4202  g_loss:1.9383
# epoch:1866  d_loss:0.4509  g_loss:1.7656
# epoch:1867  d_loss:0.6522  g_loss:1.3511
# epoch:1868  d_loss:0.4333  g_loss:1.5300
# epoch:1869  d_loss:0.4496  g_loss:1.9505
# epoch:1870  d_loss:0.4393  g_loss:1.7529
# epoch:1871  d_loss:0.3502  g_loss:1.8723
# epoch:1872  d_loss:0.5417  g_loss:1.9836
# epoch:1873  d_loss:0.5369  g_loss:1.5160
# epoch:1874  d_loss:0.4295  g_loss:1.4974
# epoch:1875  d_loss:0.5527  g_loss:1.6230
# epoch:1876  d_loss:0.5347  g_loss:1.3864
# epoch:1877  d_loss:0.3959  g_loss:1.8238
# epoch:1878  d_loss:0.5055  g_loss:2.1408
# epoch:1879  d_loss:0.5096  g_loss:1.4924
# epoch:1880  d_loss:0.7578  g_loss:1.3278
# epoch:1881  d_loss:0.5002  g_loss:1.5869
# epoch:1882  d_loss:0.5127  g_loss:1.4408
# epoch:1883  d_loss:0.6203  g_loss:1.3622
# epoch:1884  d_loss:0.6611  g_loss:1.2697
# epoch:1885  d_loss:0.5895  g_loss:1.5015
# epoch:1886  d_loss:0.6772  g_loss:1.3043
# epoch:1887  d_loss:0.6337  g_loss:1.2844
# epoch:1888  d_loss:0.6034  g_loss:1.3443
# epoch:1889  d_loss:0.7394  g_loss:1.1965
# epoch:1890  d_loss:0.5559  g_loss:1.3767
# epoch:1891  d_loss:0.4932  g_loss:1.1223
# epoch:1892  d_loss:0.4814  g_loss:1.5380
# epoch:1893  d_loss:0.5606  g_loss:1.3332
# epoch:1894  d_loss:0.5175  g_loss:1.7784
# epoch:1895  d_loss:0.6870  g_loss:1.3421
# epoch:1896  d_loss:0.6217  g_loss:1.2263
# epoch:1897  d_loss:0.6338  g_loss:1.2508
# epoch:1898  d_loss:0.5010  g_loss:1.2353
# epoch:1899  d_loss:0.5280  g_loss:1.4929
# epoch:1900  d_loss:0.4436  g_loss:1.6005
# epoch:1901  d_loss:0.4458  g_loss:1.6207
# epoch:1902  d_loss:0.4155  g_loss:1.5135
# epoch:1903  d_loss:0.4635  g_loss:1.6442
# epoch:1904  d_loss:0.4267  g_loss:1.6728
# epoch:1905  d_loss:0.4546  g_loss:1.5591
# epoch:1906  d_loss:0.4430  g_loss:2.1225
# epoch:1907  d_loss:0.4829  g_loss:1.5595
# epoch:1908  d_loss:0.3865  g_loss:1.8295
# epoch:1909  d_loss:0.3078  g_loss:1.7824
# epoch:1910  d_loss:0.3682  g_loss:1.7451
# epoch:1911  d_loss:0.3754  g_loss:1.7159
# epoch:1912  d_loss:0.4442  g_loss:1.7151
# epoch:1913  d_loss:0.3810  g_loss:1.5377
# epoch:1914  d_loss:0.4256  g_loss:1.5016
# epoch:1915  d_loss:0.4007  g_loss:1.5264
# epoch:1916  d_loss:0.3865  g_loss:1.5452
# epoch:1917  d_loss:0.4176  g_loss:1.7581
# epoch:1918  d_loss:0.5412  g_loss:1.5860
# epoch:1919  d_loss:0.6055  g_loss:1.1402
# epoch:1920  d_loss:0.4642  g_loss:1.5577
# epoch:1921  d_loss:0.4583  g_loss:1.5321
# epoch:1922  d_loss:0.6121  g_loss:1.2365
# epoch:1923  d_loss:0.7051  g_loss:1.1772
# epoch:1924  d_loss:0.5156  g_loss:1.9441
# epoch:1925  d_loss:0.6741  g_loss:1.6741
# epoch:1926  d_loss:0.6378  g_loss:1.3541
# epoch:1927  d_loss:0.5615  g_loss:1.1979
# epoch:1928  d_loss:0.4760  g_loss:1.4799
# epoch:1929  d_loss:0.5570  g_loss:1.2928
# epoch:1930  d_loss:0.5597  g_loss:1.2450
# epoch:1931  d_loss:0.4877  g_loss:1.3189
# epoch:1932  d_loss:0.5639  g_loss:1.6607
# epoch:1933  d_loss:0.5433  g_loss:1.7103
# epoch:1934  d_loss:0.4790  g_loss:1.7498
# epoch:1935  d_loss:0.5080  g_loss:1.8793
# epoch:1936  d_loss:0.3813  g_loss:1.6002
# epoch:1937  d_loss:0.5305  g_loss:1.4744
# epoch:1938  d_loss:0.4793  g_loss:1.4539
# epoch:1939  d_loss:0.4108  g_loss:1.8432
# epoch:1940  d_loss:0.3349  g_loss:2.0276
# epoch:1941  d_loss:0.6073  g_loss:1.7924
# epoch:1942  d_loss:0.5680  g_loss:1.8028
# epoch:1943  d_loss:0.4448  g_loss:1.5263
# epoch:1944  d_loss:0.4629  g_loss:1.6319
# epoch:1945  d_loss:0.4477  g_loss:1.7043
# epoch:1946  d_loss:0.5118  g_loss:1.5068
# epoch:1947  d_loss:0.4507  g_loss:1.5387
# epoch:1948  d_loss:0.5431  g_loss:1.6387
# epoch:1949  d_loss:0.5671  g_loss:1.6163
# epoch:1950  d_loss:0.4649  g_loss:1.6516
# epoch:1951  d_loss:0.4929  g_loss:1.7838
# epoch:1952  d_loss:0.5319  g_loss:1.5709
# epoch:1953  d_loss:0.4579  g_loss:1.4864
# epoch:1954  d_loss:0.5633  g_loss:1.5889
# epoch:1955  d_loss:0.6217  g_loss:1.4809
# epoch:1956  d_loss:0.4395  g_loss:1.5356
# epoch:1957  d_loss:0.5554  g_loss:1.7485
# epoch:1958  d_loss:0.6658  g_loss:1.5624
# epoch:1959  d_loss:0.6036  g_loss:1.2354
# epoch:1960  d_loss:0.3996  g_loss:1.4330
# epoch:1961  d_loss:0.5361  g_loss:1.4349
# epoch:1962  d_loss:0.4903  g_loss:1.5179
# epoch:1963  d_loss:0.6483  g_loss:1.5699
# epoch:1964  d_loss:0.4656  g_loss:2.0647
# epoch:1965  d_loss:0.5327  g_loss:1.6532
# epoch:1966  d_loss:0.4794  g_loss:1.4510
# epoch:1967  d_loss:0.4628  g_loss:1.5010
# epoch:1968  d_loss:0.4450  g_loss:1.4526
# epoch:1969  d_loss:0.4012  g_loss:1.3595
# epoch:1970  d_loss:0.4817  g_loss:1.5188
# epoch:1971  d_loss:0.4677  g_loss:1.9337
# epoch:1972  d_loss:0.5562  g_loss:1.5452
# epoch:1973  d_loss:0.3474  g_loss:1.9030
# epoch:1974  d_loss:0.4016  g_loss:1.5744
# epoch:1975  d_loss:0.3264  g_loss:1.9418
# epoch:1976  d_loss:0.5454  g_loss:1.5546
# epoch:1977  d_loss:0.4779  g_loss:1.5339
# epoch:1978  d_loss:0.4518  g_loss:1.8823
# epoch:1979  d_loss:0.4410  g_loss:1.6229
# epoch:1980  d_loss:0.3459  g_loss:1.7020
# epoch:1981  d_loss:0.4617  g_loss:1.5069
# epoch:1982  d_loss:0.3930  g_loss:1.6088
# epoch:1983  d_loss:0.5280  g_loss:1.3751
# epoch:1984  d_loss:0.5193  g_loss:1.6654
# epoch:1985  d_loss:0.4686  g_loss:1.4633
# epoch:1986  d_loss:0.6143  g_loss:1.6296
# epoch:1987  d_loss:0.5081  g_loss:1.3646
# epoch:1988  d_loss:0.5140  g_loss:1.3902
# epoch:1989  d_loss:0.4981  g_loss:1.5247
# epoch:1990  d_loss:0.5903  g_loss:1.0711
# epoch:1991  d_loss:0.5989  g_loss:1.3163
# epoch:1992  d_loss:0.6153  g_loss:1.4596
# epoch:1993  d_loss:0.7263  g_loss:1.3412
# epoch:1994  d_loss:0.4770  g_loss:1.6201
# epoch:1995  d_loss:0.5634  g_loss:1.4525
# epoch:1996  d_loss:0.5625  g_loss:1.5925
# epoch:1997  d_loss:0.6960  g_loss:1.1721
# epoch:1998  d_loss:0.5794  g_loss:1.3820
# epoch:1999  d_loss:0.4916  g_loss:1.5338
# epoch:2000  d_loss:0.4690  g_loss:1.4901

# %% [markdown]
# ## 4. 이미지의 특징을 추출하는 오토인코더

# %% [markdown]
# ### 실습: 오토인코더 실습하기

# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, UpSampling2D, Flatten, Reshape

import matplotlib.pyplot as plt
import numpy as np

# MNIST 데이터셋을 불러옵니다.

(X_train, _), (X_test, _) = mnist.load_data()
X_train = X_train.reshape(X_train.shape[0], 28, 28, 1).astype('float32') / 255
X_test = X_test.reshape(X_test.shape[0], 28, 28, 1).astype('float32') / 255

# 생성자 모델을 만듭니다.
autoencoder = Sequential()

# 인코딩 부분입니다.
autoencoder.add(Conv2D(16, kernel_size=3, padding='same', input_shape=(28,28,1), activation='relu'))
autoencoder.add(MaxPooling2D(pool_size=2, padding='same'))
autoencoder.add(Conv2D(8, kernel_size=3, activation='relu', padding='same'))
autoencoder.add(MaxPooling2D(pool_size=2, padding='same'))
autoencoder.add(Conv2D(8, kernel_size=3, strides=2, padding='same', activation='relu'))

# 디코딩 부분입니다.
autoencoder.add(Conv2D(8, kernel_size=3, padding='same', activation='relu'))
autoencoder.add(UpSampling2D())
autoencoder.add(Conv2D(8, kernel_size=3, padding='same', activation='relu'))
autoencoder.add(UpSampling2D())
autoencoder.add(Conv2D(16, kernel_size=3, activation='relu'))
autoencoder.add(UpSampling2D())
autoencoder.add(Conv2D(1, kernel_size=3, padding='same', activation='sigmoid'))

# 전체 구조를 확인합니다.
autoencoder.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_18 (Conv2D)          (None, 28, 28, 16)        160
#
#  max_pooling2d_4 (MaxPooling  (None, 14, 14, 16)       0
#  2D)
#
#  conv2d_19 (Conv2D)          (None, 14, 14, 8)         1160
#
#  max_pooling2d_5 (MaxPooling  (None, 7, 7, 8)          0
#  2D)
#
#  conv2d_20 (Conv2D)          (None, 4, 4, 8)           584
#
#  conv2d_21 (Conv2D)          (None, 4, 4, 8)           584
#
#  up_sampling2d_8 (UpSampling  (None, 8, 8, 8)          0
#  2D)
#
#  conv2d_22 (Conv2D)          (None, 8, 8, 8)           584
#
#  up_sampling2d_9 (UpSampling  (None, 16, 16, 8)        0
#  2D)
#
#  conv2d_23 (Conv2D)          (None, 14, 14, 16)        1168
#
#  up_sampling2d_10 (UpSamplin  (None, 28, 28, 16)       0
#  g2D)
#
#  conv2d_24 (Conv2D)          (None, 28, 28, 1)         145
#
# =================================================================
# Total params: 4,385
# Trainable params: 4,385
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 컴파일 및 학습을 하는 부분입니다.
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')
autoencoder.fit(X_train, X_train, epochs=50, batch_size=128, validation_data=(X_test, X_test))

# 학습된 결과를 출력하는 부분입니다.
random_test = np.random.randint(X_test.shape[0], size=5)  # 테스트할 이미지를 랜덤하게 불러옵니다.
ae_imgs = autoencoder.predict(X_test)                     # 앞서 만든 오토인코더 모델에 집어 넣습니다.

plt.figure(figsize=(7, 2))                         # 출력될 이미지의 크기를 정합니다.

for i, image_idx in enumerate(random_test):        # 랜덤하게 뽑은 이미지를 차례로 나열합니다.
   ax = plt.subplot(2, 7, i + 1)
   plt.imshow(X_test[image_idx].reshape(28, 28))   # 테스트할 이미지를 먼저 그대로 보여줍니다.
   ax.axis('off')
   ax = plt.subplot(2, 7, 7 + i +1)
   plt.imshow(ae_imgs[image_idx].reshape(28, 28))  # 오토인코딩 결과를 다음열에 출력합니다.
   ax.axis('off')
plt.show()
# Out:
# Epoch 1/50
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x0000012BC0C5A288> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x0000012BC0C5A288> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 463/469 [============================>.] - ETA: 0s - loss: 0.0861WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x0000012BC0C77708> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x0000012BC0C77708> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0861 - val_loss: 0.0841
# Epoch 2/50
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0850 - val_loss: 0.0841
# Epoch 3/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0851 - val_loss: 0.0844
# Epoch 4/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0851 - val_loss: 0.0839
# Epoch 5/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0850 - val_loss: 0.0840
# Epoch 6/50
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0849 - val_loss: 0.0839
# Epoch 7/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0849 - val_loss: 0.0840
# Epoch 8/50
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0848 - val_loss: 0.0837
# Epoch 9/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0847 - val_loss: 0.0840
# Epoch 10/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0847 - val_loss: 0.0839
# Epoch 11/50
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0847 - val_loss: 0.0841
# Epoch 12/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0845 - val_loss: 0.0836
# Epoch 13/50
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0845 - val_loss: 0.0837
# Epoch 14/50
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0845 - val_loss: 0.0838
# Epoch 15/50
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0844 - val_loss: 0.0834
# Epoch 16/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0844 - val_loss: 0.0839
# Epoch 17/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0844 - val_loss: 0.0838
# Epoch 18/50
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0843 - val_loss: 0.0832
# Epoch 19/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0843 - val_loss: 0.0835
# Epoch 20/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0842 - val_loss: 0.0835
# Epoch 21/50
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0841 - val_loss: 0.0835
# Epoch 22/50
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0841 - val_loss: 0.0832
# Epoch 23/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0841 - val_loss: 0.0832
# Epoch 24/50
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0840 - val_loss: 0.0836
# Epoch 25/50
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0840 - val_loss: 0.0834
# Epoch 26/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0839 - val_loss: 0.0830
# Epoch 27/50
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0839 - val_loss: 0.0830
# Epoch 28/50
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0839 - val_loss: 0.0829
# Epoch 29/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0838 - val_loss: 0.0829
# Epoch 30/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0837 - val_loss: 0.0828
# Epoch 31/50
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0837 - val_loss: 0.0829
# Epoch 32/50
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0836 - val_loss: 0.0827
# Epoch 33/50
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0837 - val_loss: 0.0828
# Epoch 34/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0836 - val_loss: 0.0827
# Epoch 35/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0836 - val_loss: 0.0827
# Epoch 36/50
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0835 - val_loss: 0.0832
# Epoch 37/50
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0835 - val_loss: 0.0825
# Epoch 38/50
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0835 - val_loss: 0.0824
# Epoch 39/50
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0834 - val_loss: 0.0824
# Epoch 40/50
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0834 - val_loss: 0.0827
# Epoch 41/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0833 - val_loss: 0.0824
# Epoch 42/50
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0833 - val_loss: 0.0824
# Epoch 43/50
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0832 - val_loss: 0.0823
# Epoch 44/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0832 - val_loss: 0.0823
# Epoch 45/50
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0832 - val_loss: 0.0829
# Epoch 46/50
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0831 - val_loss: 0.0822
# Epoch 47/50
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0831 - val_loss: 0.0821
# Epoch 48/50
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0831 - val_loss: 0.0822
# Epoch 49/50
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0830 - val_loss: 0.0820
# Epoch 50/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0829 - val_loss: 0.0825
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x0000012BC0DFB798> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x0000012BC0DFB798> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
